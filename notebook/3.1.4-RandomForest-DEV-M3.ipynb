# %% [markdown]
# # Import Packages

# %%
from numpy import asarray
from IPython.display import display, HTML
from set_params import func_train_test_split, count_train_test, series_to_supervised, train_test_split, vif_check
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random as rd
import time
import warnings

def calculate_iqr(values):
    # Calculate Q1
    Q1 = np.percentile(values, 25)
    # Calculate Q3
    Q3 = np.percentile(values, 75)
    # Calculate IQR
    IQR = Q3 - Q1
    return IQR

def detect_outliers_iqr(values):
    # Calculate the IQR of the values
    IQR = calculate_iqr(values)
    # Calculate Q1 and Q3
    Q1 = np.percentile(values, 25)
    Q3 = np.percentile(values, 75)
    # Define the lower and upper bound for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    # Return a boolean array: True if the value is an outlier, False otherwise
    return lower_bound, upper_bound

def vis_line_plot_results(y_pred, y_test, model = 'HAR', name = 'BARCLAYS', r = 1, dataset = 'm1'):

    plt.figure(figsize=(10,4))
    true, = plt.plot(y_test)
    preds, = plt.plot(y_pred)
    plt.title(f'{model}-{dataset}-{name}', fontsize=15)
    plt.legend(['True Volatility', 'Predicted Volatility'], fontsize=9)
    plt.xticks(rotation=45)
    plt.savefig(f'../outputs/{model}-{dataset}/{str(r+1).zfill(3)}-{model}-{name}.png')
    plt.close()

# display(HTML("<style>.container { width:80% !important; }</style>"))
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100)

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Import Data and Split Train - Test

# %%
base_FTSE_df = pd.read_csv('../data/1.3-FTSE_Monthly_ESG_Volatility_Final.csv')
base_FTSE_df = base_FTSE_df.rename(columns={'Date_x':'date_key'})

# %%
train_df, valid_df, test_df = func_train_test_split(validation = False, threshold = 24)

# %%
count_rows_df = count_train_test(train_df, test_df)

# %%
coverage_df = pd.read_csv('../data/coverage_dataframe.csv')
coverage_df.PermID = coverage_df.PermID.astype(int)
coverage_df = coverage_df[['PermID', 'Name']]
coverage_df = coverage_df.rename(columns={'PermID':'Asset'})

# %%
train_df = pd.merge(train_df, coverage_df, how = 'left', on = 'Asset')
train_df.index = train_df.month_key

# %%
# fit an random forest model and make a one step prediction
def random_forest_forecast(train, testX):
    # transform list into array
    train = asarray(train)
    # split into input and output columns
    trainX, trainy = train[:, :-1], train[:, -1]
    # fit model
    model = RandomForestRegressor(n_estimators=1000)
    model.fit(trainX, trainy)
    # make a one-step prediction
    yhat = model.predict([testX])
    return yhat[0]

# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, verbose = True):
    predictions = list()
    # split dataset
    train, test = train_test_split(data, n_test)
    # seed history with training dataset
    history = [x for x in train]
    # print(history)
    # step over each time-step in the test set
    
    for i in range(len(test)):
        # split test row into input and output columns
        testX, testy = test[i, :-1], test[i, -1]
        # fit model on history and make a prediction
        yhat = random_forest_forecast(history, testX)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for the next loop
        history.append(test[i])
        # summarize progress
        # print('>expected=%.4f, predicted=%.4f' % (testy, yhat))
        
    # estimate prediction error
    error = mean_squared_error(test[:, -1], predictions) *10**3
    # error = mean_absolute_error(test[:, -1], predictions)
    
    return error, test[:, -1], predictions

# %%
def compile_train_test(train_df, test_df, sample = True, algo = 'HAR', dataset = 'm1', viz = False, cap = True):
    '''
    '''
    test_perc = .3 

    if dataset == 'm1':
        cols = ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
        
    elif dataset == 'm2':
        cols = vif_check()

    else:
        cols = [ 'buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar'
                ,'CSRStrategy','Community','Emissions','EnvironmentalInnovation','HumanRights','Management','ProductResponsibility'
                ,'ResourceUse','Shareholders','Workforce', 'vol_series_daily','vol_series_weekly','vol_series_monthly', 'V^YZ']
                
        # version 2
        cols = ['buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar','Community',
                'EnvironmentalInnovation','Management','ProductResponsibility','Shareholders','Workforce', 'V^YZ']


    mresults = pd.DataFrame()

    if sample:
        assets = [4295894970, 8589934212]
    else:
        assets = train_df.Asset.unique().tolist()

    for r, asset in enumerate(assets): 
        # print(asset)
        name = train_df[train_df['Asset'] == asset].iloc[0,-1]

        df_train = train_df[train_df.Asset == asset][cols].dropna()
        df_test = test_df[test_df.Asset == asset][cols].dropna()
        indices = test_df[test_df.Asset == asset].index

        # print(asset, df_train.shape, df_test.shape)
        df_merge = pd.concat([df_train, df_test])
        df_merge = series_to_supervised(df_merge, n_in=3, target= ['V^YZ'])
        test_size = int(df_merge.shape[0] * test_perc)
        
        print(f'Execute Training and Walk Forward Testing for ({name}) for {test_size} times..')
        start_time = time.time()
        mse, y, yhat = walk_forward_validation(df_merge, test_size)
        print("---"*10, "%s seconds |"%(time.time() - start_time), 'MAE: %.3f'%mse, "---"*10)
        
        mresult = pd.DataFrame({
            'Asset': asset,
            'Name': name,
            'Model': algo,
            'Test Size': test_size,
            'MSE^3':mse
                    }
            , index=[r]
        )
        mresults = pd.concat([mresults, mresult])

        if viz: 
            vis_line_plot_results(yhat, y, model = algo, dataset=dataset, name=name, r = r)

    return mresults

# %%
mresults_m3 = compile_train_test(train_df, test_df, sample=False, algo='RF', dataset='m3', viz=True, cap = True)
# Out:
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 7 times..
# ------------------------------ 4.883482456207275 seconds | MAE: 0.046 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 6 times..
# ------------------------------ 4.217527866363525 seconds | MAE: 0.338 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 8 times..
# ------------------------------ 5.941842317581177 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 10 times..
# ------------------------------ 7.865678787231445 seconds | MAE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 11 times..
# ------------------------------ 8.690311431884766 seconds | MAE: 0.223 ------------------------------
# Execute Training and Walk Forward Testing for (JD Sports Fashion PLC) for 11 times..
# ------------------------------ 8.67822551727295 seconds | MAE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (Phoenix Group Holdings PLC) for 12 times..
# ------------------------------ 10.017807006835938 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Spirax-Sarco Engineering PLC) for 13 times..
# ------------------------------ 10.916305541992188 seconds | MAE: 0.018 ------------------------------
# Execute Training and Walk Forward Testing for (Entain PLC) for 10 times..
# ------------------------------ 7.6443281173706055 seconds | MAE: 0.053 ------------------------------
# Execute Training and Walk Forward Testing for (Ocado Group PLC) for 15 times..
# ------------------------------ 13.138224124908447 seconds | MAE: 0.074 ------------------------------
# Execute Training and Walk Forward Testing for (Rightmove PLC) for 15 times..
# ------------------------------ 13.583964586257935 seconds | MAE: 0.031 ------------------------------
# Execute Training and Walk Forward Testing for (Halma PLC) for 17 times..
# ------------------------------ 16.028521060943604 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (DS Smith PLC) for 17 times..
# ------------------------------ 15.416588544845581 seconds | MAE: 0.021 ------------------------------
# Execute Training and Walk Forward Testing for (NMC Health PLC) for 7 times..
# ------------------------------ 4.8742899894714355 seconds | MAE: 0.996 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish Mortgage Investment Trust PLC) for 19 times..
# ------------------------------ 18.196420431137085 seconds | MAE: 0.064 ------------------------------
# Execute Training and Walk Forward Testing for (Smurfit Kappa Group PLC) for 20 times..
# ------------------------------ 20.275894165039062 seconds | MAE: 0.043 ------------------------------
# Execute Training and Walk Forward Testing for (Micro Focus International Ltd) for 9 times..
# ------------------------------ 6.93036150932312 seconds | MAE: 0.116 ------------------------------
# Execute Training and Walk Forward Testing for (Informa PLC) for 23 times..
# ------------------------------ 25.316927909851074 seconds | MAE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (Mediclinic Group Ltd) for 6 times..
# ------------------------------ 4.314666032791138 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Flutter Entertainment PLC) for 23 times..
# ------------------------------ 26.255093097686768 seconds | MAE: 0.039 ------------------------------
# Execute Training and Walk Forward Testing for (DCC PLC) for 24 times..
# ------------------------------ 28.15375804901123 seconds | MAE: 0.009 ------------------------------
# Execute Training and Walk Forward Testing for (Berkeley Group Holdings PLC) for 21 times..
# ------------------------------ 22.77806329727173 seconds | MAE: 0.110 ------------------------------
# Execute Training and Walk Forward Testing for (Merlin Entertainments Ltd) for 8 times..
# ------------------------------ 5.822359561920166 seconds | MAE: 0.150 ------------------------------
# Execute Training and Walk Forward Testing for (Hikma Pharmaceuticals PLC) for 17 times..
# ------------------------------ 17.115599155426025 seconds | MAE: 0.036 ------------------------------
# Execute Training and Walk Forward Testing for (TUI AG) for 16 times..
# ------------------------------ 14.457281589508057 seconds | MAE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Direct Line Insurance Group PLC) for 16 times..
# ------------------------------ 15.191154479980469 seconds | MAE: 0.012 ------------------------------
# Execute Training and Walk Forward Testing for (International Distributions Services PLC) for 18 times..
# ------------------------------ 17.49490737915039 seconds | MAE: 0.045 ------------------------------
# Execute Training and Walk Forward Testing for (Ashtead Group PLC) for 31 times..
# ------------------------------ 42.39440178871155 seconds | MAE: 0.091 ------------------------------
# Execute Training and Walk Forward Testing for (Coca Cola HBC AG) for 32 times..
# ------------------------------ 43.136908769607544 seconds | MAE: 0.036 ------------------------------
# Execute Training and Walk Forward Testing for (Frasers Group PLC) for 8 times..
# ------------------------------ 5.8790881633758545 seconds | MAE: 0.053 ------------------------------
# Execute Training and Walk Forward Testing for (Mondi PLC) for 32 times..
# ------------------------------ 42.49892592430115 seconds | MAE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Travis Perkins PLC) for 11 times..
# ------------------------------ 8.791836500167847 seconds | MAE: 1.660 ------------------------------
# Execute Training and Walk Forward Testing for (Easyjet PLC) for 22 times..
# ------------------------------ 24.231114864349365 seconds | MAE: 0.269 ------------------------------
# Execute Training and Walk Forward Testing for (Melrose Industries PLC) for 21 times..
# ------------------------------ 22.030640602111816 seconds | MAE: 0.057 ------------------------------
# Execute Training and Walk Forward Testing for (Babcock International Group PLC) for 18 times..
# ------------------------------ 17.587436199188232 seconds | MAE: 0.127 ------------------------------
# Execute Training and Walk Forward Testing for (Croda International PLC) for 27 times..
# ------------------------------ 33.10201930999756 seconds | MAE: 0.014 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn Holdings Ltd) for 13 times..
# ------------------------------ 10.51199197769165 seconds | MAE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (EVRAZ plc) for 18 times..
# ------------------------------ 17.411438941955566 seconds | MAE: 0.171 ------------------------------
# Execute Training and Walk Forward Testing for (Polymetal International PLC) for 13 times..
# ------------------------------ 11.084566593170166 seconds | MAE: 1.070 ------------------------------
# Execute Training and Walk Forward Testing for (Meggitt Ltd) for 19 times..
# ------------------------------ 21.286808490753174 seconds | MAE: 0.386 ------------------------------
# Execute Training and Walk Forward Testing for (Glencore PLC) for 40 times..
# ------------------------------ 65.46829414367676 seconds | MAE: 0.105 ------------------------------
# Execute Training and Walk Forward Testing for (Hargreaves Lansdown PLC) for 41 times..
# ------------------------------ 66.64122223854065 seconds | MAE: 0.085 ------------------------------
# Execute Training and Walk Forward Testing for (International Consolidated Airlines Group SA) for 41 times..
# ------------------------------ 74.57815861701965 seconds | MAE: 0.192 ------------------------------
# Execute Training and Walk Forward Testing for (IMI PLC) for 13 times..
# ------------------------------ 10.571202754974365 seconds | MAE: 0.012 ------------------------------
# Execute Training and Walk Forward Testing for (Weir Group PLC) for 18 times..
# ------------------------------ 16.98481035232544 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (GKN Ltd) for 26 times..
# ------------------------------ 30.384570598602295 seconds | MAE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (SVF Holdco (UK) Ltd) for 22 times..
# ------------------------------ 23.854800701141357 seconds | MAE: 0.362 ------------------------------
# Execute Training and Walk Forward Testing for (Aggreko Ltd) for 18 times..
# ------------------------------ 17.996901273727417 seconds | MAE: 0.012 ------------------------------
# Execute Training and Walk Forward Testing for (Burberry Group PLC) for 46 times..
# ------------------------------ 83.45892691612244 seconds | MAE: 0.047 ------------------------------
# Execute Training and Walk Forward Testing for (Intertek Group PLC) for 48 times..
# ------------------------------ 89.11326551437378 seconds | MAE: 0.105 ------------------------------
# Execute Training and Walk Forward Testing for (Serco Group PLC) for 15 times..
# ------------------------------ 13.907318830490112 seconds | MAE: 0.015 ------------------------------
# Execute Training and Walk Forward Testing for (Barrick Gold (Holdings) Ltd) for 34 times..
# ------------------------------ 47.49015212059021 seconds | MAE: 0.039 ------------------------------
# Execute Training and Walk Forward Testing for (Fresnillo PLC) for 48 times..
# ------------------------------ 84.82464957237244 seconds | MAE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (Inmarsat Group Holdings Ltd) for 13 times..
# ------------------------------ 11.146825551986694 seconds | MAE: 0.036 ------------------------------
# Execute Training and Walk Forward Testing for (Autonomy Corp Ltd) for 9 times..
# ------------------------------ 6.864465236663818 seconds | MAE: 1.570 ------------------------------
# Execute Training and Walk Forward Testing for (Petrofac Ltd) for 21 times..
# ------------------------------ 22.202098846435547 seconds | MAE: 0.075 ------------------------------
# Execute Training and Walk Forward Testing for (John Wood Group PLC) for 7 times..
# ------------------------------ 5.001367568969727 seconds | MAE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (Bunzl plc) for 49 times..
# ------------------------------ 97.27746820449829 seconds | MAE: 0.088 ------------------------------
# Execute Training and Walk Forward Testing for (Cobham Ltd) for 8 times..
# ------------------------------ 5.980201005935669 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance Trust PLC) for 9 times..
# ------------------------------ 6.932132244110107 seconds | MAE: 0.003 ------------------------------
# Execute Training and Walk Forward Testing for (London Stock Exchange Group PLC) for 41 times..
# ------------------------------ 64.22109341621399 seconds | MAE: 0.082 ------------------------------
# Execute Training and Walk Forward Testing for (Admiral Group PLC) for 53 times..
# ------------------------------ 110.63893032073975 seconds | MAE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (Tui Travel Ltd) for 18 times..
# ------------------------------ 17.01633358001709 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Amec Foster Wheeler Ltd) for 21 times..
# ------------------------------ 22.608277559280396 seconds | MAE: 0.011 ------------------------------
# Execute Training and Walk Forward Testing for (G4S Ltd) for 30 times..
# ------------------------------ 40.63185691833496 seconds | MAE: 0.009 ------------------------------
# Execute Training and Walk Forward Testing for (Currys PLC) for 11 times..
# ------------------------------ 8.813828468322754 seconds | MAE: 3.376 ------------------------------
# Execute Training and Walk Forward Testing for (Tullow Oil PLC) for 25 times..
# ------------------------------ 29.189104318618774 seconds | MAE: 0.047 ------------------------------
# Execute Training and Walk Forward Testing for (Taylor Wimpey PLC) for 29 times..
# ------------------------------ 38.435229778289795 seconds | MAE: 0.058 ------------------------------
# Execute Training and Walk Forward Testing for (Barratt Developments P L C) for 30 times..
# ------------------------------ 41.24708580970764 seconds | MAE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (Whitbread PLC) for 55 times..
# ------------------------------ 118.69400954246521 seconds | MAE: 0.111 ------------------------------
# Execute Training and Walk Forward Testing for (Experian PLC) for 57 times..
# ------------------------------ 119.01350831985474 seconds | MAE: 0.119 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn PLC) for 56 times..
# ------------------------------ 121.0846037864685 seconds | MAE: 0.138 ------------------------------
# Execute Training and Walk Forward Testing for (SEGRO PLC) for 26 times..
# ------------------------------ 29.520578861236572 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (NEX Group Ltd) for 21 times..
# ------------------------------ 22.748126745224 seconds | MAE: 0.084 ------------------------------
# Execute Training and Walk Forward Testing for (Sibanye Uk Ltd) for 17 times..
# ------------------------------ 16.070423126220703 seconds | MAE: 0.242 ------------------------------
# Execute Training and Walk Forward Testing for (Aviva PLC) for 60 times..
# ------------------------------ 131.02703857421875 seconds | MAE: 0.071 ------------------------------
# Execute Training and Walk Forward Testing for (Barclays PLC) for 60 times..
# ------------------------------ 133.83205580711365 seconds | MAE: 0.183 ------------------------------
# Execute Training and Walk Forward Testing for (HSBC Holdings PLC) for 60 times..
# ------------------------------ 127.44667291641235 seconds | MAE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 60 times..
# ------------------------------ 137.6892912387848 seconds | MAE: 0.101 ------------------------------
# Execute Training and Walk Forward Testing for (Prudential PLC) for 60 times..
# ------------------------------ 132.05940508842468 seconds | MAE: 0.119 ------------------------------
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 60 times..
# ------------------------------ 127.8827817440033 seconds | MAE: 0.104 ------------------------------
# Execute Training and Walk Forward Testing for (Man Group PLC) for 21 times..
# ------------------------------ 22.108975410461426 seconds | MAE: 0.067 ------------------------------
# Execute Training and Walk Forward Testing for (WPP PLC) for 60 times..
# ------------------------------ 142.79650044441223 seconds | MAE: 0.076 ------------------------------
# Execute Training and Walk Forward Testing for (Rolls-Royce Holdings PLC) for 60 times..
# ------------------------------ 128.2963423728943 seconds | MAE: 0.245 ------------------------------
# Execute Training and Walk Forward Testing for (United Utilities Group PLC) for 60 times..
# ------------------------------ 130.22650265693665 seconds | MAE: 0.038 ------------------------------
# Execute Training and Walk Forward Testing for (Xstrata Ltd) for 25 times..
# ------------------------------ 27.84902811050415 seconds | MAE: 0.074 ------------------------------
# Execute Training and Walk Forward Testing for (BAE Systems PLC) for 60 times..
# ------------------------------ 130.300208568573 seconds | MAE: 0.038 ------------------------------
# Execute Training and Walk Forward Testing for (EDF Energy Nuclear Generation Group Ltd) for 7 times..
# ------------------------------ 5.023589134216309 seconds | MAE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (Sage Group PLC) for 60 times..
# ------------------------------ 133.8454737663269 seconds | MAE: 0.045 ------------------------------
# Execute Training and Walk Forward Testing for (Antofagasta PLC) for 60 times..
# ------------------------------ 140.59568619728088 seconds | MAE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (ITV PLC) for 45 times..
# ------------------------------ 89.05637383460999 seconds | MAE: 0.165 ------------------------------
# Execute Training and Walk Forward Testing for (WM Morrison Supermarkets Ltd) for 52 times..
# ------------------------------ 102.31881785392761 seconds | MAE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (Sky Ltd) for 44 times..
# ------------------------------ 74.52137851715088 seconds | MAE: 0.068 ------------------------------
# Execute Training and Walk Forward Testing for (Vodafone Group PLC) for 60 times..
# ------------------------------ 135.0631263256073 seconds | MAE: 0.070 ------------------------------
# Execute Training and Walk Forward Testing for (Severn Trent PLC) for 60 times..
# ------------------------------ 136.37939500808716 seconds | MAE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Anglo American PLC) for 60 times..
# ------------------------------ 134.16515278816223 seconds | MAE: 0.082 ------------------------------
# Execute Training and Walk Forward Testing for (Abi Sab Group Holding Ltd) for 37 times..
# ------------------------------ 55.37450671195984 seconds | MAE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (Kingfisher PLC) for 58 times..
# ------------------------------ 136.03205132484436 seconds | MAE: 0.097 ------------------------------
# Execute Training and Walk Forward Testing for (3i Group PLC) for 48 times..
# ------------------------------ 94.66029024124146 seconds | MAE: 0.107 ------------------------------
# Execute Training and Walk Forward Testing for (GSK plc) for 60 times..
# ------------------------------ 132.06047892570496 seconds | MAE: 0.028 ------------------------------
# Execute Training and Walk Forward Testing for (Next PLC) for 60 times..
# ------------------------------ 140.88651418685913 seconds | MAE: 0.113 ------------------------------
# Execute Training and Walk Forward Testing for (HBOS Plc) for 9 times..
# ------------------------------ 6.765693187713623 seconds | MAE: 2.292 ------------------------------
# Execute Training and Walk Forward Testing for (BT Group PLC) for 60 times..
# ------------------------------ 138.64917850494385 seconds | MAE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (Compass Group PLC) for 60 times..
# ------------------------------ 136.5333776473999 seconds | MAE: 0.095 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance & Leicester Ltd) for 7 times..
# ------------------------------ 5.050229549407959 seconds | MAE: 0.176 ------------------------------
# Execute Training and Walk Forward Testing for (Tesco PLC) for 60 times..
# ------------------------------ 124.51765131950378 seconds | MAE: 0.028 ------------------------------
# Execute Training and Walk Forward Testing for (RSA Insurance Group Ltd) for 54 times..
# ------------------------------ 111.5603711605072 seconds | MAE: 0.077 ------------------------------
# Execute Training and Walk Forward Testing for (Standard Chartered PLC) for 60 times..
# ------------------------------ 130.0058982372284 seconds | MAE: 0.047 ------------------------------
# Execute Training and Walk Forward Testing for (Smith & Nephew PLC) for 60 times..
# ------------------------------ 129.9471640586853 seconds | MAE: 0.041 ------------------------------
# Execute Training and Walk Forward Testing for (Smiths Group PLC) for 58 times..
# ------------------------------ 130.19249629974365 seconds | MAE: 0.063 ------------------------------
# Execute Training and Walk Forward Testing for (Schroders PLC) for 57 times..
# ------------------------------ 120.68015003204346 seconds | MAE: 0.177 ------------------------------
# Execute Training and Walk Forward Testing for (J Sainsbury PLC) for 60 times..
# ------------------------------ 129.89662837982178 seconds | MAE: 0.059 ------------------------------
# Execute Training and Walk Forward Testing for (Hammerson PLC) for 42 times..
# ------------------------------ 66.08550333976746 seconds | MAE: 0.209 ------------------------------
# Execute Training and Walk Forward Testing for (Legal & General Group PLC) for 60 times..
# ------------------------------ 127.4420018196106 seconds | MAE: 0.114 ------------------------------
# Execute Training and Walk Forward Testing for (British Airways PLC) for 16 times..
# ------------------------------ 14.071931600570679 seconds | MAE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (BG Group Ltd) for 35 times..
# ------------------------------ 48.00514459609985 seconds | MAE: 0.138 ------------------------------
# Execute Training and Walk Forward Testing for (Associated British Foods PLC) for 60 times..
# ------------------------------ 141.66701674461365 seconds | MAE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (British Land Company PLC) for 60 times..
# ------------------------------ 130.29762506484985 seconds | MAE: 0.066 ------------------------------
# Execute Training and Walk Forward Testing for (BHP Group (UK) Ltd) for 56 times..
# ------------------------------ 115.88438200950623 seconds | MAE: 0.069 ------------------------------
# Execute Training and Walk Forward Testing for (Pearson PLC) for 60 times..
# ------------------------------ 133.1898021697998 seconds | MAE: 0.040 ------------------------------
# Execute Training and Walk Forward Testing for (Diageo PLC) for 60 times..
# ------------------------------ 132.88657331466675 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Johnson Matthey PLC) for 56 times..
# ------------------------------ 113.83777809143066 seconds | MAE: 0.067 ------------------------------
# Execute Training and Walk Forward Testing for (Rio Tinto PLC) for 60 times..
# ------------------------------ 131.8780541419983 seconds | MAE: 0.055 ------------------------------
# Execute Training and Walk Forward Testing for (British American Tobacco PLC) for 60 times..
# ------------------------------ 138.42968201637268 seconds | MAE: 0.059 ------------------------------
# Execute Training and Walk Forward Testing for (Unilever PLC) for 60 times..
# ------------------------------ 133.41779732704163 seconds | MAE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (Relx PLC) for 60 times..
# ------------------------------ 138.86368060112 seconds | MAE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (InterContinental Hotels Group PLC) for 60 times..
# ------------------------------ 120.05707168579102 seconds | MAE: 0.089 ------------------------------
# Execute Training and Walk Forward Testing for (Tate & Lyle PLC) for 16 times..
# ------------------------------ 14.771384239196777 seconds | MAE: 0.040 ------------------------------
# Execute Training and Walk Forward Testing for (Cadbury Ltd) for 13 times..
# ------------------------------ 11.121052980422974 seconds | MAE: 0.149 ------------------------------
# Execute Training and Walk Forward Testing for (Reckitt Benckiser Group PLC) for 60 times..
# ------------------------------ 142.6688961982727 seconds | MAE: 0.021 ------------------------------
# Execute Training and Walk Forward Testing for (Rexam Ltd) for 30 times..
# ------------------------------ 39.474536180496216 seconds | MAE: 0.014 ------------------------------
# Execute Training and Walk Forward Testing for (BP PLC) for 60 times..
# ------------------------------ 130.69818568229675 seconds | MAE: 0.104 ------------------------------
# Execute Training and Walk Forward Testing for (Centrica PLC) for 52 times..
# ------------------------------ 102.61248421669006 seconds | MAE: 0.150 ------------------------------
# Execute Training and Walk Forward Testing for (Shire Ltd) for 45 times..
# ------------------------------ 79.85457944869995 seconds | MAE: 0.196 ------------------------------
# Execute Training and Walk Forward Testing for (Imperial Brands PLC) for 60 times..
# ------------------------------ 131.04729056358337 seconds | MAE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (Ei Group Ltd) for 8 times..
# ------------------------------ 5.6999733448028564 seconds | MAE: 0.058 ------------------------------
# Execute Training and Walk Forward Testing for (Rentokil Initial PLC) for 24 times..
# ------------------------------ 27.63483715057373 seconds | MAE: 0.038 ------------------------------
# Execute Training and Walk Forward Testing for (National Grid PLC) for 60 times..
# ------------------------------ 135.58196020126343 seconds | MAE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Home Retail Group Ltd) for 13 times..
# ------------------------------ 10.6314537525177 seconds | MAE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (AstraZeneca PLC) for 60 times..
# ------------------------------ 125.26540970802307 seconds | MAE: 0.052 ------------------------------
# Execute Training and Walk Forward Testing for (SSE PLC) for 60 times..
# ------------------------------ 140.36392331123352 seconds | MAE: 0.070 ------------------------------
# Execute Training and Walk Forward Testing for (Capricorn Energy PLC) for 18 times..
# ------------------------------ 17.241917610168457 seconds | MAE: 0.145 ------------------------------
# Execute Training and Walk Forward Testing for (Persimmon PLC) for 41 times..
# ------------------------------ 72.67941308021545 seconds | MAE: 0.113 ------------------------------
# Execute Training and Walk Forward Testing for (Shell PLC) for 60 times..
# ------------------------------ 124.09483194351196 seconds | MAE: 0.100 ------------------------------

# %%
mresults_m2 = compile_train_test(train_df, test_df, sample=False, algo='RF', dataset='m2', viz=False, cap = True)
# Out:
# Execute Training and Walk Forward Testing for (Pershing Square Holdings Ltd) for 7 times..
# ------------------------------ 4.430306434631348 seconds | MAE: 0.023 ------------------------------
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 8 times..
# ------------------------------ 5.079566717147827 seconds | MAE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 7 times..
# ------------------------------ 4.345094919204712 seconds | MAE: 0.307 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 9 times..
# ------------------------------ 5.671299934387207 seconds | MAE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 11 times..
# ------------------------------ 7.384570837020874 seconds | MAE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 12 times..
# ------------------------------ 8.32431435585022 seconds | MAE: 0.193 ------------------------------
# Execute Training and Walk Forward Testing for (JD Sports Fashion PLC) for 12 times..
# ------------------------------ 8.418700218200684 seconds | MAE: 0.045 ------------------------------
# Execute Training and Walk Forward Testing for (Phoenix Group Holdings PLC) for 13 times..
# ------------------------------ 9.246777296066284 seconds | MAE: 0.014 ------------------------------
# Execute Training and Walk Forward Testing for (Auto Trader Group PLC) for 14 times..
# ------------------------------ 9.915968179702759 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (Spirax-Sarco Engineering PLC) for 14 times..
# ------------------------------ 10.496954441070557 seconds | MAE: 0.012 ------------------------------
# Execute Training and Walk Forward Testing for (Entain PLC) for 11 times..
# ------------------------------ 7.484467506408691 seconds | MAE: 0.018 ------------------------------
# Execute Training and Walk Forward Testing for (Ocado Group PLC) for 16 times..
# ------------------------------ 12.332998752593994 seconds | MAE: 0.072 ------------------------------
# Execute Training and Walk Forward Testing for (Rightmove PLC) for 16 times..
# ------------------------------ 12.047973394393921 seconds | MAE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Halma PLC) for 18 times..
# ------------------------------ 14.289210319519043 seconds | MAE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (DS Smith PLC) for 18 times..
# ------------------------------ 14.090862035751343 seconds | MAE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (NMC Health PLC) for 8 times..
# ------------------------------ 5.04246711730957 seconds | MAE: 0.921 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish Mortgage Investment Trust PLC) for 21 times..
# ------------------------------ 17.485164642333984 seconds | MAE: 0.058 ------------------------------
# Execute Training and Walk Forward Testing for (Smurfit Kappa Group PLC) for 21 times..
# ------------------------------ 18.805983781814575 seconds | MAE: 0.047 ------------------------------
# Execute Training and Walk Forward Testing for (Micro Focus International Ltd) for 10 times..
# ------------------------------ 6.6147284507751465 seconds | MAE: 0.092 ------------------------------
# Execute Training and Walk Forward Testing for (Informa PLC) for 24 times..
# ------------------------------ 22.135805368423462 seconds | MAE: 0.036 ------------------------------
# Execute Training and Walk Forward Testing for (Mediclinic Group Ltd) for 7 times..
# ------------------------------ 4.4147796630859375 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Flutter Entertainment PLC) for 24 times..
# ------------------------------ 22.651328563690186 seconds | MAE: 0.037 ------------------------------
# Execute Training and Walk Forward Testing for (Worldpay Group Ltd) for 7 times..
# ------------------------------ 4.368310928344727 seconds | MAE: 0.298 ------------------------------
# Execute Training and Walk Forward Testing for (DCC PLC) for 25 times..
# ------------------------------ 23.85920739173889 seconds | MAE: 0.028 ------------------------------
# Execute Training and Walk Forward Testing for (Berkeley Group Holdings PLC) for 22 times..
# ------------------------------ 20.02329969406128 seconds | MAE: 0.038 ------------------------------
# Execute Training and Walk Forward Testing for (Merlin Entertainments Ltd) for 9 times..
# ------------------------------ 5.771851301193237 seconds | MAE: 0.148 ------------------------------
# Execute Training and Walk Forward Testing for (Hikma Pharmaceuticals PLC) for 18 times..
# ------------------------------ 14.765790700912476 seconds | MAE: 0.054 ------------------------------
# Execute Training and Walk Forward Testing for (TUI AG) for 17 times..
# ------------------------------ 13.352498054504395 seconds | MAE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (Direct Line Insurance Group PLC) for 17 times..
# ------------------------------ 13.346447467803955 seconds | MAE: 0.013 ------------------------------
# Execute Training and Walk Forward Testing for (St James's Place PLC) for 31 times..
# ------------------------------ 31.388697862625122 seconds | MAE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (International Distributions Services PLC) for 19 times..
# ------------------------------ 15.213935136795044 seconds | MAE: 0.043 ------------------------------
# Execute Training and Walk Forward Testing for (Ashtead Group PLC) for 32 times..
# ------------------------------ 35.971545457839966 seconds | MAE: 0.104 ------------------------------
# Execute Training and Walk Forward Testing for (Coca Cola HBC AG) for 33 times..
# ------------------------------ 37.78202486038208 seconds | MAE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (Frasers Group PLC) for 9 times..
# ------------------------------ 5.819975137710571 seconds | MAE: 0.046 ------------------------------
# Execute Training and Walk Forward Testing for (Mondi PLC) for 33 times..
# ------------------------------ 36.58840036392212 seconds | MAE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (Travis Perkins PLC) for 12 times..
# ------------------------------ 8.174847841262817 seconds | MAE: 1.047 ------------------------------
# Execute Training and Walk Forward Testing for (Easyjet PLC) for 23 times..
# ------------------------------ 21.45510220527649 seconds | MAE: 0.195 ------------------------------
# Execute Training and Walk Forward Testing for (Melrose Industries PLC) for 23 times..
# ------------------------------ 20.312883138656616 seconds | MAE: 0.054 ------------------------------
# Execute Training and Walk Forward Testing for (Babcock International Group PLC) for 19 times..
# ------------------------------ 15.91657018661499 seconds | MAE: 0.119 ------------------------------
# Execute Training and Walk Forward Testing for (Croda International PLC) for 28 times..
# ------------------------------ 29.325948238372803 seconds | MAE: 0.013 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn Holdings Ltd) for 14 times..
# ------------------------------ 10.166339635848999 seconds | MAE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (EVRAZ plc) for 19 times..
# ------------------------------ 16.22707462310791 seconds | MAE: 0.521 ------------------------------
# Execute Training and Walk Forward Testing for (Polymetal International PLC) for 14 times..
# ------------------------------ 10.085023880004883 seconds | MAE: 1.028 ------------------------------
# Execute Training and Walk Forward Testing for (Meggitt Ltd) for 20 times..
# ------------------------------ 17.141391038894653 seconds | MAE: 0.545 ------------------------------
# Execute Training and Walk Forward Testing for (Glencore PLC) for 42 times..
# ------------------------------ 58.18687081336975 seconds | MAE: 0.100 ------------------------------
# Execute Training and Walk Forward Testing for (Hargreaves Lansdown PLC) for 42 times..
# ------------------------------ 59.87464618682861 seconds | MAE: 0.083 ------------------------------
# Execute Training and Walk Forward Testing for (International Consolidated Airlines Group SA) for 42 times..
# ------------------------------ 59.99422287940979 seconds | MAE: 0.153 ------------------------------
# Execute Training and Walk Forward Testing for (IMI PLC) for 14 times..
# ------------------------------ 9.833762407302856 seconds | MAE: 0.006 ------------------------------
# Execute Training and Walk Forward Testing for (Weir Group PLC) for 19 times..
# ------------------------------ 15.041467905044556 seconds | MAE: 0.011 ------------------------------
# Execute Training and Walk Forward Testing for (GKN Ltd) for 27 times..
# ------------------------------ 25.7106876373291 seconds | MAE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (SVF Holdco (UK) Ltd) for 23 times..
# ------------------------------ 21.358880519866943 seconds | MAE: 0.294 ------------------------------
# Execute Training and Walk Forward Testing for (Aggreko Ltd) for 19 times..
# ------------------------------ 16.007033824920654 seconds | MAE: 0.011 ------------------------------
# Execute Training and Walk Forward Testing for (Friends Life Group Ltd) for 17 times..
# ------------------------------ 12.394627571105957 seconds | MAE: 0.093 ------------------------------
# Execute Training and Walk Forward Testing for (Burberry Group PLC) for 48 times..
# ------------------------------ 75.35685586929321 seconds | MAE: 0.047 ------------------------------
# Execute Training and Walk Forward Testing for (Intertek Group PLC) for 49 times..
# ------------------------------ 77.08196592330933 seconds | MAE: 0.091 ------------------------------
# Execute Training and Walk Forward Testing for (Serco Group PLC) for 16 times..
# ------------------------------ 12.485655784606934 seconds | MAE: 0.015 ------------------------------
# Execute Training and Walk Forward Testing for (Barrick Gold (Holdings) Ltd) for 35 times..
# ------------------------------ 42.01677846908569 seconds | MAE: 0.040 ------------------------------
# Execute Training and Walk Forward Testing for (Fresnillo PLC) for 49 times..
# ------------------------------ 77.50269293785095 seconds | MAE: 0.046 ------------------------------
# Execute Training and Walk Forward Testing for (Inmarsat Group Holdings Ltd) for 14 times..
# ------------------------------ 10.270839929580688 seconds | MAE: 0.043 ------------------------------
# Execute Training and Walk Forward Testing for (Autonomy Corp Ltd) for 10 times..
# ------------------------------ 6.515974283218384 seconds | MAE: 1.238 ------------------------------
# Execute Training and Walk Forward Testing for (Petrofac Ltd) for 21 times..
# ------------------------------ 18.918067455291748 seconds | MAE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (John Wood Group PLC) for 8 times..
# ------------------------------ 5.061848163604736 seconds | MAE: 0.023 ------------------------------
# Execute Training and Walk Forward Testing for (Bunzl plc) for 51 times..
# ------------------------------ 82.921555519104 seconds | MAE: 0.086 ------------------------------
# Execute Training and Walk Forward Testing for (Cobham Ltd) for 9 times..
# ------------------------------ 5.895501613616943 seconds | MAE: 0.021 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance Trust PLC) for 10 times..
# ------------------------------ 6.60002326965332 seconds | MAE: 0.007 ------------------------------
# Execute Training and Walk Forward Testing for (London Stock Exchange Group PLC) for 42 times..
# ------------------------------ 56.22368335723877 seconds | MAE: 0.065 ------------------------------
# Execute Training and Walk Forward Testing for (Admiral Group PLC) for 54 times..
# ------------------------------ 99.24449324607849 seconds | MAE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (Tui Travel Ltd) for 19 times..
# ------------------------------ 15.438773155212402 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Amec Foster Wheeler Ltd) for 22 times..
# ------------------------------ 19.47523307800293 seconds | MAE: 0.012 ------------------------------
# Execute Training and Walk Forward Testing for (G4S Ltd) for 31 times..
# ------------------------------ 35.65961289405823 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Currys PLC) for 12 times..
# ------------------------------ 8.126533508300781 seconds | MAE: 3.143 ------------------------------
# Execute Training and Walk Forward Testing for (Tullow Oil PLC) for 26 times..
# ------------------------------ 25.539035320281982 seconds | MAE: 0.039 ------------------------------
# Execute Training and Walk Forward Testing for (Taylor Wimpey PLC) for 30 times..
# ------------------------------ 34.83242964744568 seconds | MAE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (Barratt Developments P L C) for 32 times..
# ------------------------------ 38.316643714904785 seconds | MAE: 0.046 ------------------------------
# Execute Training and Walk Forward Testing for (Whitbread PLC) for 56 times..
# ------------------------------ 106.44021916389465 seconds | MAE: 0.094 ------------------------------
# Execute Training and Walk Forward Testing for (Experian PLC) for 58 times..
# ------------------------------ 105.22927784919739 seconds | MAE: 0.141 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn PLC) for 57 times..
# ------------------------------ 103.44648170471191 seconds | MAE: 0.145 ------------------------------
# Execute Training and Walk Forward Testing for (SEGRO PLC) for 27 times..
# ------------------------------ 26.929062366485596 seconds | MAE: 0.024 ------------------------------
# Execute Training and Walk Forward Testing for (NEX Group Ltd) for 22 times..
# ------------------------------ 19.395933866500854 seconds | MAE: 0.061 ------------------------------
# Execute Training and Walk Forward Testing for (Sibanye Uk Ltd) for 18 times..
# ------------------------------ 14.362605810165405 seconds | MAE: 0.059 ------------------------------
# Execute Training and Walk Forward Testing for (Drax Group PLC) for 7 times..
# ------------------------------ 4.427797079086304 seconds | MAE: 0.083 ------------------------------
# Execute Training and Walk Forward Testing for (Aviva PLC) for 60 times..
# ------------------------------ 114.18013334274292 seconds | MAE: 0.059 ------------------------------
# Execute Training and Walk Forward Testing for (Barclays PLC) for 60 times..
# ------------------------------ 113.52146768569946 seconds | MAE: 0.175 ------------------------------
# Execute Training and Walk Forward Testing for (HSBC Holdings PLC) for 60 times..
# ------------------------------ 113.4215681552887 seconds | MAE: 0.024 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 60 times..
# ------------------------------ 117.7191116809845 seconds | MAE: 0.105 ------------------------------
# Execute Training and Walk Forward Testing for (Prudential PLC) for 60 times..
# ------------------------------ 114.5429425239563 seconds | MAE: 0.121 ------------------------------
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 60 times..
# ------------------------------ 111.63440608978271 seconds | MAE: 0.086 ------------------------------
# Execute Training and Walk Forward Testing for (Man Group PLC) for 22 times..
# ------------------------------ 19.619043588638306 seconds | MAE: 0.199 ------------------------------
# Execute Training and Walk Forward Testing for (WPP PLC) for 60 times..
# ------------------------------ 119.81936049461365 seconds | MAE: 0.054 ------------------------------
# Execute Training and Walk Forward Testing for (Rolls-Royce Holdings PLC) for 60 times..
# ------------------------------ 113.42445087432861 seconds | MAE: 0.229 ------------------------------
# Execute Training and Walk Forward Testing for (Cable and Wireless Communications Ltd (Pre-Merger)) for 12 times..
# ------------------------------ 7.690542936325073 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Friends Life FPG Ltd) for 12 times..
# ------------------------------ 8.165525436401367 seconds | MAE: 0.414 ------------------------------
# Execute Training and Walk Forward Testing for (United Utilities Group PLC) for 60 times..
# ------------------------------ 110.11680579185486 seconds | MAE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (Xstrata Ltd) for 25 times..
# ------------------------------ 23.661409854888916 seconds | MAE: 0.069 ------------------------------
# Execute Training and Walk Forward Testing for (BAE Systems PLC) for 60 times..
# ------------------------------ 113.93398857116699 seconds | MAE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (EDF Energy Nuclear Generation Group Ltd) for 8 times..
# ------------------------------ 4.971901893615723 seconds | MAE: 0.084 ------------------------------
# Execute Training and Walk Forward Testing for (Sage Group PLC) for 60 times..
# ------------------------------ 114.77658772468567 seconds | MAE: 0.049 ------------------------------
# Execute Training and Walk Forward Testing for (Capita PLC) for 39 times..
# ------------------------------ 48.95427894592285 seconds | MAE: 0.103 ------------------------------
# Execute Training and Walk Forward Testing for (Antofagasta PLC) for 60 times..
# ------------------------------ 114.38860201835632 seconds | MAE: 0.063 ------------------------------
# Execute Training and Walk Forward Testing for (ITV PLC) for 46 times..
# ------------------------------ 70.23486614227295 seconds | MAE: 0.184 ------------------------------
# Execute Training and Walk Forward Testing for (WM Morrison Supermarkets Ltd) for 52 times..
# ------------------------------ 81.82621765136719 seconds | MAE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (Sky Ltd) for 45 times..
# ------------------------------ 65.11528396606445 seconds | MAE: 0.070 ------------------------------
# Execute Training and Walk Forward Testing for (Vodafone Group PLC) for 60 times..
# ------------------------------ 117.92068314552307 seconds | MAE: 0.075 ------------------------------
# Execute Training and Walk Forward Testing for (Severn Trent PLC) for 60 times..
# ------------------------------ 113.40894532203674 seconds | MAE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Thomson Reuters UK Ltd) for 12 times..
# ------------------------------ 8.195422410964966 seconds | MAE: 0.176 ------------------------------
# Execute Training and Walk Forward Testing for (Anglo American PLC) for 60 times..
# ------------------------------ 112.02756857872009 seconds | MAE: 0.072 ------------------------------
# Execute Training and Walk Forward Testing for (Abi Sab Group Holding Ltd) for 38 times..
# ------------------------------ 47.206172704696655 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Carnival PLC) for 51 times..
# ------------------------------ 78.95616459846497 seconds | MAE: 0.200 ------------------------------
# Execute Training and Walk Forward Testing for (Kingfisher PLC) for 59 times..
# ------------------------------ 113.4326536655426 seconds | MAE: 0.097 ------------------------------
# Execute Training and Walk Forward Testing for (3i Group PLC) for 49 times..
# ------------------------------ 76.76394391059875 seconds | MAE: 0.076 ------------------------------
# Execute Training and Walk Forward Testing for (GSK plc) for 60 times..
# ------------------------------ 117.32685947418213 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Next PLC) for 60 times..
# ------------------------------ 118.96383166313171 seconds | MAE: 0.120 ------------------------------
# Execute Training and Walk Forward Testing for (HBOS Plc) for 10 times..
# ------------------------------ 6.387632369995117 seconds | MAE: 2.128 ------------------------------
# Execute Training and Walk Forward Testing for (BT Group PLC) for 60 times..
# ------------------------------ 121.40053701400757 seconds | MAE: 0.043 ------------------------------
# Execute Training and Walk Forward Testing for (Compass Group PLC) for 60 times..
# ------------------------------ 117.79232907295227 seconds | MAE: 0.107 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance & Leicester Ltd) for 8 times..
# ------------------------------ 4.995395183563232 seconds | MAE: 0.089 ------------------------------
# Execute Training and Walk Forward Testing for (Tesco PLC) for 60 times..
# ------------------------------ 109.24846911430359 seconds | MAE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (RSA Insurance Group Ltd) for 54 times..
# ------------------------------ 92.12185907363892 seconds | MAE: 0.068 ------------------------------
# Execute Training and Walk Forward Testing for (Standard Chartered PLC) for 60 times..
# ------------------------------ 115.55996513366699 seconds | MAE: 0.043 ------------------------------
# Execute Training and Walk Forward Testing for (Smith & Nephew PLC) for 60 times..
# ------------------------------ 109.36712789535522 seconds | MAE: 0.045 ------------------------------
# Execute Training and Walk Forward Testing for (Smiths Group PLC) for 59 times..
# ------------------------------ 110.03726077079773 seconds | MAE: 0.066 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish & Newcastle Ltd) for 7 times..
# ------------------------------ 4.4826250076293945 seconds | MAE: 0.073 ------------------------------
# Execute Training and Walk Forward Testing for (Schroders PLC) for 58 times..
# ------------------------------ 109.13238835334778 seconds | MAE: 0.247 ------------------------------
# Execute Training and Walk Forward Testing for (J Sainsbury PLC) for 60 times..
# ------------------------------ 114.57245326042175 seconds | MAE: 0.056 ------------------------------
# Execute Training and Walk Forward Testing for (Hammerson PLC) for 43 times..
# ------------------------------ 58.585843563079834 seconds | MAE: 0.248 ------------------------------
# Execute Training and Walk Forward Testing for (Marks and Spencer Group PLC) for 48 times..
# ------------------------------ 64.00822019577026 seconds | MAE: 0.160 ------------------------------
# Execute Training and Walk Forward Testing for (Legal & General Group PLC) for 60 times..
# ------------------------------ 112.51364994049072 seconds | MAE: 0.135 ------------------------------
# Execute Training and Walk Forward Testing for (Land Securities Group PLC) for 60 times..
# ------------------------------ 107.1037278175354 seconds | MAE: 0.039 ------------------------------
# Execute Training and Walk Forward Testing for (British Airways PLC) for 17 times..
# ------------------------------ 13.123690128326416 seconds | MAE: 0.039 ------------------------------
# Execute Training and Walk Forward Testing for (BG Group Ltd) for 35 times..
# ------------------------------ 41.45257759094238 seconds | MAE: 0.112 ------------------------------
# Execute Training and Walk Forward Testing for (Associated British Foods PLC) for 60 times..
# ------------------------------ 122.15855407714844 seconds | MAE: 0.041 ------------------------------
# Execute Training and Walk Forward Testing for (British Land Company PLC) for 60 times..
# ------------------------------ 113.95633816719055 seconds | MAE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (BHP Group (UK) Ltd) for 57 times..
# ------------------------------ 97.25584673881531 seconds | MAE: 0.069 ------------------------------
# Execute Training and Walk Forward Testing for (Pearson PLC) for 60 times..
# ------------------------------ 119.69741296768188 seconds | MAE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (Diageo PLC) for 60 times..
# ------------------------------ 114.40780520439148 seconds | MAE: 0.052 ------------------------------
# Execute Training and Walk Forward Testing for (Johnson Matthey PLC) for 56 times..
# ------------------------------ 99.59797167778015 seconds | MAE: 0.056 ------------------------------
# Execute Training and Walk Forward Testing for (Rio Tinto PLC) for 60 times..
# ------------------------------ 113.136225938797 seconds | MAE: 0.059 ------------------------------
# Execute Training and Walk Forward Testing for (British American Tobacco PLC) for 60 times..
# ------------------------------ 114.46303248405457 seconds | MAE: 0.059 ------------------------------
# Execute Training and Walk Forward Testing for (Unilever PLC) for 60 times..
# ------------------------------ 114.35296273231506 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Relx PLC) for 60 times..
# ------------------------------ 118.85762763023376 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (InterContinental Hotels Group PLC) for 60 times..
# ------------------------------ 104.69150114059448 seconds | MAE: 0.086 ------------------------------
# Execute Training and Walk Forward Testing for (Tate & Lyle PLC) for 17 times..
# ------------------------------ 12.949183702468872 seconds | MAE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (Cadbury Ltd) for 14 times..
# ------------------------------ 10.28106141090393 seconds | MAE: 0.175 ------------------------------
# Execute Training and Walk Forward Testing for (Reckitt Benckiser Group PLC) for 60 times..
# ------------------------------ 119.90697503089905 seconds | MAE: 0.022 ------------------------------
# Execute Training and Walk Forward Testing for (Rexam Ltd) for 31 times..
# ------------------------------ 33.7701153755188 seconds | MAE: 0.021 ------------------------------
# Execute Training and Walk Forward Testing for (BP PLC) for 60 times..
# ------------------------------ 108.4816746711731 seconds | MAE: 0.103 ------------------------------
# Execute Training and Walk Forward Testing for (Centrica PLC) for 53 times..
# ------------------------------ 89.63684797286987 seconds | MAE: 0.144 ------------------------------
# Execute Training and Walk Forward Testing for (Shire Ltd) for 45 times..
# ------------------------------ 65.86954402923584 seconds | MAE: 0.216 ------------------------------
# Execute Training and Walk Forward Testing for (Imperial Brands PLC) for 60 times..
# ------------------------------ 111.80884528160095 seconds | MAE: 0.028 ------------------------------
# Execute Training and Walk Forward Testing for (Ei Group Ltd) for 9 times..
# ------------------------------ 5.605376482009888 seconds | MAE: 0.045 ------------------------------
# Execute Training and Walk Forward Testing for (Rentokil Initial PLC) for 25 times..
# ------------------------------ 24.00693368911743 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (National Grid PLC) for 60 times..
# ------------------------------ 117.18582201004028 seconds | MAE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Home Retail Group Ltd) for 13 times..
# ------------------------------ 9.123367071151733 seconds | MAE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (AstraZeneca PLC) for 60 times..
# ------------------------------ 108.12588691711426 seconds | MAE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Intu Properties PLC) for 35 times..
# ------------------------------ 37.71297478675842 seconds | MAE: 0.036 ------------------------------
# Execute Training and Walk Forward Testing for (SSE PLC) for 60 times..
# ------------------------------ 120.29413294792175 seconds | MAE: 0.074 ------------------------------
# Execute Training and Walk Forward Testing for (International Power Ltd) for 22 times..
# ------------------------------ 18.11122441291809 seconds | MAE: 0.102 ------------------------------
# Execute Training and Walk Forward Testing for (Capricorn Energy PLC) for 18 times..
# ------------------------------ 14.597209692001343 seconds | MAE: 0.142 ------------------------------
# Execute Training and Walk Forward Testing for (Persimmon PLC) for 42 times..
# ------------------------------ 58.68210506439209 seconds | MAE: 0.134 ------------------------------
# Execute Training and Walk Forward Testing for (Shell PLC) for 60 times..
# ------------------------------ 111.23298573493958 seconds | MAE: 0.097 ------------------------------

# %% [markdown]
# # Results

# %%
mresults_m3.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                         Name Model  Test Size     MSE^3
# 65   5000683618                   Currys PLC    RF         11  3.376438
# 101  4295895499                     HBOS Plc    RF          9  2.292086
# 31   4295894092           Travis Perkins PLC    RF         11  1.660446
# 54   4295896428            Autonomy Corp Ltd    RF          9  1.570479
# 38   5036206981  Polymetal International PLC    RF         13  1.069694
# ..          ...                          ...   ...        ...       ...
# 47   4295894819                  Aggreko Ltd    RF         18  0.011693
# 63   4295894471      Amec Foster Wheeler Ltd    RF         21  0.010681
# 64   4295893850                      G4S Ltd    RF         30  0.009397
# 20   4295874865                      DCC PLC    RF         24  0.008813
# 59   4295895691           Alliance Trust PLC    RF          9  0.003251
#
# [144 rows x 5 columns]

# %%
mresults_m3.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                         Name Model  Test Size     MSE^3
# 70   5000683618                   Currys PLC    RF         12  3.093467
# 112  4295895499                     HBOS Plc    RF         10  2.146841
# 59   4295896428            Autonomy Corp Ltd    RF         10  1.218058
# 35   4295894092           Travis Perkins PLC    RF         12  1.132370
# 42   5036206981  Polymetal International PLC    RF         14  1.030174
# ..          ...                          ...   ...        ...       ...
# 55   4295898751              Serco Group PLC    RF         16  0.012833
# 51   4295894819                  Aggreko Ltd    RF         19  0.010403
# 68   4295894471      Amec Foster Wheeler Ltd    RF         22  0.009548
# 47   4295894784                      IMI PLC    RF         14  0.006152
# 64   4295895691           Alliance Trust PLC    RF         10  0.005796
#
# [160 rows x 5 columns]

# %%
mresults_m2.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                         Name Model  Test Size     MSE^3
# 70   5000683618                   Currys PLC    RF         12  3.142663
# 112  4295895499                     HBOS Plc    RF         10  2.128162
# 59   4295896428            Autonomy Corp Ltd    RF         10  1.237753
# 35   4295894092           Travis Perkins PLC    RF         12  1.047205
# 42   5036206981  Polymetal International PLC    RF         14  1.027622
# ..          ...                          ...   ...        ...       ...
# 68   4295894471      Amec Foster Wheeler Ltd    RF         22  0.011986
# 48   4295895858               Weir Group PLC    RF         19  0.010993
# 51   4295894819                  Aggreko Ltd    RF         19  0.010586
# 64   4295895691           Alliance Trust PLC    RF         10  0.006822
# 47   4295894784                      IMI PLC    RF         14  0.006451
#
# [160 rows x 5 columns]

# %% [markdown]
# ## Exporting the Results

# %%
np.mean(mresults_m3['MSE^3'])
# Out:
# 0.14950075507514893

# %%
np.mean(mresults_m3['MSE^3'])
# Out:
# 0.13529247091706614

# %%
np.mean(mresults_m2['MSE^3'])
# Out:
# 0.13798890987628293

# %%
MODEL = 'RF'
THRESHOLD = str(24)
CAP = 'm3'
mresults_m3.to_excel(f'../results/1-{MODEL}-{THRESHOLD}MONTH-{CAP}.xlsx', index=None)

# %%
MODEL = 'RF'
THRESHOLD = str(24)
CAP = 'm2'
mresults_m2.to_excel(f'../results/1-{MODEL}-{THRESHOLD}MONTH-{CAP}.xlsx', index=None)

# %% [markdown]
# ---

# %% [markdown]
# # VIZ

# %%
def compile_train_test(train_df, test_df, sample = True, algo = 'HAR', dataset = 'm1', viz = False, cap = True):
    '''
    '''
    test_perc = .3 

    if dataset == 'm1':
        cols = ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
        
    elif dataset == 'm2':
        cols = vif_check()

    else:
        cols = [ 'buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar'
                ,'CSRStrategy','Community','Emissions','EnvironmentalInnovation','HumanRights','Management','ProductResponsibility'
                ,'ResourceUse','Shareholders','Workforce', 'vol_series_daily','vol_series_weekly','vol_series_monthly', 'V^YZ']
                
        # version 2
        cols = ['buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar','Community',
                'EnvironmentalInnovation','Management','ProductResponsibility','Shareholders','Workforce', 'V^YZ']


    mresults = pd.DataFrame()
    predictions_df = pd.DataFrame()

    if sample:
        # assets = [4295894970, 8589934212]
        assets = [8589934212, 8589934254] # 3rd and 4th most volatile stocks in FTSE 2006 to 2022

    else:
        assets = train_df.Asset.unique().tolist()

    for r, asset in enumerate(assets): 
        # print(asset)
        name = train_df[train_df['Asset'] == asset].iloc[0,-1]

        df_train = train_df[train_df.Asset == asset][cols].dropna()
        df_test = test_df[test_df.Asset == asset][cols].dropna()
        indices = test_df[test_df.Asset == asset].index
        # print(asset, df_train.shape, df_test.shape)
        df_merge = pd.concat([df_train, df_test])
        df_merge = series_to_supervised(df_merge, n_in=3, target= ['V^YZ'])
        test_size = int(df_merge.shape[0] * test_perc)
        
        print(f'Execute Training and Walk Forward Testing for ({name}) for {test_size} times..')
        start_time = time.time()
        mse, y, yhat = walk_forward_validation(df_merge, test_size)
        print("---"*10, "%s seconds |"%(time.time() - start_time), 'MAE: %.3f'%mse, "---"*10)
        
        mresult = pd.DataFrame({
            'Asset': asset,
            'Name': name,
            'Model': algo,
            'Test Size': test_size,
            'MSE^3':mse
                    }
            , index=[r]
        )
        
        prediction_df = pd.DataFrame({
            'Asset':asset,
            'Test Data': y,
            'Predictions': yhat
        }, index = indices[-len(yhat):])
        
        mresults = pd.concat([mresults, mresult])
        predictions_df = pd.concat([predictions_df, prediction_df])

        if viz: 
            vis_line_plot_results(yhat, y, model = algo, dataset=dataset, name=name, r = r)

    return mresults, predictions_df

# %%
mresults_m3, pred = compile_train_test(train_df, test_df, sample=True, algo='RF', dataset='m3', viz=False, cap = True)
# Out:
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 60 times..
# ------------------------------ 128.08844995498657 seconds | MAE: 0.099 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 60 times..
# ------------------------------ 135.58832836151123 seconds | MAE: 0.102 ------------------------------

# %%
pred.to_csv('../data/9-RF-SAMPLE-PREDICTION-RESULTS.csv')
