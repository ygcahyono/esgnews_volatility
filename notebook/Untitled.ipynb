# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import sys, os
sys.path.append('../python')
from util import *
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 100)

# %%
DProcess = Data_Processing('2006-01-01', '2022-12-01')

df_clean, train_df, valid_df, test_df = DProcess.cleansing_final1(fillna = True)

# %%
run_algorithms = Run_Algorithms(train_df, test_df, algorithms='HAR', sample= False, features='m2')

mresults = run_algorithms.compile_train_test()

# %%
mresults.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                          Name Model Features  Test Size  \
# 56   4295897144           John Wood Group PLC   HAR       M2          8
# 7    4295894930  Spirax-Sarco Engineering PLC   HAR       M2         14
# 65   5000683618                    Currys PLC   HAR       M2         12
# 58   4295894904                    Cobham Ltd   HAR       M2          9
# 101  4295895499                      HBOS Plc   HAR       M2         10
# ..          ...                           ...   ...      ...        ...
# 20   4295874865                       DCC PLC   HAR       M2         25
# 10   4295899077                 Rightmove PLC   HAR       M2         16
# 136  4295894497          Rentokil Initial PLC   HAR       M2         25
# 43   4295894784                       IMI PLC   HAR       M2         14
# 50   4295898751               Serco Group PLC   HAR       M2         16
#
#          MSE^3
# 56   23.351436
# 7     4.931732
# 65    4.499321
# 58    3.766352
# 101   3.648292
# ...

# %%
import numpy as np

# %%
np.mean(mresults['MSE^3'])
# Out:
# 0.5170461028594866

# %%
run_algorithms = Run_Algorithms(train_df, test_df, algorithms='HAR', sample= False, features='m3')

mresults = run_algorithms.compile_train_test()

# %%
mresults.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                             Name Model Features  Test Size  \
# 5    4295894669            JD Sports Fashion PLC   HAR       M3         12
# 56   4295897144              John Wood Group PLC   HAR       M3          8
# 101  4295895499                         HBOS Plc   HAR       M3         10
# 58   4295894904                       Cobham Ltd   HAR       M3          9
# 65   5000683618                       Currys PLC   HAR       M3         12
# ..          ...                              ...   ...      ...        ...
# 24   4295869210                           TUI AG   HAR       M3         17
# 129  4295894756      Reckitt Benckiser Group PLC   HAR       M3         60
# 99   4295895781                          GSK plc   HAR       M3         60
# 25   4298449570  Direct Line Insurance Group PLC   HAR       M3         17
# 50   4295898751                  Serco Group PLC   HAR       M3         16
#
#          MSE^3
# 5    13.043086
# 56   12.361643
# 101   8.127406
# ...

# %%
np.mean(mresults['MSE^3'])
# Out:
# 0.7784622504039624

# %% [markdown]
# ---

# %%
run_algorithms = Run_Algorithms(train_df, test_df, algorithms='GARCH', sample= False, features='m1')

mresults = run_algorithms.compile_train_test()
# Out:
# /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# ...

# %%
np.mean(mresults['MSE^3'])
# Out:
# 3934.5152731160906

# %% [markdown]
# ---

# %%
run_algorithms = Run_Algorithms(train_df, test_df, algorithms='EN', sample= False, features='m1')

mresults = run_algorithms.compile_train_test()
# Out:
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 3 times..
# ------------------------------ 0.004965066909790039 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 3 times..
# ------------------------------ 0.0006880760192871094 seconds | MAE: 0.899 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 5 times..
# ------------------------------ 0.0009491443634033203 seconds | MAE: 0.011 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 6 times..
# ------------------------------ 0.0010631084442138672 seconds | MAE: 0.009 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 8 times..
# ------------------------------ 0.0013568401336669922 seconds | MAE: 0.339 ------------------------------
# ...

# %%
np.mean(mresults['MSE^3'])
# Out:
# 0.2206788192810873

# %% [markdown]
# ---

# %%
run_algorithms = Run_Algorithms(train_df, test_df, algorithms='EN', sample= False, features='m2')

mresults = run_algorithms.compile_train_test()
# Out:
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 7 times..
# ------------------------------ 0.0022552013397216797 seconds | MAE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 6 times..
# ------------------------------ 0.0010669231414794922 seconds | MAE: 0.436 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 8 times..
# ------------------------------ 0.0013387203216552734 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 10 times..
# ------------------------------ 0.0025072097778320312 seconds | MAE: 0.113 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 11 times..
# ------------------------------ 0.002691030502319336 seconds | MAE: 0.390 ------------------------------
# ...

# %%
np.mean(mresults['MSE^3'])
# Out:
# 0.188549875778676

# %% [markdown]
# ---

# %%
run_algorithms = Run_Algorithms(train_df, test_df, algorithms='EN', sample= False, features='m3')

mresults = run_algorithms.compile_train_test()
# Out:
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 7 times..
# ------------------------------ 0.006721973419189453 seconds | MAE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 6 times..
# ------------------------------ 0.0011110305786132812 seconds | MAE: 0.436 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 8 times..
# ------------------------------ 0.0013518333435058594 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 10 times..
# ------------------------------ 0.0034487247467041016 seconds | MAE: 0.113 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 11 times..
# ------------------------------ 0.003773927688598633 seconds | MAE: 0.390 ------------------------------
# ...

# %%
np.mean(mresults['MSE^3'])
# Out:
# 0.1885493550756858

# %% [markdown]
# ---

# %%
run_algorithms = Run_Algorithms(train_df, test_df, algorithms='RF', sample= True, features='m1', outputs=True)

mresults = run_algorithms.compile_train_test()
# Out:
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 56 times..
# ------------------------------ 41.156293869018555 seconds | MAE: 0.077 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 56 times..
# ------------------------------ 41.75848603248596 seconds | MAE: 0.143 ------------------------------

# %%
np.mean(mresults['MSE^3'])
# Out:
# 0.1885493550756858
