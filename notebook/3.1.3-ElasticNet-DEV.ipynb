# %% [markdown]
# # Import Packages

# %%
# Method #3 Regularisation Model
from sklearn.linear_model import ElasticNet

from numpy import asarray
from IPython.display import display, HTML
from set_params import func_train_test_split, count_train_test, series_to_supervised, train_test_split, vif_check
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random as rd
import time
import warnings

def calculate_iqr(values):
    # Calculate Q1
    Q1 = np.percentile(values, 25)
    # Calculate Q3
    Q3 = np.percentile(values, 75)
    # Calculate IQR
    IQR = Q3 - Q1
    return IQR

def detect_outliers_iqr(values):
    # Calculate the IQR of the values
    IQR = calculate_iqr(values)
    # Calculate Q1 and Q3
    Q1 = np.percentile(values, 25)
    Q3 = np.percentile(values, 75)
    # Define the lower and upper bound for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    # Return a boolean array: True if the value is an outlier, False otherwise
    return lower_bound, upper_bound

def vis_line_plot_results(y_pred, y_test, model = 'HAR', name = 'BARCLAYS', r = 1, dataset = 'm1'):

    plt.figure(figsize=(10,4))
    true, = plt.plot(y_test)
    preds, = plt.plot(y_pred)
    plt.title(f'{model}-{dataset}-{name}', fontsize=15)
    plt.legend(['True Volatility', 'Predicted Volatility'], fontsize=9)
    plt.xticks(rotation=45)
    plt.savefig(f'../outputs/{model}-{dataset}/{str(r+1).zfill(3)}-{model}-{name}.png')
    plt.close()

# display(HTML("<style>.container { width:80% !important; }</style>"))
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100)

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Import Data and Split Train - Test

# %%
base_FTSE_df = pd.read_csv('../data/1.3-FTSE_Monthly_ESG_Volatility_Final_v2.csv')
base_FTSE_df = base_FTSE_df.rename(columns={'Date_x':'date_key'})

# %%
train_df, valid_df, test_df = func_train_test_split(validation = False, threshold = 24)

# %%
count_rows_df = count_train_test(train_df, test_df)

# %%
coverage_df = pd.read_csv('../data/coverage_dataframe.csv')
coverage_df.PermID = coverage_df.PermID.astype(int)
coverage_df = coverage_df[['PermID', 'Name']]
coverage_df = coverage_df.rename(columns={'PermID':'Asset'})

# %%
train_df = pd.merge(train_df, coverage_df, how = 'left', on = 'Asset')
train_df.index = train_df.month_key

# %%
# fit an random forest model and make a one step prediction
def elasticnet_forecast(train, testX, l1_ratio = 0.25):
    # transform list into array
    train = asarray(train)
    # split into input and output columns
    trainX, trainy = train[:, :-1], train[:, -1]
    # fit model
    model = ElasticNet(l1_ratio= l1_ratio)
    model.fit(trainX, trainy)
    # make a one-step prediction
    yhat = model.predict([testX])
    return yhat[0]

# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, verbose = True):
    predictions = list()
    # split dataset
    train, test = train_test_split(data, n_test)
    # seed history with training dataset
    history = [x for x in train]
    # print(history)
    # step over each time-step in the test set
    
    for i in range(len(test)):
        # split test row into input and output columns
        testX, testy = test[i, :-1], test[i, -1]
        # fit model on history and make a prediction
        yhat = elasticnet_forecast(history, testX)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for the next loop
        history.append(test[i])
        # summarize progress
        # print('>expected=%.4f, predicted=%.4f' % (testy, yhat))
        
    # estimate prediction error
    error = mean_squared_error(test[:, -1], predictions) * 10**3
    # error = mean_absolute_error(test[:, -1], predictions)
    
    return error, test[:, -1], predictions

# %%
def compile_train_test(train_df, test_df, sample = True, algo = 'HAR', dataset = 'm1', viz = False, cap = True):
    '''
    '''
    test_perc = .3 

    if dataset == 'm1':
        cols = ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
        
    elif dataset == 'm2':
        cols = vif_check()

    else:
        cols = [ 'buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar'
                ,'CSRStrategy','Community','Emissions','EnvironmentalInnovation','HumanRights','Management','ProductResponsibility'
                ,'ResourceUse','Shareholders','Workforce', 'vol_series_daily','vol_series_weekly','vol_series_monthly', 'V^YZ']
        
        # version 2
        cols = ['buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar','Community',
                'EnvironmentalInnovation','Management','ProductResponsibility','Shareholders','Workforce', 
                'vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']

    mresults = pd.DataFrame()

    if sample:
        assets = [4295894970, 8589934212]
    else:
        assets = train_df.Asset.unique().tolist()

    for r, asset in enumerate(assets): 
        # print(asset)
        name = train_df[train_df['Asset'] == asset].iloc[0,-1]

        df_train = train_df[train_df.Asset == asset][cols].dropna()
        df_test = test_df[test_df.Asset == asset][cols].dropna()
        indices = test_df[test_df.Asset == asset].index
        # display(df_train)
        df_merge = pd.concat([df_train, df_test])
        df_merge = series_to_supervised(df_merge, n_in=3, target= ['V^YZ'])
        test_size = int(df_merge.shape[0] * test_perc)
        
        print(f'Execute Training and Walk Forward Testing for ({name}) for {test_size} times..')
        start_time = time.time()
        mse, y, yhat = walk_forward_validation(df_merge, test_size)
        print("---"*10, "%s seconds |"%(time.time() - start_time), 'MAE: %.3f'%mse, "---"*10)
        
        mresult = pd.DataFrame({
            'Asset': asset,
            'Name': name,
            'Model': algo,
            'Test Size': test_size,
            'MSE^3':mse
                    }
            , index=[r]
        )
        mresults = pd.concat([mresults, mresult])

        if viz: 
            vis_line_plot_results(yhat, y, model = algo, dataset=dataset, name=name, r = r)

    return mresults

# %%
mresults_m1 = compile_train_test(train_df, test_df, sample=False, algo='EN', dataset='m1', viz=False, cap = True)
# Out:
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 3 times..
# ------------------------------ 0.001550912857055664 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 3 times..
# ------------------------------ 0.0011260509490966797 seconds | MAE: 0.899 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 5 times..
# ------------------------------ 0.0016698837280273438 seconds | MAE: 0.011 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 6 times..
# ------------------------------ 0.0019681453704833984 seconds | MAE: 0.009 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 8 times..
# ------------------------------ 0.0024073123931884766 seconds | MAE: 0.339 ------------------------------
# Execute Training and Walk Forward Testing for (JD Sports Fashion PLC) for 8 times..
# ------------------------------ 0.002559661865234375 seconds | MAE: 0.099 ------------------------------
# Execute Training and Walk Forward Testing for (Phoenix Group Holdings PLC) for 9 times..
# ------------------------------ 0.0027620792388916016 seconds | MAE: 0.009 ------------------------------
# Execute Training and Walk Forward Testing for (Spirax-Sarco Engineering PLC) for 9 times..
# ------------------------------ 0.002778768539428711 seconds | MAE: 0.009 ------------------------------
# Execute Training and Walk Forward Testing for (Entain PLC) for 6 times..
# ------------------------------ 0.001867532730102539 seconds | MAE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Ocado Group PLC) for 11 times..
# ------------------------------ 0.0030727386474609375 seconds | MAE: 0.179 ------------------------------
# Execute Training and Walk Forward Testing for (Rightmove PLC) for 11 times..
# ------------------------------ 0.0030541419982910156 seconds | MAE: 0.018 ------------------------------
# Execute Training and Walk Forward Testing for (Halma PLC) for 13 times..
# ------------------------------ 0.0035114288330078125 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (DS Smith PLC) for 13 times..
# ------------------------------ 0.004068613052368164 seconds | MAE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (NMC Health PLC) for 3 times..
# ------------------------------ 0.0009777545928955078 seconds | MAE: 1.607 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish Mortgage Investment Trust PLC) for 16 times..
# ------------------------------ 0.004675626754760742 seconds | MAE: 0.056 ------------------------------
# Execute Training and Walk Forward Testing for (Smurfit Kappa Group PLC) for 17 times..
# ------------------------------ 0.004637956619262695 seconds | MAE: 0.028 ------------------------------
# Execute Training and Walk Forward Testing for (Micro Focus International Ltd) for 6 times..
# ------------------------------ 0.0017554759979248047 seconds | MAE: 0.234 ------------------------------
# Execute Training and Walk Forward Testing for (Informa PLC) for 19 times..
# ------------------------------ 0.006095170974731445 seconds | MAE: 0.021 ------------------------------
# Execute Training and Walk Forward Testing for (Mediclinic Group Ltd) for 3 times..
# ------------------------------ 0.0010724067687988281 seconds | MAE: 0.003 ------------------------------
# Execute Training and Walk Forward Testing for (Flutter Entertainment PLC) for 19 times..
# ------------------------------ 0.0053234100341796875 seconds | MAE: 0.031 ------------------------------
# Execute Training and Walk Forward Testing for (DCC PLC) for 20 times..
# ------------------------------ 0.006285190582275391 seconds | MAE: 0.008 ------------------------------
# Execute Training and Walk Forward Testing for (Berkeley Group Holdings PLC) for 17 times..
# ------------------------------ 0.004900932312011719 seconds | MAE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (Merlin Entertainments Ltd) for 4 times..
# ------------------------------ 0.0015480518341064453 seconds | MAE: 0.303 ------------------------------
# Execute Training and Walk Forward Testing for (Hikma Pharmaceuticals PLC) for 14 times..
# ------------------------------ 0.005938053131103516 seconds | MAE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (TUI AG) for 12 times..
# ------------------------------ 0.0037038326263427734 seconds | MAE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (Direct Line Insurance Group PLC) for 13 times..
# ------------------------------ 0.004090309143066406 seconds | MAE: 0.012 ------------------------------
# Execute Training and Walk Forward Testing for (International Distributions Services PLC) for 14 times..
# ------------------------------ 0.0053713321685791016 seconds | MAE: 0.096 ------------------------------
# Execute Training and Walk Forward Testing for (Ashtead Group PLC) for 27 times..
# ------------------------------ 0.007760763168334961 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Coca Cola HBC AG) for 28 times..
# ------------------------------ 0.00784754753112793 seconds | MAE: 0.040 ------------------------------
# Execute Training and Walk Forward Testing for (Frasers Group PLC) for 5 times..
# ------------------------------ 0.0015194416046142578 seconds | MAE: 0.132 ------------------------------
# Execute Training and Walk Forward Testing for (Mondi PLC) for 28 times..
# ------------------------------ 0.008053064346313477 seconds | MAE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (Travis Perkins PLC) for 7 times..
# ------------------------------ 0.0022344589233398438 seconds | MAE: 2.112 ------------------------------
# Execute Training and Walk Forward Testing for (Easyjet PLC) for 19 times..
# ------------------------------ 0.005493640899658203 seconds | MAE: 0.550 ------------------------------
# Execute Training and Walk Forward Testing for (Melrose Industries PLC) for 18 times..
# ------------------------------ 0.004914760589599609 seconds | MAE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Babcock International Group PLC) for 15 times..
# ------------------------------ 0.0043773651123046875 seconds | MAE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (Croda International PLC) for 23 times..
# ------------------------------ 0.006285190582275391 seconds | MAE: 0.021 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn Holdings Ltd) for 9 times..
# ------------------------------ 0.0024919509887695312 seconds | MAE: 0.057 ------------------------------
# Execute Training and Walk Forward Testing for (EVRAZ plc) for 15 times..
# ------------------------------ 0.004138469696044922 seconds | MAE: 0.452 ------------------------------
# Execute Training and Walk Forward Testing for (Polymetal International PLC) for 9 times..
# ------------------------------ 0.003317117691040039 seconds | MAE: 1.517 ------------------------------
# Execute Training and Walk Forward Testing for (Meggitt Ltd) for 15 times..
# ------------------------------ 0.004240989685058594 seconds | MAE: 0.587 ------------------------------
# Execute Training and Walk Forward Testing for (Glencore PLC) for 37 times..
# ------------------------------ 0.010183334350585938 seconds | MAE: 0.117 ------------------------------
# Execute Training and Walk Forward Testing for (Hargreaves Lansdown PLC) for 37 times..
# ------------------------------ 0.01223611831665039 seconds | MAE: 0.167 ------------------------------
# Execute Training and Walk Forward Testing for (International Consolidated Airlines Group SA) for 38 times..
# ------------------------------ 0.011222362518310547 seconds | MAE: 0.453 ------------------------------
# Execute Training and Walk Forward Testing for (IMI PLC) for 9 times..
# ------------------------------ 0.0026884078979492188 seconds | MAE: 0.014 ------------------------------
# Execute Training and Walk Forward Testing for (Weir Group PLC) for 14 times..
# ------------------------------ 0.00407862663269043 seconds | MAE: 0.040 ------------------------------
# Execute Training and Walk Forward Testing for (GKN Ltd) for 22 times..
# ------------------------------ 0.006267070770263672 seconds | MAE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (SVF Holdco (UK) Ltd) for 18 times..
# ------------------------------ 0.005198478698730469 seconds | MAE: 0.265 ------------------------------
# Execute Training and Walk Forward Testing for (Aggreko Ltd) for 15 times..
# ------------------------------ 0.004302978515625 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Burberry Group PLC) for 43 times..
# ------------------------------ 0.012782812118530273 seconds | MAE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (Intertek Group PLC) for 44 times..
# ------------------------------ 0.012744665145874023 seconds | MAE: 0.107 ------------------------------
# Execute Training and Walk Forward Testing for (Serco Group PLC) for 12 times..
# ------------------------------ 0.003459453582763672 seconds | MAE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (Barrick Gold (Holdings) Ltd) for 31 times..
# ------------------------------ 0.008895397186279297 seconds | MAE: 0.065 ------------------------------
# Execute Training and Walk Forward Testing for (Fresnillo PLC) for 44 times..
# ------------------------------ 0.014650583267211914 seconds | MAE: 0.056 ------------------------------
# Execute Training and Walk Forward Testing for (Inmarsat Group Holdings Ltd) for 10 times..
# ------------------------------ 0.0028192996978759766 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (Autonomy Corp Ltd) for 6 times..
# ------------------------------ 0.0018906593322753906 seconds | MAE: 2.392 ------------------------------
# Execute Training and Walk Forward Testing for (Petrofac Ltd) for 17 times..
# ------------------------------ 0.0049054622650146484 seconds | MAE: 0.076 ------------------------------
# Execute Training and Walk Forward Testing for (John Wood Group PLC) for 3 times..
# ------------------------------ 0.001230478286743164 seconds | MAE: 0.074 ------------------------------
# Execute Training and Walk Forward Testing for (Bunzl plc) for 46 times..
# ------------------------------ 0.014762401580810547 seconds | MAE: 0.101 ------------------------------
# Execute Training and Walk Forward Testing for (Cobham Ltd) for 5 times..
# ------------------------------ 0.0015869140625 seconds | MAE: 0.010 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance Trust PLC) for 6 times..
# ------------------------------ 0.0019335746765136719 seconds | MAE: 0.004 ------------------------------
# Execute Training and Walk Forward Testing for (London Stock Exchange Group PLC) for 38 times..
# ------------------------------ 0.010897159576416016 seconds | MAE: 0.078 ------------------------------
# Execute Training and Walk Forward Testing for (Admiral Group PLC) for 49 times..
# ------------------------------ 0.015118837356567383 seconds | MAE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (Tui Travel Ltd) for 14 times..
# ------------------------------ 0.0038056373596191406 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Amec Foster Wheeler Ltd) for 17 times..
# ------------------------------ 0.004853248596191406 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (G4S Ltd) for 27 times..
# ------------------------------ 0.008596658706665039 seconds | MAE: 0.007 ------------------------------
# Execute Training and Walk Forward Testing for (Currys PLC) for 7 times..
# ------------------------------ 0.0028302669525146484 seconds | MAE: 3.131 ------------------------------
# Execute Training and Walk Forward Testing for (Tullow Oil PLC) for 22 times..
# ------------------------------ 0.006155729293823242 seconds | MAE: 0.068 ------------------------------
# Execute Training and Walk Forward Testing for (Taylor Wimpey PLC) for 25 times..
# ------------------------------ 0.007010698318481445 seconds | MAE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (Barratt Developments P L C) for 27 times..
# ------------------------------ 0.007650136947631836 seconds | MAE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Whitbread PLC) for 51 times..
# ------------------------------ 0.01666712760925293 seconds | MAE: 0.173 ------------------------------
# Execute Training and Walk Forward Testing for (Experian PLC) for 53 times..
# ------------------------------ 0.016376256942749023 seconds | MAE: 0.127 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn PLC) for 52 times..
# ------------------------------ 0.015876054763793945 seconds | MAE: 0.113 ------------------------------
# Execute Training and Walk Forward Testing for (SEGRO PLC) for 22 times..
# ------------------------------ 0.006244182586669922 seconds | MAE: 0.041 ------------------------------
# Execute Training and Walk Forward Testing for (NEX Group Ltd) for 17 times..
# ------------------------------ 0.004988908767700195 seconds | MAE: 0.102 ------------------------------
# Execute Training and Walk Forward Testing for (Sibanye Uk Ltd) for 13 times..
# ------------------------------ 0.003670215606689453 seconds | MAE: 0.199 ------------------------------
# Execute Training and Walk Forward Testing for (Aviva PLC) for 56 times..
# ------------------------------ 0.015981435775756836 seconds | MAE: 0.105 ------------------------------
# Execute Training and Walk Forward Testing for (Barclays PLC) for 56 times..
# ------------------------------ 0.016537189483642578 seconds | MAE: 0.236 ------------------------------
# Execute Training and Walk Forward Testing for (HSBC Holdings PLC) for 56 times..
# ------------------------------ 0.016288280487060547 seconds | MAE: 0.041 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 56 times..
# ------------------------------ 0.017525434494018555 seconds | MAE: 0.144 ------------------------------
# Execute Training and Walk Forward Testing for (Prudential PLC) for 56 times..
# ------------------------------ 0.0159456729888916 seconds | MAE: 0.164 ------------------------------
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 56 times..
# ------------------------------ 0.017154932022094727 seconds | MAE: 0.170 ------------------------------
# Execute Training and Walk Forward Testing for (Man Group PLC) for 18 times..
# ------------------------------ 0.005328655242919922 seconds | MAE: 0.140 ------------------------------
# Execute Training and Walk Forward Testing for (WPP PLC) for 56 times..
# ------------------------------ 0.02252650260925293 seconds | MAE: 0.090 ------------------------------
# Execute Training and Walk Forward Testing for (Rolls-Royce Holdings PLC) for 56 times..
# ------------------------------ 0.016425371170043945 seconds | MAE: 0.589 ------------------------------
# Execute Training and Walk Forward Testing for (United Utilities Group PLC) for 56 times..
# ------------------------------ 0.01578664779663086 seconds | MAE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (Xstrata Ltd) for 21 times..
# ------------------------------ 0.00565791130065918 seconds | MAE: 0.182 ------------------------------
# Execute Training and Walk Forward Testing for (BAE Systems PLC) for 56 times..
# ------------------------------ 0.015625476837158203 seconds | MAE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (EDF Energy Nuclear Generation Group Ltd) for 3 times..
# ------------------------------ 0.0009918212890625 seconds | MAE: 0.196 ------------------------------
# Execute Training and Walk Forward Testing for (Sage Group PLC) for 56 times..
# ------------------------------ 0.015657901763916016 seconds | MAE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (Antofagasta PLC) for 56 times..
# ------------------------------ 0.015627384185791016 seconds | MAE: 0.065 ------------------------------
# Execute Training and Walk Forward Testing for (ITV PLC) for 42 times..
# ------------------------------ 0.01140594482421875 seconds | MAE: 0.198 ------------------------------
# Execute Training and Walk Forward Testing for (WM Morrison Supermarkets Ltd) for 48 times..
# ------------------------------ 0.013219118118286133 seconds | MAE: 0.045 ------------------------------
# Execute Training and Walk Forward Testing for (Sky Ltd) for 41 times..
# ------------------------------ 0.013782739639282227 seconds | MAE: 0.093 ------------------------------
# Execute Training and Walk Forward Testing for (Vodafone Group PLC) for 56 times..
# ------------------------------ 0.018208742141723633 seconds | MAE: 0.063 ------------------------------
# Execute Training and Walk Forward Testing for (Severn Trent PLC) for 56 times..
# ------------------------------ 0.017706871032714844 seconds | MAE: 0.038 ------------------------------
# Execute Training and Walk Forward Testing for (Anglo American PLC) for 56 times..
# ------------------------------ 0.016870737075805664 seconds | MAE: 0.106 ------------------------------
# Execute Training and Walk Forward Testing for (Abi Sab Group Holding Ltd) for 33 times..
# ------------------------------ 0.00926518440246582 seconds | MAE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (Kingfisher PLC) for 55 times..
# ------------------------------ 0.016757726669311523 seconds | MAE: 0.088 ------------------------------
# Execute Training and Walk Forward Testing for (3i Group PLC) for 45 times..
# ------------------------------ 0.012835264205932617 seconds | MAE: 0.126 ------------------------------
# Execute Training and Walk Forward Testing for (GSK plc) for 56 times..
# ------------------------------ 0.01700878143310547 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Next PLC) for 56 times..
# ------------------------------ 0.01781916618347168 seconds | MAE: 0.137 ------------------------------
# Execute Training and Walk Forward Testing for (HBOS Plc) for 6 times..
# ------------------------------ 0.0018630027770996094 seconds | MAE: 6.076 ------------------------------
# Execute Training and Walk Forward Testing for (BT Group PLC) for 56 times..
# ------------------------------ 0.017291784286499023 seconds | MAE: 0.056 ------------------------------
# Execute Training and Walk Forward Testing for (Compass Group PLC) for 56 times..
# ------------------------------ 0.019155263900756836 seconds | MAE: 0.170 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance & Leicester Ltd) for 3 times..
# ------------------------------ 0.001165151596069336 seconds | MAE: 0.201 ------------------------------
# Execute Training and Walk Forward Testing for (Tesco PLC) for 56 times..
# ------------------------------ 0.017042875289916992 seconds | MAE: 0.041 ------------------------------
# Execute Training and Walk Forward Testing for (RSA Insurance Group Ltd) for 50 times..
# ------------------------------ 0.015567302703857422 seconds | MAE: 0.144 ------------------------------
# Execute Training and Walk Forward Testing for (Standard Chartered PLC) for 56 times..
# ------------------------------ 0.017789602279663086 seconds | MAE: 0.069 ------------------------------
# Execute Training and Walk Forward Testing for (Smith & Nephew PLC) for 56 times..
# ------------------------------ 0.01664447784423828 seconds | MAE: 0.066 ------------------------------
# Execute Training and Walk Forward Testing for (Smiths Group PLC) for 55 times..
# ------------------------------ 0.015837430953979492 seconds | MAE: 0.091 ------------------------------
# Execute Training and Walk Forward Testing for (Schroders PLC) for 54 times..
# ------------------------------ 0.01766490936279297 seconds | MAE: 0.151 ------------------------------
# Execute Training and Walk Forward Testing for (J Sainsbury PLC) for 56 times..
# ------------------------------ 0.01613330841064453 seconds | MAE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (Hammerson PLC) for 39 times..
# ------------------------------ 0.01076650619506836 seconds | MAE: 0.241 ------------------------------
# Execute Training and Walk Forward Testing for (Legal & General Group PLC) for 56 times..
# ------------------------------ 0.017968177795410156 seconds | MAE: 0.176 ------------------------------
# Execute Training and Walk Forward Testing for (British Airways PLC) for 13 times..
# ------------------------------ 0.003682374954223633 seconds | MAE: 0.169 ------------------------------
# Execute Training and Walk Forward Testing for (BG Group Ltd) for 31 times..
# ------------------------------ 0.008483648300170898 seconds | MAE: 0.119 ------------------------------
# Execute Training and Walk Forward Testing for (Associated British Foods PLC) for 56 times..
# ------------------------------ 0.016250133514404297 seconds | MAE: 0.064 ------------------------------
# Execute Training and Walk Forward Testing for (British Land Company PLC) for 56 times..
# ------------------------------ 0.016205310821533203 seconds | MAE: 0.082 ------------------------------
# Execute Training and Walk Forward Testing for (BHP Group (UK) Ltd) for 52 times..
# ------------------------------ 0.015059709548950195 seconds | MAE: 0.088 ------------------------------
# Execute Training and Walk Forward Testing for (Pearson PLC) for 56 times..
# ------------------------------ 0.016452789306640625 seconds | MAE: 0.083 ------------------------------
# Execute Training and Walk Forward Testing for (Diageo PLC) for 56 times..
# ------------------------------ 0.017743587493896484 seconds | MAE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Johnson Matthey PLC) for 52 times..
# ------------------------------ 0.016828536987304688 seconds | MAE: 0.069 ------------------------------
# Execute Training and Walk Forward Testing for (Rio Tinto PLC) for 56 times..
# ------------------------------ 0.01642894744873047 seconds | MAE: 0.083 ------------------------------
# Execute Training and Walk Forward Testing for (British American Tobacco PLC) for 56 times..
# ------------------------------ 0.01784038543701172 seconds | MAE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (Unilever PLC) for 56 times..
# ------------------------------ 0.016938447952270508 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Relx PLC) for 56 times..
# ------------------------------ 0.016605615615844727 seconds | MAE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (InterContinental Hotels Group PLC) for 56 times..
# ------------------------------ 0.01656818389892578 seconds | MAE: 0.180 ------------------------------
# Execute Training and Walk Forward Testing for (Tate & Lyle PLC) for 12 times..
# ------------------------------ 0.0035598278045654297 seconds | MAE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (Cadbury Ltd) for 9 times..
# ------------------------------ 0.002798318862915039 seconds | MAE: 0.204 ------------------------------
# Execute Training and Walk Forward Testing for (Reckitt Benckiser Group PLC) for 56 times..
# ------------------------------ 0.016463518142700195 seconds | MAE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (Rexam Ltd) for 27 times..
# ------------------------------ 0.0073680877685546875 seconds | MAE: 0.053 ------------------------------
# Execute Training and Walk Forward Testing for (BP PLC) for 56 times..
# ------------------------------ 0.017265796661376953 seconds | MAE: 0.145 ------------------------------
# Execute Training and Walk Forward Testing for (Centrica PLC) for 48 times..
# ------------------------------ 0.015058755874633789 seconds | MAE: 0.233 ------------------------------
# Execute Training and Walk Forward Testing for (Shire Ltd) for 41 times..
# ------------------------------ 0.012226104736328125 seconds | MAE: 0.213 ------------------------------
# Execute Training and Walk Forward Testing for (Imperial Brands PLC) for 56 times..
# ------------------------------ 0.017402172088623047 seconds | MAE: 0.049 ------------------------------
# Execute Training and Walk Forward Testing for (Ei Group Ltd) for 4 times..
# ------------------------------ 0.001348257064819336 seconds | MAE: 0.116 ------------------------------
# Execute Training and Walk Forward Testing for (Rentokil Initial PLC) for 20 times..
# ------------------------------ 0.00550389289855957 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (National Grid PLC) for 56 times..
# ------------------------------ 0.016258716583251953 seconds | MAE: 0.037 ------------------------------
# Execute Training and Walk Forward Testing for (Home Retail Group Ltd) for 9 times..
# ------------------------------ 0.0025947093963623047 seconds | MAE: 0.105 ------------------------------
# Execute Training and Walk Forward Testing for (AstraZeneca PLC) for 56 times..
# ------------------------------ 0.016072511672973633 seconds | MAE: 0.054 ------------------------------
# Execute Training and Walk Forward Testing for (SSE PLC) for 56 times..
# ------------------------------ 0.016664505004882812 seconds | MAE: 0.086 ------------------------------
# Execute Training and Walk Forward Testing for (Capricorn Energy PLC) for 14 times..
# ------------------------------ 0.003946542739868164 seconds | MAE: 0.174 ------------------------------
# Execute Training and Walk Forward Testing for (Persimmon PLC) for 38 times..
# ------------------------------ 0.01087045669555664 seconds | MAE: 0.123 ------------------------------
# Execute Training and Walk Forward Testing for (Shell PLC) for 56 times..
# ------------------------------ 0.016423940658569336 seconds | MAE: 0.128 ------------------------------

# %%
mresults_m3 = compile_train_test(train_df, test_df, sample=False, algo='EN', dataset='m3', viz=True, cap = True)
# Out:
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 3 times..
# ------------------------------ 0.001733541488647461 seconds | MAE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 3 times..
# ------------------------------ 0.0014863014221191406 seconds | MAE: 0.844 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 5 times..
# ------------------------------ 0.0019483566284179688 seconds | MAE: 0.014 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 6 times..
# ------------------------------ 0.002192974090576172 seconds | MAE: 0.009 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 8 times..
# ------------------------------ 0.004134654998779297 seconds | MAE: 0.356 ------------------------------
# Execute Training and Walk Forward Testing for (JD Sports Fashion PLC) for 8 times..
# ------------------------------ 0.003167390823364258 seconds | MAE: 0.071 ------------------------------
# Execute Training and Walk Forward Testing for (Phoenix Group Holdings PLC) for 9 times..
# ------------------------------ 0.003122568130493164 seconds | MAE: 0.008 ------------------------------
# Execute Training and Walk Forward Testing for (Spirax-Sarco Engineering PLC) for 9 times..
# ------------------------------ 0.003160238265991211 seconds | MAE: 0.007 ------------------------------
# Execute Training and Walk Forward Testing for (Entain PLC) for 6 times..
# ------------------------------ 0.002664327621459961 seconds | MAE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (Ocado Group PLC) for 11 times..
# ------------------------------ 0.005598306655883789 seconds | MAE: 0.169 ------------------------------
# Execute Training and Walk Forward Testing for (Rightmove PLC) for 11 times..
# ------------------------------ 0.003772258758544922 seconds | MAE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (Halma PLC) for 13 times..
# ------------------------------ 0.0039730072021484375 seconds | MAE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (DS Smith PLC) for 13 times..
# ------------------------------ 0.007769584655761719 seconds | MAE: 0.031 ------------------------------
# Execute Training and Walk Forward Testing for (NMC Health PLC) for 3 times..
# ------------------------------ 0.0012180805206298828 seconds | MAE: 1.665 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish Mortgage Investment Trust PLC) for 16 times..
# ------------------------------ 0.0054492950439453125 seconds | MAE: 0.056 ------------------------------
# Execute Training and Walk Forward Testing for (Smurfit Kappa Group PLC) for 17 times..
# ------------------------------ 0.005369901657104492 seconds | MAE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (Micro Focus International Ltd) for 6 times..
# ------------------------------ 0.002715587615966797 seconds | MAE: 0.133 ------------------------------
# Execute Training and Walk Forward Testing for (Informa PLC) for 19 times..
# ------------------------------ 0.007065773010253906 seconds | MAE: 0.106 ------------------------------
# Execute Training and Walk Forward Testing for (Mediclinic Group Ltd) for 3 times..
# ------------------------------ 0.0012803077697753906 seconds | MAE: 0.003 ------------------------------
# Execute Training and Walk Forward Testing for (Flutter Entertainment PLC) for 19 times..
# ------------------------------ 0.007001399993896484 seconds | MAE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (DCC PLC) for 20 times..
# ------------------------------ 0.005944728851318359 seconds | MAE: 0.008 ------------------------------
# Execute Training and Walk Forward Testing for (Berkeley Group Holdings PLC) for 17 times..
# ------------------------------ 0.005249977111816406 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Merlin Entertainments Ltd) for 4 times..
# ------------------------------ 0.002016782760620117 seconds | MAE: 0.303 ------------------------------
# Execute Training and Walk Forward Testing for (Hikma Pharmaceuticals PLC) for 14 times..
# ------------------------------ 0.0041370391845703125 seconds | MAE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (TUI AG) for 12 times..
# ------------------------------ 0.004137754440307617 seconds | MAE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (Direct Line Insurance Group PLC) for 13 times..
# ------------------------------ 0.004198312759399414 seconds | MAE: 0.012 ------------------------------
# Execute Training and Walk Forward Testing for (International Distributions Services PLC) for 14 times..
# ------------------------------ 0.005276203155517578 seconds | MAE: 0.096 ------------------------------
# Execute Training and Walk Forward Testing for (Ashtead Group PLC) for 27 times..
# ------------------------------ 0.009372472763061523 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Coca Cola HBC AG) for 28 times..
# ------------------------------ 0.011198282241821289 seconds | MAE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (Frasers Group PLC) for 5 times..
# ------------------------------ 0.002300739288330078 seconds | MAE: 0.092 ------------------------------
# Execute Training and Walk Forward Testing for (Mondi PLC) for 28 times..
# ------------------------------ 0.014485597610473633 seconds | MAE: 0.040 ------------------------------
# Execute Training and Walk Forward Testing for (Travis Perkins PLC) for 7 times..
# ------------------------------ 0.002865314483642578 seconds | MAE: 2.013 ------------------------------
# Execute Training and Walk Forward Testing for (Easyjet PLC) for 19 times..
# ------------------------------ 0.007001161575317383 seconds | MAE: 0.459 ------------------------------
# Execute Training and Walk Forward Testing for (Melrose Industries PLC) for 18 times..
# ------------------------------ 0.0070455074310302734 seconds | MAE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Babcock International Group PLC) for 15 times..
# ------------------------------ 0.004347324371337891 seconds | MAE: 0.021 ------------------------------
# Execute Training and Walk Forward Testing for (Croda International PLC) for 23 times..
# ------------------------------ 0.008207559585571289 seconds | MAE: 0.018 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn Holdings Ltd) for 9 times..
# ------------------------------ 0.0029642581939697266 seconds | MAE: 0.057 ------------------------------
# Execute Training and Walk Forward Testing for (EVRAZ plc) for 15 times..
# ------------------------------ 0.004609584808349609 seconds | MAE: 0.469 ------------------------------
# Execute Training and Walk Forward Testing for (Polymetal International PLC) for 9 times..
# ------------------------------ 0.003315448760986328 seconds | MAE: 1.507 ------------------------------
# Execute Training and Walk Forward Testing for (Meggitt Ltd) for 15 times..
# ------------------------------ 0.005007266998291016 seconds | MAE: 0.671 ------------------------------
# Execute Training and Walk Forward Testing for (Glencore PLC) for 37 times..
# ------------------------------ 0.024182796478271484 seconds | MAE: 0.115 ------------------------------
# Execute Training and Walk Forward Testing for (Hargreaves Lansdown PLC) for 37 times..
# ------------------------------ 0.012613058090209961 seconds | MAE: 0.104 ------------------------------
# Execute Training and Walk Forward Testing for (International Consolidated Airlines Group SA) for 38 times..
# ------------------------------ 0.017218351364135742 seconds | MAE: 0.335 ------------------------------
# Execute Training and Walk Forward Testing for (IMI PLC) for 9 times..
# ------------------------------ 0.0034089088439941406 seconds | MAE: 0.011 ------------------------------
# Execute Training and Walk Forward Testing for (Weir Group PLC) for 14 times..
# ------------------------------ 0.004877567291259766 seconds | MAE: 0.037 ------------------------------
# Execute Training and Walk Forward Testing for (GKN Ltd) for 22 times..
# ------------------------------ 0.00656580924987793 seconds | MAE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (SVF Holdco (UK) Ltd) for 18 times..
# ------------------------------ 0.005614757537841797 seconds | MAE: 0.265 ------------------------------
# Execute Training and Walk Forward Testing for (Aggreko Ltd) for 15 times..
# ------------------------------ 0.004382610321044922 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Burberry Group PLC) for 43 times..
# ------------------------------ 0.01424860954284668 seconds | MAE: 0.087 ------------------------------
# Execute Training and Walk Forward Testing for (Intertek Group PLC) for 44 times..
# ------------------------------ 0.027782201766967773 seconds | MAE: 0.102 ------------------------------
# Execute Training and Walk Forward Testing for (Serco Group PLC) for 12 times..
# ------------------------------ 0.0039825439453125 seconds | MAE: 0.022 ------------------------------
# Execute Training and Walk Forward Testing for (Barrick Gold (Holdings) Ltd) for 31 times..
# ------------------------------ 0.01003265380859375 seconds | MAE: 0.065 ------------------------------
# Execute Training and Walk Forward Testing for (Fresnillo PLC) for 44 times..
# ------------------------------ 0.014057159423828125 seconds | MAE: 0.057 ------------------------------
# Execute Training and Walk Forward Testing for (Inmarsat Group Holdings Ltd) for 10 times..
# ------------------------------ 0.0030312538146972656 seconds | MAE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (Autonomy Corp Ltd) for 6 times..
# ------------------------------ 0.002809286117553711 seconds | MAE: 2.174 ------------------------------
# Execute Training and Walk Forward Testing for (Petrofac Ltd) for 17 times..
# ------------------------------ 0.0049436092376708984 seconds | MAE: 0.077 ------------------------------
# Execute Training and Walk Forward Testing for (John Wood Group PLC) for 3 times..
# ------------------------------ 0.0012264251708984375 seconds | MAE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (Bunzl plc) for 46 times..
# ------------------------------ 0.016010761260986328 seconds | MAE: 0.098 ------------------------------
# Execute Training and Walk Forward Testing for (Cobham Ltd) for 5 times..
# ------------------------------ 0.001741170883178711 seconds | MAE: 0.010 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance Trust PLC) for 6 times..
# ------------------------------ 0.0023963451385498047 seconds | MAE: 0.004 ------------------------------
# Execute Training and Walk Forward Testing for (London Stock Exchange Group PLC) for 38 times..
# ------------------------------ 0.022266149520874023 seconds | MAE: 0.085 ------------------------------
# Execute Training and Walk Forward Testing for (Admiral Group PLC) for 49 times..
# ------------------------------ 0.01530599594116211 seconds | MAE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (Tui Travel Ltd) for 14 times..
# ------------------------------ 0.004111528396606445 seconds | MAE: 0.024 ------------------------------
# Execute Training and Walk Forward Testing for (Amec Foster Wheeler Ltd) for 17 times..
# ------------------------------ 0.005196809768676758 seconds | MAE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (G4S Ltd) for 27 times..
# ------------------------------ 0.014171361923217773 seconds | MAE: 0.005 ------------------------------
# Execute Training and Walk Forward Testing for (Currys PLC) for 7 times..
# ------------------------------ 0.002689838409423828 seconds | MAE: 3.554 ------------------------------
# Execute Training and Walk Forward Testing for (Tullow Oil PLC) for 22 times..
# ------------------------------ 0.006819486618041992 seconds | MAE: 0.072 ------------------------------
# Execute Training and Walk Forward Testing for (Taylor Wimpey PLC) for 25 times..
# ------------------------------ 0.014338016510009766 seconds | MAE: 0.037 ------------------------------
# Execute Training and Walk Forward Testing for (Barratt Developments P L C) for 27 times..
# ------------------------------ 0.008151531219482422 seconds | MAE: 0.039 ------------------------------
# Execute Training and Walk Forward Testing for (Whitbread PLC) for 51 times..
# ------------------------------ 0.0184328556060791 seconds | MAE: 0.173 ------------------------------
# Execute Training and Walk Forward Testing for (Experian PLC) for 53 times..
# ------------------------------ 0.03489065170288086 seconds | MAE: 0.158 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn PLC) for 52 times..
# ------------------------------ 0.024608373641967773 seconds | MAE: 0.120 ------------------------------
# Execute Training and Walk Forward Testing for (SEGRO PLC) for 22 times..
# ------------------------------ 0.006636142730712891 seconds | MAE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (NEX Group Ltd) for 17 times..
# ------------------------------ 0.005833625793457031 seconds | MAE: 0.088 ------------------------------
# Execute Training and Walk Forward Testing for (Sibanye Uk Ltd) for 13 times..
# ------------------------------ 0.005645751953125 seconds | MAE: 0.110 ------------------------------
# Execute Training and Walk Forward Testing for (Aviva PLC) for 56 times..
# ------------------------------ 0.05716347694396973 seconds | MAE: 0.137 ------------------------------
# Execute Training and Walk Forward Testing for (Barclays PLC) for 56 times..
# ------------------------------ 0.06655359268188477 seconds | MAE: 0.221 ------------------------------
# Execute Training and Walk Forward Testing for (HSBC Holdings PLC) for 56 times..
# ------------------------------ 0.02777838706970215 seconds | MAE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 56 times..
# ------------------------------ 0.03794217109680176 seconds | MAE: 0.133 ------------------------------
# Execute Training and Walk Forward Testing for (Prudential PLC) for 56 times..
# ------------------------------ 0.030431747436523438 seconds | MAE: 0.177 ------------------------------
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 56 times..
# ------------------------------ 0.10998368263244629 seconds | MAE: 0.221 ------------------------------
# Execute Training and Walk Forward Testing for (Man Group PLC) for 18 times..
# ------------------------------ 0.006326913833618164 seconds | MAE: 0.127 ------------------------------
# Execute Training and Walk Forward Testing for (WPP PLC) for 56 times..
# ------------------------------ 0.020469188690185547 seconds | MAE: 0.101 ------------------------------
# Execute Training and Walk Forward Testing for (Rolls-Royce Holdings PLC) for 56 times..
# ------------------------------ 0.03656959533691406 seconds | MAE: 0.568 ------------------------------
# Execute Training and Walk Forward Testing for (United Utilities Group PLC) for 56 times..
# ------------------------------ 0.01898670196533203 seconds | MAE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (Xstrata Ltd) for 21 times..
# ------------------------------ 0.009092330932617188 seconds | MAE: 0.111 ------------------------------
# Execute Training and Walk Forward Testing for (BAE Systems PLC) for 56 times..
# ------------------------------ 0.03057122230529785 seconds | MAE: 0.047 ------------------------------
# Execute Training and Walk Forward Testing for (EDF Energy Nuclear Generation Group Ltd) for 3 times..
# ------------------------------ 0.0012047290802001953 seconds | MAE: 0.114 ------------------------------
# Execute Training and Walk Forward Testing for (Sage Group PLC) for 56 times..
# ------------------------------ 0.019070863723754883 seconds | MAE: 0.049 ------------------------------
# Execute Training and Walk Forward Testing for (Antofagasta PLC) for 56 times..
# ------------------------------ 0.023233413696289062 seconds | MAE: 0.065 ------------------------------
# Execute Training and Walk Forward Testing for (ITV PLC) for 42 times..
# ------------------------------ 0.0128631591796875 seconds | MAE: 0.198 ------------------------------
# Execute Training and Walk Forward Testing for (WM Morrison Supermarkets Ltd) for 48 times..
# ------------------------------ 0.023265600204467773 seconds | MAE: 0.045 ------------------------------
# Execute Training and Walk Forward Testing for (Sky Ltd) for 41 times..
# ------------------------------ 0.015939712524414062 seconds | MAE: 0.095 ------------------------------
# Execute Training and Walk Forward Testing for (Vodafone Group PLC) for 56 times..
# ------------------------------ 0.05286264419555664 seconds | MAE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (Severn Trent PLC) for 56 times..
# ------------------------------ 0.031037569046020508 seconds | MAE: 0.041 ------------------------------
# Execute Training and Walk Forward Testing for (Anglo American PLC) for 56 times..
# ------------------------------ 0.01779651641845703 seconds | MAE: 0.106 ------------------------------
# Execute Training and Walk Forward Testing for (Abi Sab Group Holding Ltd) for 33 times..
# ------------------------------ 0.011008024215698242 seconds | MAE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (Kingfisher PLC) for 55 times..
# ------------------------------ 0.017386674880981445 seconds | MAE: 0.089 ------------------------------
# Execute Training and Walk Forward Testing for (3i Group PLC) for 45 times..
# ------------------------------ 0.014007568359375 seconds | MAE: 0.134 ------------------------------
# Execute Training and Walk Forward Testing for (GSK plc) for 56 times..
# ------------------------------ 0.05228924751281738 seconds | MAE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Next PLC) for 56 times..
# ------------------------------ 0.018204689025878906 seconds | MAE: 0.136 ------------------------------
# Execute Training and Walk Forward Testing for (HBOS Plc) for 6 times..
# ------------------------------ 0.002157449722290039 seconds | MAE: 5.202 ------------------------------
# Execute Training and Walk Forward Testing for (BT Group PLC) for 56 times..
# ------------------------------ 0.020277023315429688 seconds | MAE: 0.060 ------------------------------
# Execute Training and Walk Forward Testing for (Compass Group PLC) for 56 times..
# ------------------------------ 0.028172731399536133 seconds | MAE: 0.174 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance & Leicester Ltd) for 3 times..
# ------------------------------ 0.001485586166381836 seconds | MAE: 0.269 ------------------------------
# Execute Training and Walk Forward Testing for (Tesco PLC) for 56 times..
# ------------------------------ 0.03573346138000488 seconds | MAE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (RSA Insurance Group Ltd) for 50 times..
# ------------------------------ 0.015790700912475586 seconds | MAE: 0.145 ------------------------------
# Execute Training and Walk Forward Testing for (Standard Chartered PLC) for 56 times..
# ------------------------------ 0.028676271438598633 seconds | MAE: 0.075 ------------------------------
# Execute Training and Walk Forward Testing for (Smith & Nephew PLC) for 56 times..
# ------------------------------ 0.02214193344116211 seconds | MAE: 0.071 ------------------------------
# Execute Training and Walk Forward Testing for (Smiths Group PLC) for 55 times..
# ------------------------------ 0.018505334854125977 seconds | MAE: 0.091 ------------------------------
# Execute Training and Walk Forward Testing for (Schroders PLC) for 54 times..
# ------------------------------ 0.02172708511352539 seconds | MAE: 0.255 ------------------------------
# Execute Training and Walk Forward Testing for (J Sainsbury PLC) for 56 times..
# ------------------------------ 0.03907942771911621 seconds | MAE: 0.077 ------------------------------
# Execute Training and Walk Forward Testing for (Hammerson PLC) for 39 times..
# ------------------------------ 0.011479377746582031 seconds | MAE: 0.241 ------------------------------
# Execute Training and Walk Forward Testing for (Legal & General Group PLC) for 56 times..
# ------------------------------ 0.023269176483154297 seconds | MAE: 0.245 ------------------------------
# Execute Training and Walk Forward Testing for (British Airways PLC) for 13 times..
# ------------------------------ 0.004611968994140625 seconds | MAE: 0.182 ------------------------------
# Execute Training and Walk Forward Testing for (BG Group Ltd) for 31 times..
# ------------------------------ 0.010944604873657227 seconds | MAE: 0.117 ------------------------------
# Execute Training and Walk Forward Testing for (Associated British Foods PLC) for 56 times..
# ------------------------------ 0.024450063705444336 seconds | MAE: 0.066 ------------------------------
# Execute Training and Walk Forward Testing for (British Land Company PLC) for 56 times..
# ------------------------------ 0.019101858139038086 seconds | MAE: 0.082 ------------------------------
# Execute Training and Walk Forward Testing for (BHP Group (UK) Ltd) for 52 times..
# ------------------------------ 0.01866436004638672 seconds | MAE: 0.088 ------------------------------
# Execute Training and Walk Forward Testing for (Pearson PLC) for 56 times..
# ------------------------------ 0.018215417861938477 seconds | MAE: 0.083 ------------------------------
# Execute Training and Walk Forward Testing for (Diageo PLC) for 56 times..
# ------------------------------ 0.02325749397277832 seconds | MAE: 0.068 ------------------------------
# Execute Training and Walk Forward Testing for (Johnson Matthey PLC) for 52 times..
# ------------------------------ 0.017868757247924805 seconds | MAE: 0.072 ------------------------------
# Execute Training and Walk Forward Testing for (Rio Tinto PLC) for 56 times..
# ------------------------------ 0.028340578079223633 seconds | MAE: 0.071 ------------------------------
# Execute Training and Walk Forward Testing for (British American Tobacco PLC) for 56 times..
# ------------------------------ 0.020290851593017578 seconds | MAE: 0.084 ------------------------------
# Execute Training and Walk Forward Testing for (Unilever PLC) for 56 times..
# ------------------------------ 0.04615163803100586 seconds | MAE: 0.041 ------------------------------
# Execute Training and Walk Forward Testing for (Relx PLC) for 56 times..
# ------------------------------ 0.019438505172729492 seconds | MAE: 0.028 ------------------------------
# Execute Training and Walk Forward Testing for (InterContinental Hotels Group PLC) for 56 times..
# ------------------------------ 0.04214811325073242 seconds | MAE: 0.227 ------------------------------
# Execute Training and Walk Forward Testing for (Tate & Lyle PLC) for 12 times..
# ------------------------------ 0.003951072692871094 seconds | MAE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (Cadbury Ltd) for 9 times..
# ------------------------------ 0.004185676574707031 seconds | MAE: 0.213 ------------------------------
# Execute Training and Walk Forward Testing for (Reckitt Benckiser Group PLC) for 56 times..
# ------------------------------ 0.03504061698913574 seconds | MAE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Rexam Ltd) for 27 times..
# ------------------------------ 0.008478641510009766 seconds | MAE: 0.063 ------------------------------
# Execute Training and Walk Forward Testing for (BP PLC) for 56 times..
# ------------------------------ 0.1976938247680664 seconds | MAE: 0.145 ------------------------------
# Execute Training and Walk Forward Testing for (Centrica PLC) for 48 times..
# ------------------------------ 0.021991252899169922 seconds | MAE: 0.229 ------------------------------
# Execute Training and Walk Forward Testing for (Shire Ltd) for 41 times..
# ------------------------------ 0.013839006423950195 seconds | MAE: 0.225 ------------------------------
# Execute Training and Walk Forward Testing for (Imperial Brands PLC) for 56 times..
# ------------------------------ 0.029467344284057617 seconds | MAE: 0.065 ------------------------------
# Execute Training and Walk Forward Testing for (Ei Group Ltd) for 4 times..
# ------------------------------ 0.001821279525756836 seconds | MAE: 0.111 ------------------------------
# Execute Training and Walk Forward Testing for (Rentokil Initial PLC) for 20 times..
# ------------------------------ 0.006248950958251953 seconds | MAE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (National Grid PLC) for 56 times..
# ------------------------------ 0.01905679702758789 seconds | MAE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Home Retail Group Ltd) for 9 times..
# ------------------------------ 0.0030624866485595703 seconds | MAE: 0.111 ------------------------------
# Execute Training and Walk Forward Testing for (AstraZeneca PLC) for 56 times..
# ------------------------------ 0.09478306770324707 seconds | MAE: 0.082 ------------------------------
# Execute Training and Walk Forward Testing for (SSE PLC) for 56 times..
# ------------------------------ 0.022266149520874023 seconds | MAE: 0.088 ------------------------------
# Execute Training and Walk Forward Testing for (Capricorn Energy PLC) for 14 times..
# ------------------------------ 0.00493168830871582 seconds | MAE: 0.247 ------------------------------
# Execute Training and Walk Forward Testing for (Persimmon PLC) for 38 times..
# ------------------------------ 0.013704538345336914 seconds | MAE: 0.130 ------------------------------
# Execute Training and Walk Forward Testing for (Shell PLC) for 56 times..
# ------------------------------ 0.1062166690826416 seconds | MAE: 0.141 ------------------------------

# %%
mresults_m2 = compile_train_test(train_df, test_df, sample=False, algo='EN', dataset='m2', viz=False, cap = True)
# Out:
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 7 times..
# ------------------------------ 0.0030968189239501953 seconds | MAE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 6 times..
# ------------------------------ 0.0023326873779296875 seconds | MAE: 0.436 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 8 times..
# ------------------------------ 0.002931833267211914 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 10 times..
# ------------------------------ 0.004168510437011719 seconds | MAE: 0.113 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 11 times..
# ------------------------------ 0.004671573638916016 seconds | MAE: 0.390 ------------------------------
# Execute Training and Walk Forward Testing for (JD Sports Fashion PLC) for 11 times..
# ------------------------------ 0.003640413284301758 seconds | MAE: 0.155 ------------------------------
# Execute Training and Walk Forward Testing for (Phoenix Group Holdings PLC) for 12 times..
# ------------------------------ 0.0035436153411865234 seconds | MAE: 0.015 ------------------------------
# Execute Training and Walk Forward Testing for (Spirax-Sarco Engineering PLC) for 13 times..
# ------------------------------ 0.0038950443267822266 seconds | MAE: 0.012 ------------------------------
# Execute Training and Walk Forward Testing for (Entain PLC) for 10 times..
# ------------------------------ 0.003062725067138672 seconds | MAE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (Ocado Group PLC) for 15 times..
# ------------------------------ 0.00507354736328125 seconds | MAE: 0.161 ------------------------------
# Execute Training and Walk Forward Testing for (Rightmove PLC) for 15 times..
# ------------------------------ 0.004411220550537109 seconds | MAE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (Halma PLC) for 17 times..
# ------------------------------ 0.004963397979736328 seconds | MAE: 0.022 ------------------------------
# Execute Training and Walk Forward Testing for (DS Smith PLC) for 17 times..
# ------------------------------ 0.0061795711517333984 seconds | MAE: 0.040 ------------------------------
# Execute Training and Walk Forward Testing for (NMC Health PLC) for 7 times..
# ------------------------------ 0.0023107528686523438 seconds | MAE: 1.083 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish Mortgage Investment Trust PLC) for 19 times..
# ------------------------------ 0.00509953498840332 seconds | MAE: 0.064 ------------------------------
# Execute Training and Walk Forward Testing for (Smurfit Kappa Group PLC) for 20 times..
# ------------------------------ 0.005589008331298828 seconds | MAE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (Micro Focus International Ltd) for 9 times..
# ------------------------------ 0.0029458999633789062 seconds | MAE: 0.102 ------------------------------
# Execute Training and Walk Forward Testing for (Informa PLC) for 23 times..
# ------------------------------ 0.00963592529296875 seconds | MAE: 0.067 ------------------------------
# Execute Training and Walk Forward Testing for (Mediclinic Group Ltd) for 6 times..
# ------------------------------ 0.0018913745880126953 seconds | MAE: 0.022 ------------------------------
# Execute Training and Walk Forward Testing for (Flutter Entertainment PLC) for 23 times..
# ------------------------------ 0.008617162704467773 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (DCC PLC) for 24 times..
# ------------------------------ 0.006974458694458008 seconds | MAE: 0.009 ------------------------------
# Execute Training and Walk Forward Testing for (Berkeley Group Holdings PLC) for 21 times..
# ------------------------------ 0.0061414241790771484 seconds | MAE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (Merlin Entertainments Ltd) for 8 times..
# ------------------------------ 0.0024099349975585938 seconds | MAE: 0.146 ------------------------------
# Execute Training and Walk Forward Testing for (Hikma Pharmaceuticals PLC) for 17 times..
# ------------------------------ 0.004770755767822266 seconds | MAE: 0.037 ------------------------------
# Execute Training and Walk Forward Testing for (TUI AG) for 16 times..
# ------------------------------ 0.004353046417236328 seconds | MAE: 0.055 ------------------------------
# Execute Training and Walk Forward Testing for (Direct Line Insurance Group PLC) for 16 times..
# ------------------------------ 0.004725933074951172 seconds | MAE: 0.010 ------------------------------
# Execute Training and Walk Forward Testing for (International Distributions Services PLC) for 18 times..
# ------------------------------ 0.005212068557739258 seconds | MAE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (Ashtead Group PLC) for 31 times..
# ------------------------------ 0.010409832000732422 seconds | MAE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (Coca Cola HBC AG) for 32 times..
# ------------------------------ 0.01029515266418457 seconds | MAE: 0.045 ------------------------------
# Execute Training and Walk Forward Testing for (Frasers Group PLC) for 8 times..
# ------------------------------ 0.0023145675659179688 seconds | MAE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (Mondi PLC) for 32 times..
# ------------------------------ 0.012408733367919922 seconds | MAE: 0.036 ------------------------------
# Execute Training and Walk Forward Testing for (Travis Perkins PLC) for 11 times..
# ------------------------------ 0.0033299922943115234 seconds | MAE: 1.310 ------------------------------
# Execute Training and Walk Forward Testing for (Easyjet PLC) for 22 times..
# ------------------------------ 0.006581306457519531 seconds | MAE: 0.403 ------------------------------
# Execute Training and Walk Forward Testing for (Melrose Industries PLC) for 21 times..
# ------------------------------ 0.005956888198852539 seconds | MAE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Babcock International Group PLC) for 18 times..
# ------------------------------ 0.004950761795043945 seconds | MAE: 0.112 ------------------------------
# Execute Training and Walk Forward Testing for (Croda International PLC) for 27 times..
# ------------------------------ 0.008570194244384766 seconds | MAE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn Holdings Ltd) for 13 times..
# ------------------------------ 0.003647327423095703 seconds | MAE: 0.043 ------------------------------
# Execute Training and Walk Forward Testing for (EVRAZ plc) for 18 times..
# ------------------------------ 0.006018161773681641 seconds | MAE: 0.397 ------------------------------
# Execute Training and Walk Forward Testing for (Polymetal International PLC) for 13 times..
# ------------------------------ 0.0038216114044189453 seconds | MAE: 1.070 ------------------------------
# Execute Training and Walk Forward Testing for (Meggitt Ltd) for 19 times..
# ------------------------------ 0.005488872528076172 seconds | MAE: 0.523 ------------------------------
# Execute Training and Walk Forward Testing for (Glencore PLC) for 40 times..
# ------------------------------ 0.019573688507080078 seconds | MAE: 0.110 ------------------------------
# Execute Training and Walk Forward Testing for (Hargreaves Lansdown PLC) for 41 times..
# ------------------------------ 0.012940168380737305 seconds | MAE: 0.114 ------------------------------
# Execute Training and Walk Forward Testing for (International Consolidated Airlines Group SA) for 41 times..
# ------------------------------ 0.014515161514282227 seconds | MAE: 0.321 ------------------------------
# Execute Training and Walk Forward Testing for (IMI PLC) for 13 times..
# ------------------------------ 0.004349470138549805 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Weir Group PLC) for 18 times..
# ------------------------------ 0.005552530288696289 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (GKN Ltd) for 26 times..
# ------------------------------ 0.007142305374145508 seconds | MAE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (SVF Holdco (UK) Ltd) for 22 times..
# ------------------------------ 0.006474971771240234 seconds | MAE: 0.217 ------------------------------
# Execute Training and Walk Forward Testing for (Aggreko Ltd) for 18 times..
# ------------------------------ 0.005194664001464844 seconds | MAE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Burberry Group PLC) for 46 times..
# ------------------------------ 0.013442039489746094 seconds | MAE: 0.079 ------------------------------
# Execute Training and Walk Forward Testing for (Intertek Group PLC) for 48 times..
# ------------------------------ 0.021433591842651367 seconds | MAE: 0.094 ------------------------------
# Execute Training and Walk Forward Testing for (Serco Group PLC) for 15 times..
# ------------------------------ 0.006610870361328125 seconds | MAE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (Barrick Gold (Holdings) Ltd) for 34 times..
# ------------------------------ 0.00950312614440918 seconds | MAE: 0.067 ------------------------------
# Execute Training and Walk Forward Testing for (Fresnillo PLC) for 48 times..
# ------------------------------ 0.015035629272460938 seconds | MAE: 0.056 ------------------------------
# Execute Training and Walk Forward Testing for (Inmarsat Group Holdings Ltd) for 13 times..
# ------------------------------ 0.0038154125213623047 seconds | MAE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Autonomy Corp Ltd) for 9 times..
# ------------------------------ 0.0027501583099365234 seconds | MAE: 1.428 ------------------------------
# Execute Training and Walk Forward Testing for (Petrofac Ltd) for 21 times..
# ------------------------------ 0.0062618255615234375 seconds | MAE: 0.097 ------------------------------
# Execute Training and Walk Forward Testing for (John Wood Group PLC) for 7 times..
# ------------------------------ 0.002184152603149414 seconds | MAE: 0.059 ------------------------------
# Execute Training and Walk Forward Testing for (Bunzl plc) for 49 times..
# ------------------------------ 0.015111446380615234 seconds | MAE: 0.091 ------------------------------
# Execute Training and Walk Forward Testing for (Cobham Ltd) for 8 times..
# ------------------------------ 0.0025682449340820312 seconds | MAE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance Trust PLC) for 9 times..
# ------------------------------ 0.002880096435546875 seconds | MAE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (London Stock Exchange Group PLC) for 41 times..
# ------------------------------ 0.018818140029907227 seconds | MAE: 0.131 ------------------------------
# Execute Training and Walk Forward Testing for (Admiral Group PLC) for 53 times..
# ------------------------------ 0.016803979873657227 seconds | MAE: 0.055 ------------------------------
# Execute Training and Walk Forward Testing for (Tui Travel Ltd) for 18 times..
# ------------------------------ 0.0053250789642333984 seconds | MAE: 0.146 ------------------------------
# Execute Training and Walk Forward Testing for (Amec Foster Wheeler Ltd) for 21 times..
# ------------------------------ 0.006536006927490234 seconds | MAE: 0.150 ------------------------------
# Execute Training and Walk Forward Testing for (G4S Ltd) for 30 times..
# ------------------------------ 0.014395713806152344 seconds | MAE: 0.010 ------------------------------
# Execute Training and Walk Forward Testing for (Currys PLC) for 11 times..
# ------------------------------ 0.003078460693359375 seconds | MAE: 3.449 ------------------------------
# Execute Training and Walk Forward Testing for (Tullow Oil PLC) for 25 times..
# ------------------------------ 0.008203983306884766 seconds | MAE: 0.093 ------------------------------
# Execute Training and Walk Forward Testing for (Taylor Wimpey PLC) for 29 times..
# ------------------------------ 0.011957883834838867 seconds | MAE: 0.049 ------------------------------
# Execute Training and Walk Forward Testing for (Barratt Developments P L C) for 30 times..
# ------------------------------ 0.008906126022338867 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Whitbread PLC) for 55 times..
# ------------------------------ 0.016565322875976562 seconds | MAE: 0.164 ------------------------------
# Execute Training and Walk Forward Testing for (Experian PLC) for 57 times..
# ------------------------------ 0.027342796325683594 seconds | MAE: 0.148 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn PLC) for 56 times..
# ------------------------------ 0.018178462982177734 seconds | MAE: 0.116 ------------------------------
# Execute Training and Walk Forward Testing for (SEGRO PLC) for 26 times..
# ------------------------------ 0.00787496566772461 seconds | MAE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (NEX Group Ltd) for 21 times..
# ------------------------------ 0.00879979133605957 seconds | MAE: 0.121 ------------------------------
# Execute Training and Walk Forward Testing for (Sibanye Uk Ltd) for 17 times..
# ------------------------------ 0.005838155746459961 seconds | MAE: 0.103 ------------------------------
# Execute Training and Walk Forward Testing for (Aviva PLC) for 60 times..
# ------------------------------ 0.02725672721862793 seconds | MAE: 0.104 ------------------------------
# Execute Training and Walk Forward Testing for (Barclays PLC) for 60 times..
# ------------------------------ 0.02872300148010254 seconds | MAE: 0.207 ------------------------------
# Execute Training and Walk Forward Testing for (HSBC Holdings PLC) for 60 times..
# ------------------------------ 0.022650718688964844 seconds | MAE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 60 times..
# ------------------------------ 0.02536606788635254 seconds | MAE: 0.110 ------------------------------
# Execute Training and Walk Forward Testing for (Prudential PLC) for 60 times..
# ------------------------------ 0.023839712142944336 seconds | MAE: 0.166 ------------------------------
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 60 times..
# ------------------------------ 0.03865313529968262 seconds | MAE: 0.182 ------------------------------
# Execute Training and Walk Forward Testing for (Man Group PLC) for 21 times..
# ------------------------------ 0.006499767303466797 seconds | MAE: 0.103 ------------------------------
# Execute Training and Walk Forward Testing for (WPP PLC) for 60 times..
# ------------------------------ 0.02095818519592285 seconds | MAE: 0.094 ------------------------------
# Execute Training and Walk Forward Testing for (Rolls-Royce Holdings PLC) for 60 times..
# ------------------------------ 0.026086091995239258 seconds | MAE: 0.527 ------------------------------
# Execute Training and Walk Forward Testing for (United Utilities Group PLC) for 60 times..
# ------------------------------ 0.017797470092773438 seconds | MAE: 0.040 ------------------------------
# Execute Training and Walk Forward Testing for (Xstrata Ltd) for 25 times..
# ------------------------------ 0.009897470474243164 seconds | MAE: 0.156 ------------------------------
# Execute Training and Walk Forward Testing for (BAE Systems PLC) for 60 times..
# ------------------------------ 0.025432109832763672 seconds | MAE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (EDF Energy Nuclear Generation Group Ltd) for 7 times..
# ------------------------------ 0.002185821533203125 seconds | MAE: 0.115 ------------------------------
# Execute Training and Walk Forward Testing for (Sage Group PLC) for 60 times..
# ------------------------------ 0.023675203323364258 seconds | MAE: 0.052 ------------------------------
# Execute Training and Walk Forward Testing for (Antofagasta PLC) for 60 times..
# ------------------------------ 0.01842021942138672 seconds | MAE: 0.066 ------------------------------
# Execute Training and Walk Forward Testing for (ITV PLC) for 45 times..
# ------------------------------ 0.012879610061645508 seconds | MAE: 0.190 ------------------------------
# Execute Training and Walk Forward Testing for (WM Morrison Supermarkets Ltd) for 52 times..
# ------------------------------ 0.021240234375 seconds | MAE: 0.043 ------------------------------
# Execute Training and Walk Forward Testing for (Sky Ltd) for 44 times..
# ------------------------------ 0.016564607620239258 seconds | MAE: 0.088 ------------------------------
# Execute Training and Walk Forward Testing for (Vodafone Group PLC) for 60 times..
# ------------------------------ 0.03133797645568848 seconds | MAE: 0.074 ------------------------------
# Execute Training and Walk Forward Testing for (Severn Trent PLC) for 60 times..
# ------------------------------ 0.022282838821411133 seconds | MAE: 0.038 ------------------------------
# Execute Training and Walk Forward Testing for (Anglo American PLC) for 60 times..
# ------------------------------ 0.018537044525146484 seconds | MAE: 0.097 ------------------------------
# Execute Training and Walk Forward Testing for (Abi Sab Group Holding Ltd) for 37 times..
# ------------------------------ 0.010981321334838867 seconds | MAE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (Kingfisher PLC) for 58 times..
# ------------------------------ 0.017227649688720703 seconds | MAE: 0.086 ------------------------------
# Execute Training and Walk Forward Testing for (3i Group PLC) for 48 times..
# ------------------------------ 0.013779163360595703 seconds | MAE: 0.124 ------------------------------
# Execute Training and Walk Forward Testing for (GSK plc) for 60 times..
# ------------------------------ 0.02967977523803711 seconds | MAE: 0.028 ------------------------------
# Execute Training and Walk Forward Testing for (Next PLC) for 60 times..
# ------------------------------ 0.018008708953857422 seconds | MAE: 0.125 ------------------------------
# Execute Training and Walk Forward Testing for (HBOS Plc) for 9 times..
# ------------------------------ 0.0026731491088867188 seconds | MAE: 4.298 ------------------------------
# Execute Training and Walk Forward Testing for (BT Group PLC) for 60 times..
# ------------------------------ 0.01934981346130371 seconds | MAE: 0.059 ------------------------------
# Execute Training and Walk Forward Testing for (Compass Group PLC) for 60 times..
# ------------------------------ 0.019979000091552734 seconds | MAE: 0.163 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance & Leicester Ltd) for 7 times..
# ------------------------------ 0.002004384994506836 seconds | MAE: 0.425 ------------------------------
# Execute Training and Walk Forward Testing for (Tesco PLC) for 60 times..
# ------------------------------ 0.026190757751464844 seconds | MAE: 0.043 ------------------------------
# Execute Training and Walk Forward Testing for (RSA Insurance Group Ltd) for 54 times..
# ------------------------------ 0.01539158821105957 seconds | MAE: 0.134 ------------------------------
# Execute Training and Walk Forward Testing for (Standard Chartered PLC) for 60 times..
# ------------------------------ 0.02173757553100586 seconds | MAE: 0.072 ------------------------------
# Execute Training and Walk Forward Testing for (Smith & Nephew PLC) for 60 times..
# ------------------------------ 0.017847537994384766 seconds | MAE: 0.066 ------------------------------
# Execute Training and Walk Forward Testing for (Smiths Group PLC) for 58 times..
# ------------------------------ 0.01982736587524414 seconds | MAE: 0.089 ------------------------------
# Execute Training and Walk Forward Testing for (Schroders PLC) for 57 times..
# ------------------------------ 0.018361806869506836 seconds | MAE: 0.235 ------------------------------
# Execute Training and Walk Forward Testing for (J Sainsbury PLC) for 60 times..
# ------------------------------ 0.02468729019165039 seconds | MAE: 0.086 ------------------------------
# Execute Training and Walk Forward Testing for (Hammerson PLC) for 42 times..
# ------------------------------ 0.011879205703735352 seconds | MAE: 0.226 ------------------------------
# Execute Training and Walk Forward Testing for (Legal & General Group PLC) for 60 times..
# ------------------------------ 0.022036314010620117 seconds | MAE: 0.227 ------------------------------
# Execute Training and Walk Forward Testing for (British Airways PLC) for 16 times..
# ------------------------------ 0.004758119583129883 seconds | MAE: 0.097 ------------------------------
# Execute Training and Walk Forward Testing for (BG Group Ltd) for 35 times..
# ------------------------------ 0.010665655136108398 seconds | MAE: 0.115 ------------------------------
# Execute Training and Walk Forward Testing for (Associated British Foods PLC) for 60 times..
# ------------------------------ 0.019182443618774414 seconds | MAE: 0.061 ------------------------------
# Execute Training and Walk Forward Testing for (British Land Company PLC) for 60 times..
# ------------------------------ 0.01795506477355957 seconds | MAE: 0.081 ------------------------------
# Execute Training and Walk Forward Testing for (BHP Group (UK) Ltd) for 56 times..
# ------------------------------ 0.016635417938232422 seconds | MAE: 0.085 ------------------------------
# Execute Training and Walk Forward Testing for (Pearson PLC) for 60 times..
# ------------------------------ 0.018491744995117188 seconds | MAE: 0.081 ------------------------------
# Execute Training and Walk Forward Testing for (Diageo PLC) for 60 times..
# ------------------------------ 0.022022247314453125 seconds | MAE: 0.055 ------------------------------
# Execute Training and Walk Forward Testing for (Johnson Matthey PLC) for 56 times..
# ------------------------------ 0.01761031150817871 seconds | MAE: 0.068 ------------------------------
# Execute Training and Walk Forward Testing for (Rio Tinto PLC) for 60 times..
# ------------------------------ 0.02466273307800293 seconds | MAE: 0.072 ------------------------------
# Execute Training and Walk Forward Testing for (British American Tobacco PLC) for 60 times..
# ------------------------------ 0.020670652389526367 seconds | MAE: 0.081 ------------------------------
# Execute Training and Walk Forward Testing for (Unilever PLC) for 60 times..
# ------------------------------ 0.029453516006469727 seconds | MAE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (Relx PLC) for 60 times..
# ------------------------------ 0.01871776580810547 seconds | MAE: 0.028 ------------------------------
# Execute Training and Walk Forward Testing for (InterContinental Hotels Group PLC) for 60 times..
# ------------------------------ 0.02000904083251953 seconds | MAE: 0.201 ------------------------------
# Execute Training and Walk Forward Testing for (Tate & Lyle PLC) for 16 times..
# ------------------------------ 0.0063724517822265625 seconds | MAE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (Cadbury Ltd) for 13 times..
# ------------------------------ 0.004931211471557617 seconds | MAE: 0.134 ------------------------------
# Execute Training and Walk Forward Testing for (Reckitt Benckiser Group PLC) for 60 times..
# ------------------------------ 0.01817941665649414 seconds | MAE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Rexam Ltd) for 30 times..
# ------------------------------ 0.008817195892333984 seconds | MAE: 0.056 ------------------------------
# Execute Training and Walk Forward Testing for (BP PLC) for 60 times..
# ------------------------------ 0.06712007522583008 seconds | MAE: 0.139 ------------------------------
# Execute Training and Walk Forward Testing for (Centrica PLC) for 52 times..
# ------------------------------ 0.021024227142333984 seconds | MAE: 0.212 ------------------------------
# Execute Training and Walk Forward Testing for (Shire Ltd) for 45 times..
# ------------------------------ 0.013841629028320312 seconds | MAE: 0.204 ------------------------------
# Execute Training and Walk Forward Testing for (Imperial Brands PLC) for 60 times..
# ------------------------------ 0.019106626510620117 seconds | MAE: 0.060 ------------------------------
# Execute Training and Walk Forward Testing for (Ei Group Ltd) for 8 times..
# ------------------------------ 0.0028400421142578125 seconds | MAE: 0.263 ------------------------------
# Execute Training and Walk Forward Testing for (Rentokil Initial PLC) for 24 times..
# ------------------------------ 0.00723719596862793 seconds | MAE: 0.018 ------------------------------
# Execute Training and Walk Forward Testing for (National Grid PLC) for 60 times..
# ------------------------------ 0.019466638565063477 seconds | MAE: 0.045 ------------------------------
# Execute Training and Walk Forward Testing for (Home Retail Group Ltd) for 13 times..
# ------------------------------ 0.004698991775512695 seconds | MAE: 0.120 ------------------------------
# Execute Training and Walk Forward Testing for (AstraZeneca PLC) for 60 times..
# ------------------------------ 0.03877425193786621 seconds | MAE: 0.079 ------------------------------
# Execute Training and Walk Forward Testing for (SSE PLC) for 60 times..
# ------------------------------ 0.019999980926513672 seconds | MAE: 0.082 ------------------------------
# Execute Training and Walk Forward Testing for (Capricorn Energy PLC) for 18 times..
# ------------------------------ 0.0052907466888427734 seconds | MAE: 0.226 ------------------------------
# Execute Training and Walk Forward Testing for (Persimmon PLC) for 41 times..
# ------------------------------ 0.013119697570800781 seconds | MAE: 0.121 ------------------------------
# Execute Training and Walk Forward Testing for (Shell PLC) for 60 times..
# ------------------------------ 0.05000042915344238 seconds | MAE: 0.129 ------------------------------

# %% [markdown]
# # Results Reporting

# %%
np.mean(mresults_m1['MSE^3'])
# Out:
# 0.2151216313979742

# %%
np.mean(mresults_m2['MSE^3'])
# Out:
# 0.21690611096488316

# %%
np.mean(mresults_m3['MSE^3'])
# Out:
# 0.21696378629816265

# %%
np.mean(mresults_m1['MSE^3'])
# Out:
# 0.2206788192810873

# %%
np.mean(mresults_m2['MSE^3'])
# Out:
# 0.188549875778676

# %%
np.mean(mresults_m3['MSE^3'])
# Out:
# 0.1885493550756858

# %% [markdown]
# ---

# %% [markdown]
# # Results

# %%
mresults_m1.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                  Name Model  Test Size     MSE^3
# 112  4295895499              HBOS Plc    EN          5  6.964650
# 70   5000683618            Currys PLC    EN          7  3.130503
# 59   4295896428     Autonomy Corp Ltd    EN          6  2.392032
# 35   4295894092    Travis Perkins PLC    EN          7  2.112107
# 15   5037364885        NMC Health PLC    EN          3  1.607201
# ..          ...                   ...   ...        ...       ...
# 63   4295894904            Cobham Ltd    EN          5  0.009929
# 23   4295874865               DCC PLC    EN         21  0.007946
# 69   4295893850               G4S Ltd    EN         27  0.006713
# 64   4295895691    Alliance Trust PLC    EN          6  0.003520
# 20   5040053800  Mediclinic Group Ltd    EN          3  0.002746
#
# [160 rows x 5 columns]

# %%
mresults_m3.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                         Name Model  Test Size     MSE^3
# 112  4295895499                     HBOS Plc    EN          5  7.051525
# 70   5000683618                   Currys PLC    EN          7  3.514539
# 59   4295896428            Autonomy Corp Ltd    EN          6  2.111806
# 35   4295894092           Travis Perkins PLC    EN          7  2.069147
# 42   5036206981  Polymetal International PLC    EN          9  1.520628
# ..          ...                          ...   ...        ...       ...
# 63   4295894904                   Cobham Ltd    EN          5  0.009929
# 23   4295874865                      DCC PLC    EN         21  0.007946
# 69   4295893850                      G4S Ltd    EN         27  0.004866
# 64   4295895691           Alliance Trust PLC    EN          6  0.003520
# 20   5040053800         Mediclinic Group Ltd    EN          3  0.002746
#
# [160 rows x 5 columns]

# %% [markdown]
# ## Exporting the Results

# %%
np.mean(mresults_m1['MSE^3'])
# Out:
# 0.1431645582698732

# %%
MODEL = 'RF'
THRESHOLD = str(24)
CAP = 'm1'
mresults_m1.to_excel(f'../results/1-{MODEL}-{THRESHOLD}MONTH-{CAP}.xlsx', index=None)

# %%
np.mean(mresults_m3['MSE^3'])
# Out:
# 0.13529247091706614

# %%
mresults_m3.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                         Name Model  Test Size     MSE^3
# 70   5000683618                   Currys PLC    RF         12  3.093467
# 112  4295895499                     HBOS Plc    RF         10  2.146841
# 59   4295896428            Autonomy Corp Ltd    RF         10  1.218058
# 35   4295894092           Travis Perkins PLC    RF         12  1.132370
# 42   5036206981  Polymetal International PLC    RF         14  1.030174
# ..          ...                          ...   ...        ...       ...
# 55   4295898751              Serco Group PLC    RF         16  0.012833
# 51   4295894819                  Aggreko Ltd    RF         19  0.010403
# 68   4295894471      Amec Foster Wheeler Ltd    RF         22  0.009548
# 47   4295894784                      IMI PLC    RF         14  0.006152
# 64   4295895691           Alliance Trust PLC    RF         10  0.005796
#
# [160 rows x 5 columns]

# %%
MODEL = 'RF'
THRESHOLD = str(24)
CAP = 'm3'
mresults_m3.to_excel(f'../results/1-{MODEL}-{THRESHOLD}MONTH-{CAP}.xlsx', index=None)

# %% [markdown]
# ---

# %% [markdown]
# # Viz

# %%
def compile_train_test(train_df, test_df, sample = True, algo = 'HAR', dataset = 'm1', viz = False, cap = True):
    '''
    '''
    test_perc = .3 

    if dataset == 'm1':
        cols = ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
        
    elif dataset == 'm2':
        cols = vif_check()

    else:
        cols = [ 'buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar'
                ,'CSRStrategy','Community','Emissions','EnvironmentalInnovation','HumanRights','Management','ProductResponsibility'
                ,'ResourceUse','Shareholders','Workforce', 'vol_series_daily','vol_series_weekly','vol_series_monthly', 'V^YZ']
        
        # version 2
        cols = ['buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar','Community',
                'EnvironmentalInnovation','Management','ProductResponsibility','Shareholders','Workforce', 'V^YZ']

    mresults = pd.DataFrame()
    predictions_df = pd.DataFrame()

    if sample:
        # assets = [4295894970, 8589934212]
        assets = [8589934212, 8589934254] # 3rd and 4th most volatile stocks in FTSE 2006 to 2022
    else:
        assets = train_df.Asset.unique().tolist()

    for r, asset in enumerate(assets): 
        # print(asset)
        name = train_df[train_df['Asset'] == asset].iloc[0,-1]

        df_train = train_df[train_df.Asset == asset][cols].dropna()
        df_test = test_df[test_df.Asset == asset][cols].dropna()
        indices = test_df[test_df.Asset == asset].index
        # display(df_train)
        df_merge = pd.concat([df_train, df_test])
        df_merge = series_to_supervised(df_merge, n_in=3, target= ['V^YZ'])
        test_size = int(df_merge.shape[0] * test_perc)
        
        print(f'Execute Training and Walk Forward Testing for ({name}) for {test_size} times..')
        start_time = time.time()
        mse, y, yhat = walk_forward_validation(df_merge, test_size)
        print("---"*10, "%s seconds |"%(time.time() - start_time), 'MAE: %.3f'%mse, "---"*10)
        
        mresult = pd.DataFrame({
            'Asset': asset,
            'Name': name,
            'Model': algo,
            'Test Size': test_size,
            'MSE^3':mse
                    }
            , index=[r]
        )
        
        prediction_df = pd.DataFrame({
            'Asset':asset,
            'Test Data': y,
            'Predictions': yhat
        }, index = indices[-len(yhat):])
        

        
        mresults = pd.concat([mresults, mresult])
        predictions_df = pd.concat([predictions_df, prediction_df])

        if viz: 
            vis_line_plot_results(yhat, y, model = algo, dataset=dataset, name=name, r = r)

    return mresults, predictions_df

# %%
viz_df = train_df[['Asset', 'V^YZ']]

# %%
viz_df[viz_df.Asset.isin([8589934212, 8589934254])].to_csv('../data/9-data_train.csv')

# %%
mresults_m3, pred = compile_train_test(train_df, test_df, sample=True, algo='EN', dataset='m3', viz=False, cap = True)
# Out:
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 60 times..
# ------------------------------ 0.06134963035583496 seconds | MAE: 0.182 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 60 times..
# ------------------------------ 0.03344988822937012 seconds | MAE: 0.110 ------------------------------

# %%
pred.to_csv('../data/9-EN-SAMPLE-PREDICTION-RESULTS.csv')
