# %% [markdown]
# # Import Packages

# %%
# Method #2 HAR-X Model
from statsmodels.regression.linear_model import OLS
import statsmodels.api as sm

from IPython.display import display, HTML
from sklearn.metrics import mean_squared_error
from set_params import func_train_test_split, count_train_test, vif_check, vif_dynamic_check
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random as rd
import warnings

def calculate_iqr(values):
    # Calculate Q1
    Q1 = np.percentile(values, 25)
    # Calculate Q3
    Q3 = np.percentile(values, 75)
    # Calculate IQR
    IQR = Q3 - Q1
    return IQR

def detect_outliers_iqr(values):
    # Calculate the IQR of the values
    IQR = calculate_iqr(values)
    # Calculate Q1 and Q3
    Q1 = np.percentile(values, 25)
    Q3 = np.percentile(values, 75)
    # Define the lower and upper bound for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    # Return a boolean array: True if the value is an outlier, False otherwise
    return lower_bound, upper_bound

def vis_line_plot_results(y_pred, y_test, model = 'HAR', name = 'BARCLAYS', r = 1, dataset = 'm1'):

    plt.figure(figsize=(10,4))
    true, = plt.plot(y_test)
    preds, = plt.plot(y_pred)
    plt.title(f'{model}-{dataset}-{name}', fontsize=15)
    plt.legend(['True Volatility', 'Predicted Volatility'], fontsize=9)
    plt.xticks(rotation=45)
    plt.savefig(f'../outputs/{model}-{dataset}/{str(r+1).zfill(3)}-{model}-{name}.png')
    plt.close()

# display(HTML("<style>.container { width:80% !important; }</style>"))
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100)

# %%
import time
from set_params import func_train_test_split, count_train_test, series_to_supervised, train_test_split
from numpy import asarray, log1p, expm1

def ori_har_perf(df, df1):
    
    print('m1 datasets:', np.mean(df['MSE^3']))
    print('m3 datasets:', np.mean(df1['MSE^3']))

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Import Data and Split Train - Test

# %%
base_FTSE_df = pd.read_csv('../data/1.3-FTSE_Monthly_ESG_Volatility_Final_v2.csv')
# base_FTSE_df = base_FTSE_df.rename(columns={'Date_x':'date_key'})
# base_FTSE_df = base_FTSE_df.rename(columns={'Date_Key(Price)':'date_key'})

# %%
train_df, valid_df, test_df = func_train_test_split(validation = False, threshold = 24)

# %%
count_rows_df = count_train_test(train_df, test_df)

# %%
coverage_df = pd.read_csv('../data/coverage_dataframe.csv')
coverage_df.PermID = coverage_df.PermID.astype(int)
coverage_df = coverage_df[['PermID', 'Name']]
coverage_df = coverage_df.rename(columns={'PermID':'Asset'})

# %%
train_df = pd.merge(train_df, coverage_df, how = 'left', on = 'Asset')
train_df.index = train_df.month_key

# %%
train_df.head(3)
# Out:
#             Unnamed: 0   date_key       Asset      Open      High       Low  \
# month_key
# 2020-09-01           0 2020-10-30  5042941681  4.933999  4.935000  4.830999
# 2020-10-01           1 2020-11-30  5042941681  4.742000  4.824998  4.737000
# 2020-11-01           2 2020-12-31  5042941681  5.137998  5.210000  5.135999
#
#                Close    Return      V^CC      V^RS      V^YZ  month_key  \
# month_key
# 2020-09-01  4.847998 -0.018027  0.015260  0.014832  0.016693 2020-09-01
# 2020-10-01  4.778999  0.006105  0.028225  0.025393  0.027841 2020-10-01
# 2020-11-01  5.162000 -0.009213  0.018095  0.022583  0.023722 2020-11-01
#
#               buzz   ESG  ESGCombined  ESGControversies  EnvironmentalPillar  \
# month_key
# 2020-09-01  4108.0  75.0         75.0              75.0                 64.0
# 2020-10-01  4090.5  71.0         71.0              71.0                 55.0
# 2020-11-01  4291.5  72.0         69.0              66.0                 52.0
#
#             GovernancePillar  SocialPillar  Community  \
# month_key
# 2020-09-01              71.0          91.0      100.0
# 2020-10-01              69.0          89.0      100.0
# 2020-11-01              73.0          92.0      100.0
#
#             EnvironmentalInnovation  Management  ProductResponsibility  \
# month_key
# 2020-09-01                     69.0        91.0                   97.0
# 2020-10-01                     66.0        88.0                   98.0
# 2020-11-01                     75.0        94.0                   98.0
#
#             Shareholders  Workforce  vol_series_daily  vol_series_weekly  \
# month_key
# 2020-09-01           3.0       81.0               NaN                NaN
# 2020-10-01           4.0       74.0          0.016693                NaN
# 2020-11-01           5.0       82.0          0.027841                NaN
#
#             vol_series_monthly                          Name
# month_key
# 2020-09-01                 NaN  B&M European Value Retail SA
# 2020-10-01                 NaN  B&M European Value Retail SA
# 2020-11-01                 NaN  B&M European Value Retail SA

# %% [markdown]
# - Buzz score (1)
# - ESG Overall score (1)
# - ESG Combined score (1)
# - ESG Controversy score (1)
# - Pillar scores (3)
# - Category scores (10)
#
# In total there are 17 scores provided by MP ESG Core

# %%
cols = [
    'buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar'
                ,'CSRStrategy','Community','Emissions','EnvironmentalInnovation','HumanRights','Management','ProductResponsibility'
                ,'ResourceUse','Shareholders','Workforce', 'vol_series_daily','vol_series_weekly','vol_series_monthly', 'V^YZ']

# %%
train_df[cols].head()

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Version 1.1 (Promoted)

# %% [markdown]
# ### Create Functions

# %%
def compile_train_test(train_df, test_df, sample = True, algo = 'HAR', dataset = 'm1', viz = False, cap = True):
    '''
    '''

    if dataset == 'm1':
        cols = ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
        
    elif dataset == 'm2':
        cols = vif_check()
        print(cols)

    else:
        cols = [ 'buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar'
                ,'CSRStrategy','Community','Emissions','EnvironmentalInnovation','HumanRights','Management','ProductResponsibility'
                ,'ResourceUse','Shareholders','Workforce', 'vol_series_daily','vol_series_weekly','vol_series_monthly', 'V^YZ']
        
        # version 2
        cols = ['buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar','Community',
                'EnvironmentalInnovation','Management','ProductResponsibility','Shareholders','Workforce', 'V^YZ']

    mresults = pd.DataFrame()

    if sample:
        assets = [4295894970, 8589934212]
    else:
        assets = train_df.Asset.unique().tolist()

    for r, asset in enumerate(assets): 

        name = train_df[train_df['Asset'] == asset].iloc[0,-1]

        df_train = train_df[train_df.Asset == asset][cols].dropna()
        df_test = test_df[test_df.Asset == asset][cols].dropna()
        test_size = df_test.shape[0]
        
        # vif for each assets
        # df_merge = pd.concat([df_train, df_test])
        # cols = vif_dynamic_check(df_merge)
        # print(name, cols)
        # df_merge = df_merge[cols]
        # df_train = df_merge[df_merge.Asset == asset].iloc[:-test_size,: ]
        # df_test = df_merge[df_merge.Asset == asset].iloc[-test_size:,:]
        
        df_train = log1p(df_train)
        df_test = log1p(df_test)
        
        X_train = df_train.drop(['V^YZ'], axis=1)
        X_test = df_test.drop(['V^YZ'], axis=1)
        
        y_train = df_train['V^YZ']
        y_test = df_test['V^YZ']
        
        X_train = sm.add_constant(X_train)
        X_test.loc[:, 'const'] = 1
        X_test = X_test[X_train.columns]

        # Fit the model
        model = OLS(y_train, X_train)
        model_fit = model.fit()

        # display(X_test, X_train)
        y_pred = model_fit.predict(X_test)
        if cap:
            y_pred = y_pred.clip(lower = 0)
        
        mse_million = mean_squared_error(y_test,y_pred)*10**3
        mresult = pd.DataFrame({
            'Asset': asset,
            'Name': name,
            'Model': algo,
            'Test Size': test_size,
            'MSE^3':mse_million
                    }
            , index=[r]
        )
        mresults = pd.concat([mresults, mresult])
        
        y_test = expm1(y_test)
        y_pred = expm1(y_pred)

        if viz: 
            vis_line_plot_results(y_pred, y_test, model = 'HAR', dataset=dataset, name=name, r = r)

    return mresults

# %%
mresults_m1_v11 = compile_train_test(train_df, test_df, sample=False, algo='HAR', dataset='m1', viz=True, cap = True)

# %%
mresults_m1_v11.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                                     Name Model  Test Size  \
# 104  4295895343                 Alliance & Leicester Ltd   HAR          8
# 87   4295898951  EDF Energy Nuclear Generation Group Ltd   HAR          8
# 65   5000683618                               Currys PLC   HAR         12
# 31   4295894092                       Travis Perkins PLC   HAR         12
# 101  4295895499                                 HBOS Plc   HAR         10
# ..          ...                                      ...   ...        ...
# 20   4295874865                                  DCC PLC   HAR         25
# 64   4295893850                                  G4S Ltd   HAR         31
# 59   4295895691                       Alliance Trust PLC   HAR         10
# 63   4295894471                  Amec Foster Wheeler Ltd   HAR         22
# 43   4295894784                                  IMI PLC   HAR         14
#
#         MSE^3
# 104  6.097403
# 87   3.055775
# 65   2.793378
# 31   2.176187
# 101  2.074167
# ..        ...
# 20   0.007940
# 64   0.005949
# 59   0.005820
# 63   0.005765
# 43   0.004346
#
# [144 rows x 5 columns]

# %%
np.mean(mresults_m1_v11['MSE^3'])
# Out:
# 0.21483258430981284

# %% [markdown]
# ---

# %%
mresults_m3_v11 = compile_train_test(train_df, test_df, sample=False, algo='HAR', dataset='m3', viz=True, cap = True)

# %%
mresults_m3_v11.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                             Name Model  Test Size      MSE^3
# 5    4295894669            JD Sports Fashion PLC   HAR         12  13.002178
# 56   4295897144              John Wood Group PLC   HAR          8  12.361643
# 101  4295895499                         HBOS Plc   HAR         10   6.555752
# 65   5000683618                       Currys PLC   HAR         12   3.655763
# 13   5037364885                   NMC Health PLC   HAR          8   3.271018
# ..          ...                              ...   ...        ...        ...
# 24   4295869210                           TUI AG   HAR         17   0.037912
# 129  4295894756      Reckitt Benckiser Group PLC   HAR         60   0.029652
# 99   4295895781                          GSK plc   HAR         60   0.028447
# 25   4298449570  Direct Line Insurance Group PLC   HAR         17   0.019992
# 50   4295898751                  Serco Group PLC   HAR         16   0.011917
#
# [144 rows x 5 columns]

# %%
np.mean(mresults_m3_v11['MSE^3'])
# Out:
# 0.5691182939086771

# %%
mresults_m3_v11[mresults_m3_v11.Name == 'Meggitt Ltd']
# Out:
#          Asset         Name Model  Test Size     MSE^3
# 39  4295895717  Meggitt Ltd   HAR         20  0.357407

# %% [markdown]
# ---

# %%
mresults_m2_v11 = compile_train_test(train_df, test_df, sample=False, algo='HAR', dataset='m2', viz=True, cap = True)
# Out:
# ['buzz', 'Community', 'EnvironmentalInnovation', 'ProductResponsibility', 'Workforce', 'V^YZ']

# %%
mresults_m2_v11.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                          Name Model  Test Size      MSE^3
# 56   4295897144           John Wood Group PLC   HAR          8  23.351436
# 7    4295894930  Spirax-Sarco Engineering PLC   HAR         14   4.834375
# 65   5000683618                    Currys PLC   HAR         12   3.747595
# 101  4295895499                      HBOS Plc   HAR         10   3.648292
# 13   5037364885                NMC Health PLC   HAR          8   2.231081
# ..          ...                           ...   ...        ...        ...
# 20   4295874865                       DCC PLC   HAR         25   0.021263
# 10   4295899077                 Rightmove PLC   HAR         16   0.017555
# 136  4295894497          Rentokil Initial PLC   HAR         25   0.012566
# 43   4295894784                       IMI PLC   HAR         14   0.009335
# 50   4295898751               Serco Group PLC   HAR         16   0.007030
#
# [144 rows x 5 columns]

# %%
np.mean(mresults_m2_v11['MSE^3'])
# Out:
# 0.45890887450859313

# %% [markdown]
# ## Version 1.0

# %% [markdown]
# ### Create Functions

# %%
def compile_train_test(train_df, test_df, sample = True, algo = 'HAR', dataset = 'm1', viz = False, cap = True):
    '''
    '''

    if dataset == 'm1':
        cols = ['V^YZ', 'vol_series_daily', 'vol_series_weekly', 'vol_series_monthly']

    elif dataset == 'm3':
        cols = [ 'buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar'
                ,'CSRStrategy','Community','Emissions','EnvironmentalInnovation','HumanRights','Management','ProductResponsibility'
                ,'ResourceUse','Shareholders','Workforce', 'vol_series_daily','vol_series_weekly','vol_series_monthly', 'V^YZ']

    mresults = pd.DataFrame()

    if sample:
        assets = [4295894970, 8589934212]
    else:
        assets = train_df.Asset.unique().tolist()

    for r, asset in enumerate(assets): 

        name = train_df[train_df['Asset'] == asset].iloc[0,-1]

        df_train = train_df[train_df.Asset == asset][cols].dropna()
        df_test = test_df[test_df.Asset == asset][cols].dropna()
        test_size = df_test.shape[0]
        
        X_train = df_train.drop(['V^YZ'], axis=1)
        X_test = df_test.drop(['V^YZ'], axis=1)
        
        y_train = df_train['V^YZ']
        y_test = df_test['V^YZ']
        
        X_train.loc[:, 'const'] = 1
        X_test.loc[:, 'const'] = 1

        # Fit the model
        model = OLS(y_train, X_train)
        model_fit = model.fit()

        # display(X_test, X_train)
        y_pred = model_fit.predict(X_test)
        if cap:
            y_pred = y_pred.clip(lower = 0)
        
        mse_million = mean_squared_error(y_test,y_pred)*10**3
        mresult = pd.DataFrame({
            'Asset': asset,
            'Name': name,
            'Model': algo,
            'Test Size': test_size,
            'MSE^3':mse_million
                    }
            , index=[r]
        )
        mresults = pd.concat([mresults, mresult])

        if viz: 
            vis_line_plot_results(y_pred, y_test, model = 'HAR', dataset=dataset, name=name, r = r)

    return mresults

# %% [markdown]
# ### M1

# %%
mresults_m1 = compile_train_test(train_df, test_df, sample=False, algo='HAR', dataset='m1', viz=False, cap = True)

# %%
mresults_m1.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                                     Name Model  Test Size  \
# 80   4295893846                           Drax Group PLC   HAR          7
# 115  4295895343                 Alliance & Leicester Ltd   HAR          8
# 70   5000683618                               Currys PLC   HAR         12
# 95   4295898951  EDF Energy Nuclear Generation Group Ltd   HAR          8
# 112  4295895499                                 HBOS Plc   HAR         10
# ..          ...                                      ...   ...        ...
# 23   4295874865                                  DCC PLC   HAR         25
# 69   4295893850                                  G4S Ltd   HAR         31
# 64   4295895691                       Alliance Trust PLC   HAR         10
# 68   4295894471                  Amec Foster Wheeler Ltd   HAR         22
# 47   4295894784                                  IMI PLC   HAR         14
#
#          MSE^3
# 80   77.302356
# 115  12.684197
# 70    3.245059
# 95    2.791600
# 112   2.488762
# ..         ...
# 23    0.008105
# 69    0.006133
# 64    0.005973
# 68    0.005971
# 47    0.004465
#
# [160 rows x 5 columns]

# %%
np.mean(mresults_m1['MSE^3'])
# Out:
# 0.7637676752645515

# %%
mresults_m1.to_csv('../Results/2-HAR-M1-24MONTH-LOWER0.csv', index=None)

# %% [markdown]
# ### M3

# %%
mresults_m3 = compile_train_test(train_df, test_df, sample=False, algo='HAR', dataset='m3', viz=False, cap = True)

# %%
mresults_m3.sort_values('MSE^3', ascending=False)
# Out:
#           Asset                          Name Model  Test Size        MSE^3
# 43   4295895717                   Meggitt Ltd   HAR         20  5526.282685
# 142  4295894757                   Cadbury Ltd   HAR         14  5435.397040
# 91   5000047647          Friends Life FPG Ltd   HAR         12    35.745709
# 9    4295894930  Spirax-Sarco Engineering PLC   HAR         14    25.615611
# 10   5001428097                    Entain PLC   HAR         11    21.182973
# ..          ...                           ...   ...        ...          ...
# 92   5000039682    United Utilities Group PLC   HAR         60     0.027488
# 94   5000001291               BAE Systems PLC   HAR         60     0.026897
# 106  4295896447     Abi Sab Group Holding Ltd   HAR         38     0.024991
# 144  4295894753                     Rexam Ltd   HAR         31     0.024385
# 0    5039731355  Pershing Square Holdings Ltd   HAR          7     0.017190
#
# [160 rows x 5 columns]

# %%
np.mean(mresults_m3['MSE^3'])
# Out:
# 69.87159748352417

# %% [markdown]
# ## Version 2
#
# - adding data transformatin log1p
# - transform the data into supervised

# %%
# fit an random forest model and make a one step prediction
def ols_forecast(train, testX, l1_ratio = 0.25):
    # transform list into array
    train = asarray(train)
    # split into input and output columns
    trainX, trainy = train[:, :-1], train[:, -1]

    # scale the dataset
    # scaler = MinMaxScaler()
    # trainX = scaler.fit_transform(pd.DataFrame(trainX))
    # testX = scaler.transform(pd.DataFrame([testX]))
    
    # fit model
    model = OLS(trainy, trainX)
    model_fit = model.fit()
    # make a one-step prediction
    yhat = model_fit.predict([testX])
    return yhat[0]

# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, verbose = True):
    predictions = list()
    # split dataset
    train, test = train_test_split(data, n_test)
    # transform log1p
    train = log1p(train)
    test = log1p(test)
    # seed history with training dataset
    history = [x for x in train]
    # print(history)
    
    # step over each time-step in the test set
    for i in range(len(test)):
        # split test row into input and output columns
        testX, testy = test[i, :-1], test[i, -1]
        # fit model on history and make a prediction
        yhat = ols_forecast(history, testX)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for the next loop
        history.append(test[i])
        # summarize progress
        # print('>expected=%.4f, predicted=%.4f' % (testy, yhat))
        
    # estimate prediction error
    error = mean_squared_error(test[:, -1], predictions) * 10**3
    # error = mean_absolute_error(test[:, -1], predictions)
    
    return error, test[:, -1], predictions

# %%
def compile_train_test(train_df, test_df, sample = True, algo = 'HAR', dataset = 'm1', viz = False, cap = True):
    '''
    '''
    test_perc = .3 

    if dataset == 'm1':
        cols = ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']

    elif dataset == 'm3':
        cols = [ 'buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar'
                ,'CSRStrategy','Community','Emissions','EnvironmentalInnovation','HumanRights','Management','ProductResponsibility'
                ,'ResourceUse','Shareholders','Workforce', 'vol_series_daily','vol_series_weekly','vol_series_monthly', 'V^YZ']

    mresults = pd.DataFrame()

    if sample:
        assets = [4295894970, 8589934212]
    else:
        assets = train_df.Asset.unique().tolist()

    for r, asset in enumerate(assets): 
        # print(asset)
        name = train_df[train_df['Asset'] == asset].iloc[0,-1]

        df_train = train_df[train_df.Asset == asset][cols].dropna()
        df_test = test_df[test_df.Asset == asset][cols].dropna()
        indices = test_df[test_df.Asset == asset].index

        df_merge = pd.concat([df_train, df_test])
        df_merge = series_to_supervised(df_merge, n_in=3, target= ['V^YZ'])
        
        # display(df_merge)
        test_size = int(df_merge.shape[0] * test_perc)
        
        print(f'Execute Training and Walk Forward Testing for ({name}) for {test_size} times..')
        start_time = time.time()
        mse, y, yhat = walk_forward_validation(df_merge, test_size)
        print("---"*10, "%s seconds |"%(time.time() - start_time), 'MSE: %.3f'%mse, "---"*10)
        
        # inverse the log1p.
        y = expm1(y)
        yhat = expm1(yhat)
        
        mresult = pd.DataFrame({
            'Asset': asset,
            'Name': name,
            'Model': algo,
            'Test Size': test_size,
            'MSE^3':mse
                    }
            , index=[r]
        )
        mresults = pd.concat([mresults, mresult])

        if viz: 
            vis_line_plot_results(yhat, y, model = algo, dataset=dataset, name=name, r = r)

    return mresults

# %%
mresults_m1[mresults_m1['Name'].isin(['Bunzl plc', 'Natwest Group PLC'])]
# Out:
#          Asset               Name Model  Test Size     MSE^3
# 62  4295894970          Bunzl plc   HAR         51  0.066712
# 86  8589934212  Natwest Group PLC   HAR         60  0.057812

# %%
ori_har_perf()
# Out:
# m1 datasets: 0.7637676752645515
# m3 datasets: 69.87159748352417

# %%
np.mean(mresults_m1_dev['MSE^3'])
# Out:
# 13.75543135123275

# %%
np.mean(mresults_m3_dev['MSE^3'])
# Out:
# 16.149816685769252

# %%
mresults_m3_dev = compile_train_test(train_df, test_df, sample=False, algo='HAR', dataset='m3', viz=False, cap = True)
# Out:
# Execute Training and Walk Forward Testing for (Pershing Square Holdings Ltd) for 3 times..
# ------------------------------ 0.001497507095336914 seconds | MSE: 0.015 ------------------------------
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 3 times..
# ------------------------------ 0.0013010501861572266 seconds | MSE: 0.024 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 3 times..
# ------------------------------ 0.0012772083282470703 seconds | MSE: 0.498 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 5 times..
# ------------------------------ 0.0022428035736083984 seconds | MSE: 0.036 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 6 times..
# ------------------------------ 0.0029931068420410156 seconds | MSE: 0.360 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 8 times..
# ------------------------------ 0.0032744407653808594 seconds | MSE: 0.695 ------------------------------
# Execute Training and Walk Forward Testing for (JD Sports Fashion PLC) for 8 times..
# ------------------------------ 0.004450798034667969 seconds | MSE: 0.157 ------------------------------
# Execute Training and Walk Forward Testing for (Phoenix Group Holdings PLC) for 9 times..
# ------------------------------ 0.0051767826080322266 seconds | MSE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (Auto Trader Group PLC) for 10 times..
# ------------------------------ 0.0057528018951416016 seconds | MSE: 2.884 ------------------------------
# Execute Training and Walk Forward Testing for (Spirax-Sarco Engineering PLC) for 10 times..
# ------------------------------ 0.0066678524017333984 seconds | MSE: 2.350 ------------------------------
# Execute Training and Walk Forward Testing for (Entain PLC) for 7 times..
# ------------------------------ 0.0038063526153564453 seconds | MSE: 0.942 ------------------------------
# Execute Training and Walk Forward Testing for (Ocado Group PLC) for 12 times..
# ------------------------------ 0.009694814682006836 seconds | MSE: 4.876 ------------------------------
# Execute Training and Walk Forward Testing for (Rightmove PLC) for 12 times..
# ------------------------------ 0.009272336959838867 seconds | MSE: 0.628 ------------------------------
# Execute Training and Walk Forward Testing for (Halma PLC) for 13 times..
# ------------------------------ 0.02014327049255371 seconds | MSE: 0.133 ------------------------------
# Execute Training and Walk Forward Testing for (DS Smith PLC) for 13 times..
# ------------------------------ 0.013170242309570312 seconds | MSE: 171.312 ------------------------------
# Execute Training and Walk Forward Testing for (NMC Health PLC) for 3 times..
# ------------------------------ 0.0012972354888916016 seconds | MSE: 0.534 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish Mortgage Investment Trust PLC) for 16 times..
# ------------------------------ 0.02887749671936035 seconds | MSE: 9.258 ------------------------------
# Execute Training and Walk Forward Testing for (Smurfit Kappa Group PLC) for 17 times..
# ------------------------------ 0.06786370277404785 seconds | MSE: 1.293 ------------------------------
# Execute Training and Walk Forward Testing for (Micro Focus International Ltd) for 6 times..
# ------------------------------ 0.0034558773040771484 seconds | MSE: 0.185 ------------------------------
# Execute Training and Walk Forward Testing for (Informa PLC) for 20 times..
# ------------------------------ 0.1323258876800537 seconds | MSE: 8.704 ------------------------------
# Execute Training and Walk Forward Testing for (Mediclinic Group Ltd) for 3 times..
# ------------------------------ 0.01792764663696289 seconds | MSE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (Flutter Entertainment PLC) for 20 times..
# ------------------------------ 0.06697511672973633 seconds | MSE: 2.554 ------------------------------
# Execute Training and Walk Forward Testing for (Worldpay Group Ltd) for 2 times..
# ------------------------------ 0.016993284225463867 seconds | MSE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (DCC PLC) for 21 times..
# ------------------------------ 0.09968852996826172 seconds | MSE: 23.549 ------------------------------
# Execute Training and Walk Forward Testing for (Berkeley Group Holdings PLC) for 18 times..
# ------------------------------ 0.0636909008026123 seconds | MSE: 5.992 ------------------------------
# Execute Training and Walk Forward Testing for (Merlin Entertainments Ltd) for 4 times..
# ------------------------------ 0.017014503479003906 seconds | MSE: 0.460 ------------------------------
# Execute Training and Walk Forward Testing for (Hikma Pharmaceuticals PLC) for 14 times..
# ------------------------------ 0.029897689819335938 seconds | MSE: 4.413 ------------------------------
# Execute Training and Walk Forward Testing for (TUI AG) for 12 times..
# ------------------------------ 0.007150173187255859 seconds | MSE: 0.224 ------------------------------
# Execute Training and Walk Forward Testing for (Direct Line Insurance Group PLC) for 13 times..
# ------------------------------ 0.012598991394042969 seconds | MSE: 0.304 ------------------------------
# Execute Training and Walk Forward Testing for (St James's Place PLC) for 27 times..
# ------------------------------ 0.08283543586730957 seconds | MSE: 5.018 ------------------------------
# Execute Training and Walk Forward Testing for (International Distributions Services PLC) for 14 times..
# ------------------------------ 0.029484987258911133 seconds | MSE: 8.862 ------------------------------
# Execute Training and Walk Forward Testing for (Ashtead Group PLC) for 28 times..
# ------------------------------ 0.0471498966217041 seconds | MSE: 683.248 ------------------------------
# Execute Training and Walk Forward Testing for (Coca Cola HBC AG) for 29 times..
# ------------------------------ 0.06723594665527344 seconds | MSE: 0.361 ------------------------------
# Execute Training and Walk Forward Testing for (Frasers Group PLC) for 5 times..
# ------------------------------ 0.002487659454345703 seconds | MSE: 0.049 ------------------------------
# Execute Training and Walk Forward Testing for (Mondi PLC) for 29 times..
# ------------------------------ 0.06609654426574707 seconds | MSE: 0.103 ------------------------------
# Execute Training and Walk Forward Testing for (Travis Perkins PLC) for 7 times..
# ------------------------------ 0.004538297653198242 seconds | MSE: 4.691 ------------------------------
# Execute Training and Walk Forward Testing for (Easyjet PLC) for 19 times..
# ------------------------------ 0.04677891731262207 seconds | MSE: 6.308 ------------------------------
# Execute Training and Walk Forward Testing for (Melrose Industries PLC) for 18 times..
# ------------------------------ 0.037561655044555664 seconds | MSE: 1.694 ------------------------------
# Execute Training and Walk Forward Testing for (Babcock International Group PLC) for 15 times..
# ------------------------------ 0.01334691047668457 seconds | MSE: 4.564 ------------------------------
# Execute Training and Walk Forward Testing for (Croda International PLC) for 24 times..
# ------------------------------ 0.051880598068237305 seconds | MSE: 4.709 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn Holdings Ltd) for 9 times..
# ------------------------------ 0.006070613861083984 seconds | MSE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (EVRAZ plc) for 15 times..
# ------------------------------ 0.01658034324645996 seconds | MSE: 1.995 ------------------------------
# Execute Training and Walk Forward Testing for (Polymetal International PLC) for 9 times..
# ------------------------------ 0.005725860595703125 seconds | MSE: 0.942 ------------------------------
# Execute Training and Walk Forward Testing for (Meggitt Ltd) for 15 times..
# ------------------------------ 0.014512062072753906 seconds | MSE: 1.387 ------------------------------
# Execute Training and Walk Forward Testing for (Glencore PLC) for 37 times..
# ------------------------------ 0.08474111557006836 seconds | MSE: 0.269 ------------------------------
# Execute Training and Walk Forward Testing for (Hargreaves Lansdown PLC) for 38 times..
# ------------------------------ 0.08862185478210449 seconds | MSE: 0.231 ------------------------------
# Execute Training and Walk Forward Testing for (International Consolidated Airlines Group SA) for 38 times..
# ------------------------------ 0.08579373359680176 seconds | MSE: 0.396 ------------------------------
# Execute Training and Walk Forward Testing for (IMI PLC) for 9 times..
# ------------------------------ 0.007013559341430664 seconds | MSE: 0.024 ------------------------------
# Execute Training and Walk Forward Testing for (Weir Group PLC) for 15 times..
# ------------------------------ 0.033174991607666016 seconds | MSE: 1.509 ------------------------------
# Execute Training and Walk Forward Testing for (GKN Ltd) for 22 times..
# ------------------------------ 0.041091203689575195 seconds | MSE: 2.208 ------------------------------
# Execute Training and Walk Forward Testing for (SVF Holdco (UK) Ltd) for 18 times..
# ------------------------------ 0.04010581970214844 seconds | MSE: 17.632 ------------------------------
# Execute Training and Walk Forward Testing for (Aggreko Ltd) for 15 times..
# ------------------------------ 0.015243768692016602 seconds | MSE: 0.268 ------------------------------
# Execute Training and Walk Forward Testing for (Friends Life Group Ltd) for 12 times..
# ------------------------------ 0.011291265487670898 seconds | MSE: 0.748 ------------------------------
# Execute Training and Walk Forward Testing for (Burberry Group PLC) for 43 times..
# ------------------------------ 0.10861420631408691 seconds | MSE: 0.144 ------------------------------
# Execute Training and Walk Forward Testing for (Intertek Group PLC) for 44 times..
# ------------------------------ 0.13238120079040527 seconds | MSE: 0.081 ------------------------------
# Execute Training and Walk Forward Testing for (Serco Group PLC) for 12 times..
# ------------------------------ 0.009322643280029297 seconds | MSE: 0.078 ------------------------------
# Execute Training and Walk Forward Testing for (Barrick Gold (Holdings) Ltd) for 31 times..
# ------------------------------ 0.0753023624420166 seconds | MSE: 0.133 ------------------------------
# Execute Training and Walk Forward Testing for (Fresnillo PLC) for 44 times..
# ------------------------------ 0.11856317520141602 seconds | MSE: 0.126 ------------------------------
# Execute Training and Walk Forward Testing for (Inmarsat Group Holdings Ltd) for 10 times..
# ------------------------------ 0.006453752517700195 seconds | MSE: 6.051 ------------------------------
# Execute Training and Walk Forward Testing for (Autonomy Corp Ltd) for 6 times..
# ------------------------------ 0.0023162364959716797 seconds | MSE: 2.196 ------------------------------
# Execute Training and Walk Forward Testing for (Petrofac Ltd) for 17 times..
# ------------------------------ 0.02093672752380371 seconds | MSE: 0.538 ------------------------------
# Execute Training and Walk Forward Testing for (John Wood Group PLC) for 3 times..
# ------------------------------ 0.001857757568359375 seconds | MSE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (Bunzl plc) for 46 times..
# ------------------------------ 0.12183308601379395 seconds | MSE: 0.320 ------------------------------
# Execute Training and Walk Forward Testing for (Cobham Ltd) for 5 times..
# ------------------------------ 0.0020618438720703125 seconds | MSE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance Trust PLC) for 6 times..
# ------------------------------ 0.002125978469848633 seconds | MSE: 0.008 ------------------------------
# Execute Training and Walk Forward Testing for (London Stock Exchange Group PLC) for 38 times..
# ------------------------------ 0.09654545783996582 seconds | MSE: 0.091 ------------------------------
# Execute Training and Walk Forward Testing for (Admiral Group PLC) for 49 times..
# ------------------------------ 0.1849210262298584 seconds | MSE: 0.090 ------------------------------
# Execute Training and Walk Forward Testing for (Tui Travel Ltd) for 14 times..
# ------------------------------ 0.021623849868774414 seconds | MSE: 0.130 ------------------------------
# Execute Training and Walk Forward Testing for (Amec Foster Wheeler Ltd) for 17 times..
# ------------------------------ 0.03338050842285156 seconds | MSE: 0.695 ------------------------------
# Execute Training and Walk Forward Testing for (G4S Ltd) for 27 times..
# ------------------------------ 0.045804500579833984 seconds | MSE: 0.932 ------------------------------
# Execute Training and Walk Forward Testing for (Currys PLC) for 7 times..
# ------------------------------ 0.003904581069946289 seconds | MSE: 5.703 ------------------------------
# Execute Training and Walk Forward Testing for (Tullow Oil PLC) for 22 times..
# ------------------------------ 0.04129934310913086 seconds | MSE: 0.330 ------------------------------
# Execute Training and Walk Forward Testing for (Taylor Wimpey PLC) for 26 times..
# ------------------------------ 0.06299042701721191 seconds | MSE: 7.632 ------------------------------
# Execute Training and Walk Forward Testing for (Barratt Developments P L C) for 27 times..
# ------------------------------ 0.06401228904724121 seconds | MSE: 6.099 ------------------------------
# Execute Training and Walk Forward Testing for (Whitbread PLC) for 52 times..
# ------------------------------ 0.15813922882080078 seconds | MSE: 0.120 ------------------------------
# Execute Training and Walk Forward Testing for (Experian PLC) for 54 times..
# ------------------------------ 0.17230701446533203 seconds | MSE: 0.150 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn PLC) for 53 times..
# ------------------------------ 0.18818092346191406 seconds | MSE: 0.274 ------------------------------
# Execute Training and Walk Forward Testing for (SEGRO PLC) for 22 times..
# ------------------------------ 0.05973339080810547 seconds | MSE: 0.271 ------------------------------
# Execute Training and Walk Forward Testing for (NEX Group Ltd) for 17 times..
# ------------------------------ 0.023482561111450195 seconds | MSE: 1.065 ------------------------------
# Execute Training and Walk Forward Testing for (Sibanye Uk Ltd) for 13 times..
# ------------------------------ 0.012524127960205078 seconds | MSE: 3.727 ------------------------------
# Execute Training and Walk Forward Testing for (Drax Group PLC) for 3 times..
# ------------------------------ 0.0012216567993164062 seconds | MSE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (Aviva PLC) for 56 times..
# ------------------------------ 0.2051403522491455 seconds | MSE: 0.120 ------------------------------
# Execute Training and Walk Forward Testing for (Barclays PLC) for 56 times..
# ------------------------------ 0.2359623908996582 seconds | MSE: 0.329 ------------------------------
# Execute Training and Walk Forward Testing for (HSBC Holdings PLC) for 56 times..
# ------------------------------ 0.21948647499084473 seconds | MSE: 0.113 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 56 times..
# ------------------------------ 0.19124174118041992 seconds | MSE: 0.166 ------------------------------
# Execute Training and Walk Forward Testing for (Prudential PLC) for 56 times..
# ------------------------------ 0.18996810913085938 seconds | MSE: 0.115 ------------------------------
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 56 times..
# ------------------------------ 0.19125795364379883 seconds | MSE: 0.792 ------------------------------
# Execute Training and Walk Forward Testing for (Man Group PLC) for 18 times..
# ------------------------------ 0.06554436683654785 seconds | MSE: 2.243 ------------------------------
# Execute Training and Walk Forward Testing for (WPP PLC) for 56 times..
# ------------------------------ 0.19365978240966797 seconds | MSE: 0.231 ------------------------------
# Execute Training and Walk Forward Testing for (Rolls-Royce Holdings PLC) for 56 times..
# ------------------------------ 0.19871115684509277 seconds | MSE: 0.290 ------------------------------
# Execute Training and Walk Forward Testing for (Cable and Wireless Communications Ltd (Pre-Merger)) for 8 times..
# ------------------------------ 0.003885507583618164 seconds | MSE: 0.314 ------------------------------
# Execute Training and Walk Forward Testing for (Friends Life FPG Ltd) for 8 times..
# ------------------------------ 0.005042552947998047 seconds | MSE: 0.297 ------------------------------
# Execute Training and Walk Forward Testing for (United Utilities Group PLC) for 56 times..
# ------------------------------ 0.19538307189941406 seconds | MSE: 0.040 ------------------------------
# Execute Training and Walk Forward Testing for (Xstrata Ltd) for 21 times..
# ------------------------------ 0.058216094970703125 seconds | MSE: 8.369 ------------------------------
# Execute Training and Walk Forward Testing for (BAE Systems PLC) for 56 times..
# ------------------------------ 0.19715595245361328 seconds | MSE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (EDF Energy Nuclear Generation Group Ltd) for 3 times..
# ------------------------------ 0.0013384819030761719 seconds | MSE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (Sage Group PLC) for 56 times..
# ------------------------------ 0.4076664447784424 seconds | MSE: 0.069 ------------------------------
# Execute Training and Walk Forward Testing for (Capita PLC) for 35 times..
# ------------------------------ 0.19055938720703125 seconds | MSE: 0.257 ------------------------------
# Execute Training and Walk Forward Testing for (Antofagasta PLC) for 56 times..
# ------------------------------ 0.20673036575317383 seconds | MSE: 0.105 ------------------------------
# Execute Training and Walk Forward Testing for (ITV PLC) for 41 times..
# ------------------------------ 0.09840178489685059 seconds | MSE: 0.383 ------------------------------
# Execute Training and Walk Forward Testing for (WM Morrison Supermarkets Ltd) for 48 times..
# ------------------------------ 0.15430831909179688 seconds | MSE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (Sky Ltd) for 40 times..
# ------------------------------ 0.10685539245605469 seconds | MSE: 0.290 ------------------------------
# Execute Training and Walk Forward Testing for (Vodafone Group PLC) for 56 times..
# ------------------------------ 0.19554448127746582 seconds | MSE: 0.098 ------------------------------
# Execute Training and Walk Forward Testing for (Severn Trent PLC) for 56 times..
# ------------------------------ 0.3221907615661621 seconds | MSE: 0.031 ------------------------------
# Execute Training and Walk Forward Testing for (Thomson Reuters UK Ltd) for 8 times..
# ------------------------------ 0.004662275314331055 seconds | MSE: 0.151 ------------------------------
# Execute Training and Walk Forward Testing for (Anglo American PLC) for 56 times..
# ------------------------------ 0.22619032859802246 seconds | MSE: 0.117 ------------------------------
# Execute Training and Walk Forward Testing for (Abi Sab Group Holding Ltd) for 33 times..
# ------------------------------ 0.06547117233276367 seconds | MSE: 0.054 ------------------------------
# Execute Training and Walk Forward Testing for (Carnival PLC) for 46 times..
# ------------------------------ 0.13093948364257812 seconds | MSE: 0.427 ------------------------------
# Execute Training and Walk Forward Testing for (Kingfisher PLC) for 55 times..
# ------------------------------ 0.17900633811950684 seconds | MSE: 0.123 ------------------------------
# Execute Training and Walk Forward Testing for (3i Group PLC) for 45 times..
# ------------------------------ 0.12610626220703125 seconds | MSE: 0.163 ------------------------------
# Execute Training and Walk Forward Testing for (GSK plc) for 56 times..
# ------------------------------ 0.19307684898376465 seconds | MSE: 0.047 ------------------------------
# Execute Training and Walk Forward Testing for (Next PLC) for 56 times..
# ------------------------------ 0.1697101593017578 seconds | MSE: 0.164 ------------------------------
# Execute Training and Walk Forward Testing for (HBOS Plc) for 5 times..
# ------------------------------ 0.0024383068084716797 seconds | MSE: 5.606 ------------------------------
# Execute Training and Walk Forward Testing for (BT Group PLC) for 56 times..
# ------------------------------ 0.19249200820922852 seconds | MSE: 0.085 ------------------------------
# Execute Training and Walk Forward Testing for (Compass Group PLC) for 56 times..
# ------------------------------ 0.1996016502380371 seconds | MSE: 0.121 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance & Leicester Ltd) for 3 times..
# ------------------------------ 0.005809307098388672 seconds | MSE: 0.226 ------------------------------
# Execute Training and Walk Forward Testing for (Tesco PLC) for 56 times..
# ------------------------------ 0.19576501846313477 seconds | MSE: 0.057 ------------------------------
# Execute Training and Walk Forward Testing for (RSA Insurance Group Ltd) for 50 times..
# ------------------------------ 0.19035100936889648 seconds | MSE: 0.129 ------------------------------
# Execute Training and Walk Forward Testing for (Standard Chartered PLC) for 56 times..
# ------------------------------ 0.24592947959899902 seconds | MSE: 0.076 ------------------------------
# Execute Training and Walk Forward Testing for (Smith & Nephew PLC) for 56 times..
# ------------------------------ 0.15801668167114258 seconds | MSE: 0.057 ------------------------------
# Execute Training and Walk Forward Testing for (Smiths Group PLC) for 55 times..
# ------------------------------ 0.16866087913513184 seconds | MSE: 0.086 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish & Newcastle Ltd) for 3 times..
# ------------------------------ 0.0011982917785644531 seconds | MSE: 0.102 ------------------------------
# Execute Training and Walk Forward Testing for (Schroders PLC) for 54 times..
# ------------------------------ 0.1636650562286377 seconds | MSE: 0.182 ------------------------------
# Execute Training and Walk Forward Testing for (J Sainsbury PLC) for 56 times..
# ------------------------------ 0.17546701431274414 seconds | MSE: 0.124 ------------------------------
# Execute Training and Walk Forward Testing for (Hammerson PLC) for 38 times..
# ------------------------------ 0.09247756004333496 seconds | MSE: 0.266 ------------------------------
# Execute Training and Walk Forward Testing for (Marks and Spencer Group PLC) for 44 times..
# ------------------------------ 0.08024334907531738 seconds | MSE: 0.509 ------------------------------
# Execute Training and Walk Forward Testing for (Legal & General Group PLC) for 56 times..
# ------------------------------ 0.20425987243652344 seconds | MSE: 0.341 ------------------------------
# Execute Training and Walk Forward Testing for (Land Securities Group PLC) for 56 times..
# ------------------------------ 0.17301249504089355 seconds | MSE: 0.100 ------------------------------
# Execute Training and Walk Forward Testing for (British Airways PLC) for 12 times..
# ------------------------------ 0.010706424713134766 seconds | MSE: 0.289 ------------------------------
# Execute Training and Walk Forward Testing for (BG Group Ltd) for 31 times..
# ------------------------------ 0.08015108108520508 seconds | MSE: 0.284 ------------------------------
# Execute Training and Walk Forward Testing for (Associated British Foods PLC) for 56 times..
# ------------------------------ 0.18979239463806152 seconds | MSE: 0.098 ------------------------------
# Execute Training and Walk Forward Testing for (British Land Company PLC) for 56 times..
# ------------------------------ 0.18024754524230957 seconds | MSE: 0.062 ------------------------------
# Execute Training and Walk Forward Testing for (BHP Group (UK) Ltd) for 52 times..
# ------------------------------ 0.14063382148742676 seconds | MSE: 0.086 ------------------------------
# Execute Training and Walk Forward Testing for (Pearson PLC) for 56 times..
# ------------------------------ 0.17806577682495117 seconds | MSE: 0.066 ------------------------------
# Execute Training and Walk Forward Testing for (Diageo PLC) for 56 times..
# ------------------------------ 0.19146513938903809 seconds | MSE: 0.353 ------------------------------
# Execute Training and Walk Forward Testing for (Johnson Matthey PLC) for 52 times..
# ------------------------------ 0.1737973690032959 seconds | MSE: 0.102 ------------------------------
# Execute Training and Walk Forward Testing for (Rio Tinto PLC) for 56 times..
# ------------------------------ 0.1911323070526123 seconds | MSE: 0.277 ------------------------------
# Execute Training and Walk Forward Testing for (British American Tobacco PLC) for 56 times..
# ------------------------------ 0.1882343292236328 seconds | MSE: 0.074 ------------------------------
# Execute Training and Walk Forward Testing for (Unilever PLC) for 56 times..
# ------------------------------ 0.18587803840637207 seconds | MSE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (Relx PLC) for 56 times..
# ------------------------------ 0.1958014965057373 seconds | MSE: 0.100 ------------------------------
# Execute Training and Walk Forward Testing for (InterContinental Hotels Group PLC) for 56 times..
# ------------------------------ 0.1581707000732422 seconds | MSE: 0.170 ------------------------------
# Execute Training and Walk Forward Testing for (Tate & Lyle PLC) for 12 times..
# ------------------------------ 0.019544124603271484 seconds | MSE: 0.325 ------------------------------
# Execute Training and Walk Forward Testing for (Cadbury Ltd) for 9 times..
# ------------------------------ 0.005974769592285156 seconds | MSE: 2.509 ------------------------------
# Execute Training and Walk Forward Testing for (Reckitt Benckiser Group PLC) for 56 times..
# ------------------------------ 0.15747928619384766 seconds | MSE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (Rexam Ltd) for 27 times..
# ------------------------------ 0.09500503540039062 seconds | MSE: 0.191 ------------------------------
# Execute Training and Walk Forward Testing for (BP PLC) for 56 times..
# ------------------------------ 0.1680915355682373 seconds | MSE: 0.112 ------------------------------
# Execute Training and Walk Forward Testing for (Centrica PLC) for 48 times..
# ------------------------------ 0.14405083656311035 seconds | MSE: 0.154 ------------------------------
# Execute Training and Walk Forward Testing for (Shire Ltd) for 41 times..
# ------------------------------ 0.09850358963012695 seconds | MSE: 0.344 ------------------------------
# Execute Training and Walk Forward Testing for (Imperial Brands PLC) for 56 times..
# ------------------------------ 0.18965363502502441 seconds | MSE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (Ei Group Ltd) for 4 times..
# ------------------------------ 0.0015997886657714844 seconds | MSE: 1.009 ------------------------------
# Execute Training and Walk Forward Testing for (Rentokil Initial PLC) for 20 times..
# ------------------------------ 0.037453413009643555 seconds | MSE: 28.218 ------------------------------
# Execute Training and Walk Forward Testing for (National Grid PLC) for 56 times..
# ------------------------------ 0.20216059684753418 seconds | MSE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (Home Retail Group Ltd) for 9 times..
# ------------------------------ 0.005377292633056641 seconds | MSE: 0.074 ------------------------------
# Execute Training and Walk Forward Testing for (AstraZeneca PLC) for 56 times..
# ------------------------------ 0.19575929641723633 seconds | MSE: 0.055 ------------------------------
# Execute Training and Walk Forward Testing for (Intu Properties PLC) for 31 times..
# ------------------------------ 0.07602643966674805 seconds | MSE: 2.193 ------------------------------
# Execute Training and Walk Forward Testing for (SSE PLC) for 56 times..
# ------------------------------ 0.21635055541992188 seconds | MSE: 0.094 ------------------------------
# Execute Training and Walk Forward Testing for (International Power Ltd) for 18 times..
# ------------------------------ 0.024669647216796875 seconds | MSE: 1483.353 ------------------------------
# Execute Training and Walk Forward Testing for (Capricorn Energy PLC) for 14 times..
# ------------------------------ 0.039437294006347656 seconds | MSE: 6.834 ------------------------------
# Execute Training and Walk Forward Testing for (Persimmon PLC) for 38 times..
# ------------------------------ 0.05786919593811035 seconds | MSE: 5.257 ------------------------------
# Execute Training and Walk Forward Testing for (Shell PLC) for 56 times..
# ------------------------------ 0.19937372207641602 seconds | MSE: 0.154 ------------------------------

# %%
mresults_m1_dev = compile_train_test(train_df, test_df, sample=False, algo='HAR', dataset='m1', viz=False, cap = True)
# Out:
# Execute Training and Walk Forward Testing for (Pershing Square Holdings Ltd) for 3 times..
# ------------------------------ 0.0012123584747314453 seconds | MSE: 0.041 ------------------------------
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 3 times..
# ------------------------------ 0.0012063980102539062 seconds | MSE: 1.030 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 3 times..
# ------------------------------ 0.0010819435119628906 seconds | MSE: 4.144 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 5 times..
# ------------------------------ 0.0016472339630126953 seconds | MSE: 0.108 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 6 times..
# ------------------------------ 0.002547025680541992 seconds | MSE: 0.071 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 8 times..
# ------------------------------ 0.002335071563720703 seconds | MSE: 1.477 ------------------------------
# Execute Training and Walk Forward Testing for (JD Sports Fashion PLC) for 8 times..
# ------------------------------ 0.002326488494873047 seconds | MSE: 0.117 ------------------------------
# Execute Training and Walk Forward Testing for (Phoenix Group Holdings PLC) for 9 times..
# ------------------------------ 0.002627134323120117 seconds | MSE: 0.012 ------------------------------
# Execute Training and Walk Forward Testing for (Auto Trader Group PLC) for 10 times..
# ------------------------------ 0.0027942657470703125 seconds | MSE: 0.028 ------------------------------
# Execute Training and Walk Forward Testing for (Spirax-Sarco Engineering PLC) for 10 times..
# ------------------------------ 0.0028204917907714844 seconds | MSE: 0.021 ------------------------------
# Execute Training and Walk Forward Testing for (Entain PLC) for 7 times..
# ------------------------------ 0.0021059513092041016 seconds | MSE: 0.073 ------------------------------
# Execute Training and Walk Forward Testing for (Ocado Group PLC) for 12 times..
# ------------------------------ 0.003519296646118164 seconds | MSE: 0.088 ------------------------------
# Execute Training and Walk Forward Testing for (Rightmove PLC) for 12 times..
# ------------------------------ 0.0034613609313964844 seconds | MSE: 0.047 ------------------------------
# Execute Training and Walk Forward Testing for (Halma PLC) for 13 times..
# ------------------------------ 0.003720998764038086 seconds | MSE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (DS Smith PLC) for 13 times..
# ------------------------------ 0.004024028778076172 seconds | MSE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (NMC Health PLC) for 3 times..
# ------------------------------ 0.0010344982147216797 seconds | MSE: 24.391 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish Mortgage Investment Trust PLC) for 16 times..
# ------------------------------ 0.00463414192199707 seconds | MSE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (Smurfit Kappa Group PLC) for 17 times..
# ------------------------------ 0.0049288272857666016 seconds | MSE: 0.023 ------------------------------
# Execute Training and Walk Forward Testing for (Micro Focus International Ltd) for 6 times..
# ------------------------------ 0.0017516613006591797 seconds | MSE: 3.035 ------------------------------
# Execute Training and Walk Forward Testing for (Informa PLC) for 20 times..
# ------------------------------ 0.0058171749114990234 seconds | MSE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (Mediclinic Group Ltd) for 3 times..
# ------------------------------ 0.0009477138519287109 seconds | MSE: 0.194 ------------------------------
# Execute Training and Walk Forward Testing for (Flutter Entertainment PLC) for 20 times..
# ------------------------------ 0.005666017532348633 seconds | MSE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Worldpay Group Ltd) for 2 times..
# ------------------------------ 0.0007483959197998047 seconds | MSE: 195.060 ------------------------------
# Execute Training and Walk Forward Testing for (DCC PLC) for 21 times..
# ------------------------------ 0.006756782531738281 seconds | MSE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (Berkeley Group Holdings PLC) for 18 times..
# ------------------------------ 0.005578517913818359 seconds | MSE: 0.023 ------------------------------
# Execute Training and Walk Forward Testing for (Merlin Entertainments Ltd) for 4 times..
# ------------------------------ 0.0012543201446533203 seconds | MSE: 0.529 ------------------------------
# Execute Training and Walk Forward Testing for (Hikma Pharmaceuticals PLC) for 14 times..
# ------------------------------ 0.0040323734283447266 seconds | MSE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (TUI AG) for 12 times..
# ------------------------------ 0.003476381301879883 seconds | MSE: 0.064 ------------------------------
# Execute Training and Walk Forward Testing for (Direct Line Insurance Group PLC) for 13 times..
# ------------------------------ 0.003878355026245117 seconds | MSE: 0.018 ------------------------------
# Execute Training and Walk Forward Testing for (St James's Place PLC) for 27 times..
# ------------------------------ 0.00830698013305664 seconds | MSE: 0.018 ------------------------------
# Execute Training and Walk Forward Testing for (International Distributions Services PLC) for 14 times..
# ------------------------------ 0.004156589508056641 seconds | MSE: 0.076 ------------------------------
# Execute Training and Walk Forward Testing for (Ashtead Group PLC) for 28 times..
# ------------------------------ 0.008941411972045898 seconds | MSE: 0.102 ------------------------------
# Execute Training and Walk Forward Testing for (Coca Cola HBC AG) for 29 times..
# ------------------------------ 0.009198904037475586 seconds | MSE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (Frasers Group PLC) for 5 times..
# ------------------------------ 0.0017962455749511719 seconds | MSE: 2.328 ------------------------------
# Execute Training and Walk Forward Testing for (Mondi PLC) for 29 times..
# ------------------------------ 0.009862422943115234 seconds | MSE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Travis Perkins PLC) for 7 times..
# ------------------------------ 0.0024929046630859375 seconds | MSE: 196.868 ------------------------------
# Execute Training and Walk Forward Testing for (Easyjet PLC) for 19 times..
# ------------------------------ 0.005820035934448242 seconds | MSE: 0.261 ------------------------------
# Execute Training and Walk Forward Testing for (Melrose Industries PLC) for 18 times..
# ------------------------------ 0.0052032470703125 seconds | MSE: 0.075 ------------------------------
# Execute Training and Walk Forward Testing for (Babcock International Group PLC) for 15 times..
# ------------------------------ 0.004512310028076172 seconds | MSE: 0.251 ------------------------------
# Execute Training and Walk Forward Testing for (Croda International PLC) for 24 times..
# ------------------------------ 0.008298635482788086 seconds | MSE: 0.018 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn Holdings Ltd) for 9 times..
# ------------------------------ 0.0028815269470214844 seconds | MSE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (EVRAZ plc) for 15 times..
# ------------------------------ 0.004735708236694336 seconds | MSE: 0.422 ------------------------------
# Execute Training and Walk Forward Testing for (Polymetal International PLC) for 9 times..
# ------------------------------ 0.003006458282470703 seconds | MSE: 1.389 ------------------------------
# Execute Training and Walk Forward Testing for (Meggitt Ltd) for 15 times..
# ------------------------------ 0.004325389862060547 seconds | MSE: 0.689 ------------------------------
# Execute Training and Walk Forward Testing for (Glencore PLC) for 37 times..
# ------------------------------ 0.011229991912841797 seconds | MSE: 0.121 ------------------------------
# Execute Training and Walk Forward Testing for (Hargreaves Lansdown PLC) for 38 times..
# ------------------------------ 0.011591672897338867 seconds | MSE: 0.100 ------------------------------
# Execute Training and Walk Forward Testing for (International Consolidated Airlines Group SA) for 38 times..
# ------------------------------ 0.011472940444946289 seconds | MSE: 0.252 ------------------------------
# Execute Training and Walk Forward Testing for (IMI PLC) for 9 times..
# ------------------------------ 0.002471446990966797 seconds | MSE: 0.007 ------------------------------
# Execute Training and Walk Forward Testing for (Weir Group PLC) for 15 times..
# ------------------------------ 0.00423884391784668 seconds | MSE: 0.014 ------------------------------
# Execute Training and Walk Forward Testing for (GKN Ltd) for 22 times..
# ------------------------------ 0.006394147872924805 seconds | MSE: 0.037 ------------------------------
# Execute Training and Walk Forward Testing for (SVF Holdco (UK) Ltd) for 18 times..
# ------------------------------ 0.005025386810302734 seconds | MSE: 0.523 ------------------------------
# Execute Training and Walk Forward Testing for (Aggreko Ltd) for 15 times..
# ------------------------------ 0.0041582584381103516 seconds | MSE: 0.006 ------------------------------
# Execute Training and Walk Forward Testing for (Friends Life Group Ltd) for 12 times..
# ------------------------------ 0.003326416015625 seconds | MSE: 0.113 ------------------------------
# Execute Training and Walk Forward Testing for (Burberry Group PLC) for 43 times..
# ------------------------------ 0.014093399047851562 seconds | MSE: 0.047 ------------------------------
# Execute Training and Walk Forward Testing for (Intertek Group PLC) for 44 times..
# ------------------------------ 0.014060735702514648 seconds | MSE: 0.070 ------------------------------
# Execute Training and Walk Forward Testing for (Serco Group PLC) for 12 times..
# ------------------------------ 0.0033495426177978516 seconds | MSE: 0.018 ------------------------------
# Execute Training and Walk Forward Testing for (Barrick Gold (Holdings) Ltd) for 31 times..
# ------------------------------ 0.009487152099609375 seconds | MSE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Fresnillo PLC) for 44 times..
# ------------------------------ 0.0146636962890625 seconds | MSE: 0.056 ------------------------------
# Execute Training and Walk Forward Testing for (Inmarsat Group Holdings Ltd) for 10 times..
# ------------------------------ 0.002958059310913086 seconds | MSE: 0.157 ------------------------------
# Execute Training and Walk Forward Testing for (Autonomy Corp Ltd) for 6 times..
# ------------------------------ 0.001750946044921875 seconds | MSE: 2.019 ------------------------------
# Execute Training and Walk Forward Testing for (Petrofac Ltd) for 17 times..
# ------------------------------ 0.004720449447631836 seconds | MSE: 0.107 ------------------------------
# Execute Training and Walk Forward Testing for (John Wood Group PLC) for 3 times..
# ------------------------------ 0.0010471343994140625 seconds | MSE: 5.709 ------------------------------
# Execute Training and Walk Forward Testing for (Bunzl plc) for 46 times..
# ------------------------------ 0.014851808547973633 seconds | MSE: 0.168 ------------------------------
# Execute Training and Walk Forward Testing for (Cobham Ltd) for 5 times..
# ------------------------------ 0.001649618148803711 seconds | MSE: 0.209 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance Trust PLC) for 6 times..
# ------------------------------ 0.0018429756164550781 seconds | MSE: 0.002 ------------------------------
# Execute Training and Walk Forward Testing for (London Stock Exchange Group PLC) for 38 times..
# ------------------------------ 0.01200413703918457 seconds | MSE: 0.060 ------------------------------
# Execute Training and Walk Forward Testing for (Admiral Group PLC) for 49 times..
# ------------------------------ 0.01628255844116211 seconds | MSE: 0.043 ------------------------------
# Execute Training and Walk Forward Testing for (Tui Travel Ltd) for 14 times..
# ------------------------------ 0.004354000091552734 seconds | MSE: 0.016 ------------------------------
# Execute Training and Walk Forward Testing for (Amec Foster Wheeler Ltd) for 17 times..
# ------------------------------ 0.005030155181884766 seconds | MSE: 0.004 ------------------------------
# Execute Training and Walk Forward Testing for (G4S Ltd) for 27 times..
# ------------------------------ 0.008085489273071289 seconds | MSE: 0.007 ------------------------------
# Execute Training and Walk Forward Testing for (Currys PLC) for 7 times..
# ------------------------------ 0.002124309539794922 seconds | MSE: 484.565 ------------------------------
# Execute Training and Walk Forward Testing for (Tullow Oil PLC) for 22 times..
# ------------------------------ 0.006335258483886719 seconds | MSE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (Taylor Wimpey PLC) for 26 times..
# ------------------------------ 0.0074574947357177734 seconds | MSE: 0.021 ------------------------------
# Execute Training and Walk Forward Testing for (Barratt Developments P L C) for 27 times..
# ------------------------------ 0.01059865951538086 seconds | MSE: 0.022 ------------------------------
# Execute Training and Walk Forward Testing for (Whitbread PLC) for 52 times..
# ------------------------------ 0.01888871192932129 seconds | MSE: 0.090 ------------------------------
# Execute Training and Walk Forward Testing for (Experian PLC) for 54 times..
# ------------------------------ 0.0180206298828125 seconds | MSE: 0.118 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn PLC) for 53 times..
# ------------------------------ 0.017390966415405273 seconds | MSE: 0.093 ------------------------------
# Execute Training and Walk Forward Testing for (SEGRO PLC) for 22 times..
# ------------------------------ 0.0066263675689697266 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (NEX Group Ltd) for 17 times..
# ------------------------------ 0.004917144775390625 seconds | MSE: 0.023 ------------------------------
# Execute Training and Walk Forward Testing for (Sibanye Uk Ltd) for 13 times..
# ------------------------------ 0.003998994827270508 seconds | MSE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Drax Group PLC) for 3 times..
# ------------------------------ 0.0010581016540527344 seconds | MSE: 39.055 ------------------------------
# Execute Training and Walk Forward Testing for (Aviva PLC) for 56 times..
# ------------------------------ 0.020641565322875977 seconds | MSE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Barclays PLC) for 56 times..
# ------------------------------ 0.02075481414794922 seconds | MSE: 0.146 ------------------------------
# Execute Training and Walk Forward Testing for (HSBC Holdings PLC) for 56 times..
# ------------------------------ 0.019234657287597656 seconds | MSE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 56 times..
# ------------------------------ 0.01978778839111328 seconds | MSE: 0.095 ------------------------------
# Execute Training and Walk Forward Testing for (Prudential PLC) for 56 times..
# ------------------------------ 0.018988609313964844 seconds | MSE: 0.102 ------------------------------
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 56 times..
# ------------------------------ 0.019276857376098633 seconds | MSE: 0.064 ------------------------------
# Execute Training and Walk Forward Testing for (Man Group PLC) for 18 times..
# ------------------------------ 0.005031585693359375 seconds | MSE: 0.040 ------------------------------
# Execute Training and Walk Forward Testing for (WPP PLC) for 56 times..
# ------------------------------ 0.018439054489135742 seconds | MSE: 0.052 ------------------------------
# Execute Training and Walk Forward Testing for (Rolls-Royce Holdings PLC) for 56 times..
# ------------------------------ 0.018440723419189453 seconds | MSE: 0.251 ------------------------------
# Execute Training and Walk Forward Testing for (Cable and Wireless Communications Ltd (Pre-Merger)) for 8 times..
# ------------------------------ 0.002237081527709961 seconds | MSE: 0.214 ------------------------------
# Execute Training and Walk Forward Testing for (Friends Life FPG Ltd) for 8 times..
# ------------------------------ 0.0023179054260253906 seconds | MSE: 1.793 ------------------------------
# Execute Training and Walk Forward Testing for (United Utilities Group PLC) for 56 times..
# ------------------------------ 0.019150972366333008 seconds | MSE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (Xstrata Ltd) for 21 times..
# ------------------------------ 0.006180524826049805 seconds | MSE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (BAE Systems PLC) for 56 times..
# ------------------------------ 0.018918275833129883 seconds | MSE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (EDF Energy Nuclear Generation Group Ltd) for 3 times..
# ------------------------------ 0.0010683536529541016 seconds | MSE: 1.623 ------------------------------
# Execute Training and Walk Forward Testing for (Sage Group PLC) for 56 times..
# ------------------------------ 0.018937349319458008 seconds | MSE: 0.031 ------------------------------
# Execute Training and Walk Forward Testing for (Capita PLC) for 35 times..
# ------------------------------ 0.011457681655883789 seconds | MSE: 0.149 ------------------------------
# Execute Training and Walk Forward Testing for (Antofagasta PLC) for 56 times..
# ------------------------------ 0.02071237564086914 seconds | MSE: 0.039 ------------------------------
# Execute Training and Walk Forward Testing for (ITV PLC) for 41 times..
# ------------------------------ 0.013813018798828125 seconds | MSE: 0.154 ------------------------------
# Execute Training and Walk Forward Testing for (WM Morrison Supermarkets Ltd) for 48 times..
# ------------------------------ 0.016479969024658203 seconds | MSE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (Sky Ltd) for 40 times..
# ------------------------------ 0.012935400009155273 seconds | MSE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (Vodafone Group PLC) for 56 times..
# ------------------------------ 0.02001214027404785 seconds | MSE: 0.063 ------------------------------
# Execute Training and Walk Forward Testing for (Severn Trent PLC) for 56 times..
# ------------------------------ 0.018903255462646484 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Thomson Reuters UK Ltd) for 8 times..
# ------------------------------ 0.002389192581176758 seconds | MSE: 0.218 ------------------------------
# Execute Training and Walk Forward Testing for (Anglo American PLC) for 56 times..
# ------------------------------ 0.02049398422241211 seconds | MSE: 0.066 ------------------------------
# Execute Training and Walk Forward Testing for (Abi Sab Group Holding Ltd) for 33 times..
# ------------------------------ 0.011403083801269531 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Carnival PLC) for 46 times..
# ------------------------------ 0.017493486404418945 seconds | MSE: 0.177 ------------------------------
# Execute Training and Walk Forward Testing for (Kingfisher PLC) for 55 times..
# ------------------------------ 0.018468141555786133 seconds | MSE: 0.117 ------------------------------
# Execute Training and Walk Forward Testing for (3i Group PLC) for 45 times..
# ------------------------------ 0.014323711395263672 seconds | MSE: 0.078 ------------------------------
# Execute Training and Walk Forward Testing for (GSK plc) for 56 times..
# ------------------------------ 0.01872420310974121 seconds | MSE: 0.036 ------------------------------
# Execute Training and Walk Forward Testing for (Next PLC) for 56 times..
# ------------------------------ 0.018904685974121094 seconds | MSE: 0.091 ------------------------------
# Execute Training and Walk Forward Testing for (HBOS Plc) for 5 times..
# ------------------------------ 0.002123594284057617 seconds | MSE: 433.047 ------------------------------
# Execute Training and Walk Forward Testing for (BT Group PLC) for 56 times..
# ------------------------------ 0.0186309814453125 seconds | MSE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (Compass Group PLC) for 56 times..
# ------------------------------ 0.01855158805847168 seconds | MSE: 0.145 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance & Leicester Ltd) for 3 times..
# ------------------------------ 0.0009655952453613281 seconds | MSE: 785.684 ------------------------------
# Execute Training and Walk Forward Testing for (Tesco PLC) for 56 times..
# ------------------------------ 0.0184783935546875 seconds | MSE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (RSA Insurance Group Ltd) for 50 times..
# ------------------------------ 0.01608133316040039 seconds | MSE: 0.074 ------------------------------
# Execute Training and Walk Forward Testing for (Standard Chartered PLC) for 56 times..
# ------------------------------ 0.01903223991394043 seconds | MSE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (Smith & Nephew PLC) for 56 times..
# ------------------------------ 0.01877427101135254 seconds | MSE: 0.037 ------------------------------
# Execute Training and Walk Forward Testing for (Smiths Group PLC) for 55 times..
# ------------------------------ 0.01849079132080078 seconds | MSE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish & Newcastle Ltd) for 3 times..
# ------------------------------ 0.001085519790649414 seconds | MSE: 3.515 ------------------------------
# Execute Training and Walk Forward Testing for (Schroders PLC) for 54 times..
# ------------------------------ 0.018909692764282227 seconds | MSE: 0.158 ------------------------------
# Execute Training and Walk Forward Testing for (J Sainsbury PLC) for 56 times..
# ------------------------------ 0.019479751586914062 seconds | MSE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (Hammerson PLC) for 38 times..
# ------------------------------ 0.01188969612121582 seconds | MSE: 0.336 ------------------------------
# Execute Training and Walk Forward Testing for (Marks and Spencer Group PLC) for 44 times..
# ------------------------------ 0.01455831527709961 seconds | MSE: 0.256 ------------------------------
# Execute Training and Walk Forward Testing for (Legal & General Group PLC) for 56 times..
# ------------------------------ 0.019011497497558594 seconds | MSE: 0.117 ------------------------------
# Execute Training and Walk Forward Testing for (Land Securities Group PLC) for 56 times..
# ------------------------------ 0.019507646560668945 seconds | MSE: 0.037 ------------------------------
# Execute Training and Walk Forward Testing for (British Airways PLC) for 12 times..
# ------------------------------ 0.0040128231048583984 seconds | MSE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (BG Group Ltd) for 31 times..
# ------------------------------ 0.009504556655883789 seconds | MSE: 0.209 ------------------------------
# Execute Training and Walk Forward Testing for (Associated British Foods PLC) for 56 times..
# ------------------------------ 0.019502639770507812 seconds | MSE: 0.038 ------------------------------
# Execute Training and Walk Forward Testing for (British Land Company PLC) for 56 times..
# ------------------------------ 0.01898193359375 seconds | MSE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (BHP Group (UK) Ltd) for 52 times..
# ------------------------------ 0.017902374267578125 seconds | MSE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Pearson PLC) for 56 times..
# ------------------------------ 0.02109074592590332 seconds | MSE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (Diageo PLC) for 56 times..
# ------------------------------ 0.020338058471679688 seconds | MSE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Johnson Matthey PLC) for 52 times..
# ------------------------------ 0.018453359603881836 seconds | MSE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (Rio Tinto PLC) for 56 times..
# ------------------------------ 0.01880025863647461 seconds | MSE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (British American Tobacco PLC) for 56 times..
# ------------------------------ 0.018291950225830078 seconds | MSE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Unilever PLC) for 56 times..
# ------------------------------ 0.01839160919189453 seconds | MSE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (Relx PLC) for 56 times..
# ------------------------------ 0.019235849380493164 seconds | MSE: 0.022 ------------------------------
# Execute Training and Walk Forward Testing for (InterContinental Hotels Group PLC) for 56 times..
# ------------------------------ 0.018393516540527344 seconds | MSE: 0.075 ------------------------------
# Execute Training and Walk Forward Testing for (Tate & Lyle PLC) for 12 times..
# ------------------------------ 0.0034792423248291016 seconds | MSE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (Cadbury Ltd) for 9 times..
# ------------------------------ 0.0026323795318603516 seconds | MSE: 0.376 ------------------------------
# Execute Training and Walk Forward Testing for (Reckitt Benckiser Group PLC) for 56 times..
# ------------------------------ 0.0182645320892334 seconds | MSE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (Rexam Ltd) for 27 times..
# ------------------------------ 0.00767064094543457 seconds | MSE: 0.008 ------------------------------
# Execute Training and Walk Forward Testing for (BP PLC) for 56 times..
# ------------------------------ 0.018981218338012695 seconds | MSE: 0.120 ------------------------------
# Execute Training and Walk Forward Testing for (Centrica PLC) for 48 times..
# ------------------------------ 0.015946388244628906 seconds | MSE: 0.126 ------------------------------
# Execute Training and Walk Forward Testing for (Shire Ltd) for 41 times..
# ------------------------------ 0.012893915176391602 seconds | MSE: 0.249 ------------------------------
# Execute Training and Walk Forward Testing for (Imperial Brands PLC) for 56 times..
# ------------------------------ 0.019261598587036133 seconds | MSE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (Ei Group Ltd) for 4 times..
# ------------------------------ 0.0013210773468017578 seconds | MSE: 1.500 ------------------------------
# Execute Training and Walk Forward Testing for (Rentokil Initial PLC) for 20 times..
# ------------------------------ 0.0057108402252197266 seconds | MSE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (National Grid PLC) for 56 times..
# ------------------------------ 0.019314289093017578 seconds | MSE: 0.023 ------------------------------
# Execute Training and Walk Forward Testing for (Home Retail Group Ltd) for 9 times..
# ------------------------------ 0.0025780200958251953 seconds | MSE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (AstraZeneca PLC) for 56 times..
# ------------------------------ 0.018349885940551758 seconds | MSE: 0.037 ------------------------------
# Execute Training and Walk Forward Testing for (Intu Properties PLC) for 31 times..
# ------------------------------ 0.009333610534667969 seconds | MSE: 0.031 ------------------------------
# Execute Training and Walk Forward Testing for (SSE PLC) for 56 times..
# ------------------------------ 0.018796682357788086 seconds | MSE: 0.094 ------------------------------
# Execute Training and Walk Forward Testing for (International Power Ltd) for 18 times..
# ------------------------------ 0.005693912506103516 seconds | MSE: 0.191 ------------------------------
# Execute Training and Walk Forward Testing for (Capricorn Energy PLC) for 14 times..
# ------------------------------ 0.004013776779174805 seconds | MSE: 0.170 ------------------------------
# Execute Training and Walk Forward Testing for (Persimmon PLC) for 38 times..
# ------------------------------ 0.01359415054321289 seconds | MSE: 0.091 ------------------------------
# Execute Training and Walk Forward Testing for (Shell PLC) for 56 times..
# ------------------------------ 0.020514488220214844 seconds | MSE: 0.080 ------------------------------

# %% [markdown]
# ## Version 2.1
#
# - adding constant
# - adding data transformatin log1p
# - transform the data into supervised

# %%
# fit an random forest model and make a one step prediction
def ols_forecast(train, testX, l1_ratio = 0.25):
    # transform list into array
    train = asarray(train)
    # split into input and output columns
    trainX, trainy = train[:, :-1], train[:, -1]

    # scale the dataset
    # scaler = MinMaxScaler()
    # trainX = scaler.fit_transform(pd.DataFrame(trainX))
    # testX = scaler.transform(pd.DataFrame([testX]))
    
    # fit model
    model = OLS(trainy, trainX)
    model_fit = model.fit()
    # make a one-step prediction
    yhat = model_fit.predict([testX])
    return yhat[0]

# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, verbose = True):
    predictions = list()
    # split dataset
    train, test = train_test_split(data, n_test)
    # transform log1p
    train = log1p(train)
    test = log1p(test)
    # seed history with training dataset
    history = [x for x in train]
    # print(history)
    
    # step over each time-step in the test set
    for i in range(len(test)):
        # split test row into input and output columns
        testX, testy = test[i, :-1], test[i, -1]
        # fit model on history and make a prediction
        yhat = ols_forecast(history, testX)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for the next loop
        history.append(test[i])
        # summarize progress
        # print('>expected=%.4f, predicted=%.4f' % (testy, yhat))
        
    # estimate prediction error
    error = mean_squared_error(test[:, -1], predictions) * 10**3
    # error = mean_absolute_error(test[:, -1], predictions)
    
    return error, test[:, -1], predictions

# %%
def compile_train_test(train_df, test_df, sample = True, algo = 'HAR', dataset = 'm1', viz = False, cap = True):
    '''
    '''
    test_perc = .3 

    if dataset == 'm1':
        cols = ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']

    elif dataset == 'm3':
        cols = [ 'buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar'
                ,'CSRStrategy','Community','Emissions','EnvironmentalInnovation','HumanRights','Management','ProductResponsibility'
                ,'ResourceUse','Shareholders','Workforce', 'vol_series_daily','vol_series_weekly','vol_series_monthly', 'V^YZ']

    mresults = pd.DataFrame()

    if sample:
        assets = [4295894970, 8589934212]
    else:
        assets = train_df.Asset.unique().tolist()

    for r, asset in enumerate(assets): 
        # print(asset)
        name = train_df[train_df['Asset'] == asset].iloc[0,-1]

        df_train = train_df[train_df.Asset == asset][cols].dropna()
        df_test = test_df[test_df.Asset == asset][cols].dropna()
        indices = test_df[test_df.Asset == asset].index

        df_merge = pd.concat([df_train, df_test])
        df_merge = series_to_supervised(df_merge, n_in=3, target= ['V^YZ'])
        df_merge = sm.add_constant(df_merge)
        
        # display(df_merge)
        test_size = int(df_merge.shape[0] * test_perc)
        
        print(f'Execute Training and Walk Forward Testing for ({name}) for {test_size} times..')
        start_time = time.time()
        mse, y, yhat = walk_forward_validation(df_merge, test_size)
        print("---"*10, "%s seconds |"%(time.time() - start_time), 'MSE: %.3f'%mse, "---"*10)
        
        # inverse the log1p.
        y = expm1(y)
        yhat = expm1(yhat)
        
        mresult = pd.DataFrame({
            'Asset': asset,
            'Name': name,
            'Model': algo,
            'Test Size': test_size,
            'MSE^3':mse
                    }
            , index=[r]
        )
        mresults = pd.concat([mresults, mresult])

        if viz: 
            vis_line_plot_results(yhat, y, model = algo, dataset=dataset, name=name, r = r)

    return mresults

# %%
mresults_m1_dev21 = compile_train_test(train_df, test_df, sample=False, algo='HAR', dataset='m1', viz=False, cap = True)
# Out:
# Execute Training and Walk Forward Testing for (Pershing Square Holdings Ltd) for 3 times..
# ------------------------------ 0.0016787052154541016 seconds | MSE: 0.041 ------------------------------
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 3 times..
# ------------------------------ 0.001173257827758789 seconds | MSE: 2.953 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 3 times..
# ------------------------------ 0.0007693767547607422 seconds | MSE: 0.362 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 5 times..
# ------------------------------ 0.0011408329010009766 seconds | MSE: 0.120 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 6 times..
# ------------------------------ 0.0013270378112792969 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 8 times..
# ------------------------------ 0.0016331672668457031 seconds | MSE: 0.741 ------------------------------
# Execute Training and Walk Forward Testing for (JD Sports Fashion PLC) for 8 times..
# ------------------------------ 0.001728057861328125 seconds | MSE: 0.083 ------------------------------
# Execute Training and Walk Forward Testing for (Phoenix Group Holdings PLC) for 9 times..
# ------------------------------ 0.0018987655639648438 seconds | MSE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (Auto Trader Group PLC) for 10 times..
# ------------------------------ 0.0020973682403564453 seconds | MSE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (Spirax-Sarco Engineering PLC) for 10 times..
# ------------------------------ 0.002015829086303711 seconds | MSE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (Entain PLC) for 7 times..
# ------------------------------ 0.0014302730560302734 seconds | MSE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (Ocado Group PLC) for 12 times..
# ------------------------------ 0.0024194717407226562 seconds | MSE: 0.105 ------------------------------
# Execute Training and Walk Forward Testing for (Rightmove PLC) for 12 times..
# ------------------------------ 0.0030450820922851562 seconds | MSE: 0.036 ------------------------------
# Execute Training and Walk Forward Testing for (Halma PLC) for 13 times..
# ------------------------------ 0.002737760543823242 seconds | MSE: 0.024 ------------------------------
# Execute Training and Walk Forward Testing for (DS Smith PLC) for 13 times..
# ------------------------------ 0.00275421142578125 seconds | MSE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (NMC Health PLC) for 3 times..
# ------------------------------ 0.0007493495941162109 seconds | MSE: 46.118 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish Mortgage Investment Trust PLC) for 16 times..
# ------------------------------ 0.0033495426177978516 seconds | MSE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (Smurfit Kappa Group PLC) for 17 times..
# ------------------------------ 0.003613710403442383 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Micro Focus International Ltd) for 6 times..
# ------------------------------ 0.001252889633178711 seconds | MSE: 3.195 ------------------------------
# Execute Training and Walk Forward Testing for (Informa PLC) for 20 times..
# ------------------------------ 0.004681587219238281 seconds | MSE: 0.018 ------------------------------
# Execute Training and Walk Forward Testing for (Mediclinic Group Ltd) for 3 times..
# ------------------------------ 0.0009405612945556641 seconds | MSE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (Flutter Entertainment PLC) for 20 times..
# ------------------------------ 0.004254817962646484 seconds | MSE: 0.027 ------------------------------
# Execute Training and Walk Forward Testing for (Worldpay Group Ltd) for 2 times..
# ------------------------------ 0.0005812644958496094 seconds | MSE: 51.461 ------------------------------
# Execute Training and Walk Forward Testing for (DCC PLC) for 21 times..
# ------------------------------ 0.0043392181396484375 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Berkeley Group Holdings PLC) for 18 times..
# ------------------------------ 0.004750251770019531 seconds | MSE: 0.022 ------------------------------
# Execute Training and Walk Forward Testing for (Merlin Entertainments Ltd) for 4 times..
# ------------------------------ 0.0009713172912597656 seconds | MSE: 0.775 ------------------------------
# Execute Training and Walk Forward Testing for (Hikma Pharmaceuticals PLC) for 14 times..
# ------------------------------ 0.0032949447631835938 seconds | MSE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (TUI AG) for 12 times..
# ------------------------------ 0.0025246143341064453 seconds | MSE: 0.072 ------------------------------
# Execute Training and Walk Forward Testing for (Direct Line Insurance Group PLC) for 13 times..
# ------------------------------ 0.002622365951538086 seconds | MSE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (St James's Place PLC) for 27 times..
# ------------------------------ 0.005650043487548828 seconds | MSE: 0.014 ------------------------------
# Execute Training and Walk Forward Testing for (International Distributions Services PLC) for 14 times..
# ------------------------------ 0.0027871131896972656 seconds | MSE: 0.091 ------------------------------
# Execute Training and Walk Forward Testing for (Ashtead Group PLC) for 28 times..
# ------------------------------ 0.0058879852294921875 seconds | MSE: 0.066 ------------------------------
# Execute Training and Walk Forward Testing for (Coca Cola HBC AG) for 29 times..
# ------------------------------ 0.0063135623931884766 seconds | MSE: 0.043 ------------------------------
# Execute Training and Walk Forward Testing for (Frasers Group PLC) for 5 times..
# ------------------------------ 0.00109100341796875 seconds | MSE: 2.196 ------------------------------
# Execute Training and Walk Forward Testing for (Mondi PLC) for 29 times..
# ------------------------------ 0.006331682205200195 seconds | MSE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (Travis Perkins PLC) for 7 times..
# ------------------------------ 0.001497030258178711 seconds | MSE: 24.548 ------------------------------
# Execute Training and Walk Forward Testing for (Easyjet PLC) for 19 times..
# ------------------------------ 0.003939151763916016 seconds | MSE: 0.251 ------------------------------
# Execute Training and Walk Forward Testing for (Melrose Industries PLC) for 18 times..
# ------------------------------ 0.003706216812133789 seconds | MSE: 0.074 ------------------------------
# Execute Training and Walk Forward Testing for (Babcock International Group PLC) for 15 times..
# ------------------------------ 0.0031332969665527344 seconds | MSE: 0.316 ------------------------------
# Execute Training and Walk Forward Testing for (Croda International PLC) for 24 times..
# ------------------------------ 0.0050776004791259766 seconds | MSE: 0.018 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn Holdings Ltd) for 9 times..
# ------------------------------ 0.0019273757934570312 seconds | MSE: 0.047 ------------------------------
# Execute Training and Walk Forward Testing for (EVRAZ plc) for 15 times..
# ------------------------------ 0.0030531883239746094 seconds | MSE: 0.403 ------------------------------
# Execute Training and Walk Forward Testing for (Polymetal International PLC) for 9 times..
# ------------------------------ 0.001878499984741211 seconds | MSE: 1.243 ------------------------------
# Execute Training and Walk Forward Testing for (Meggitt Ltd) for 15 times..
# ------------------------------ 0.003042936325073242 seconds | MSE: 0.873 ------------------------------
# Execute Training and Walk Forward Testing for (Glencore PLC) for 37 times..
# ------------------------------ 0.008108377456665039 seconds | MSE: 0.109 ------------------------------
# Execute Training and Walk Forward Testing for (Hargreaves Lansdown PLC) for 38 times..
# ------------------------------ 0.00855112075805664 seconds | MSE: 0.099 ------------------------------
# Execute Training and Walk Forward Testing for (International Consolidated Airlines Group SA) for 38 times..
# ------------------------------ 0.010796308517456055 seconds | MSE: 0.289 ------------------------------
# Execute Training and Walk Forward Testing for (IMI PLC) for 9 times..
# ------------------------------ 0.0019421577453613281 seconds | MSE: 0.007 ------------------------------
# Execute Training and Walk Forward Testing for (Weir Group PLC) for 15 times..
# ------------------------------ 0.003032207489013672 seconds | MSE: 0.015 ------------------------------
# Execute Training and Walk Forward Testing for (GKN Ltd) for 22 times..
# ------------------------------ 0.00448298454284668 seconds | MSE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (SVF Holdco (UK) Ltd) for 18 times..
# ------------------------------ 0.0036149024963378906 seconds | MSE: 0.482 ------------------------------
# Execute Training and Walk Forward Testing for (Aggreko Ltd) for 15 times..
# ------------------------------ 0.0030095577239990234 seconds | MSE: 0.011 ------------------------------
# Execute Training and Walk Forward Testing for (Friends Life Group Ltd) for 12 times..
# ------------------------------ 0.002481698989868164 seconds | MSE: 0.147 ------------------------------
# Execute Training and Walk Forward Testing for (Burberry Group PLC) for 43 times..
# ------------------------------ 0.009727001190185547 seconds | MSE: 0.048 ------------------------------
# Execute Training and Walk Forward Testing for (Intertek Group PLC) for 44 times..
# ------------------------------ 0.010047197341918945 seconds | MSE: 0.073 ------------------------------
# Execute Training and Walk Forward Testing for (Serco Group PLC) for 12 times..
# ------------------------------ 0.002484560012817383 seconds | MSE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (Barrick Gold (Holdings) Ltd) for 31 times..
# ------------------------------ 0.008722305297851562 seconds | MSE: 0.031 ------------------------------
# Execute Training and Walk Forward Testing for (Fresnillo PLC) for 44 times..
# ------------------------------ 0.011151790618896484 seconds | MSE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (Inmarsat Group Holdings Ltd) for 10 times..
# ------------------------------ 0.0023059844970703125 seconds | MSE: 0.108 ------------------------------
# Execute Training and Walk Forward Testing for (Autonomy Corp Ltd) for 6 times..
# ------------------------------ 0.0014789104461669922 seconds | MSE: 2.310 ------------------------------
# Execute Training and Walk Forward Testing for (Petrofac Ltd) for 17 times..
# ------------------------------ 0.0038216114044189453 seconds | MSE: 0.098 ------------------------------
# Execute Training and Walk Forward Testing for (John Wood Group PLC) for 3 times..
# ------------------------------ 0.0007991790771484375 seconds | MSE: 0.280 ------------------------------
# Execute Training and Walk Forward Testing for (Bunzl plc) for 46 times..
# ------------------------------ 0.010946512222290039 seconds | MSE: 0.148 ------------------------------
# Execute Training and Walk Forward Testing for (Cobham Ltd) for 5 times..
# ------------------------------ 0.0011398792266845703 seconds | MSE: 0.329 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance Trust PLC) for 6 times..
# ------------------------------ 0.0014331340789794922 seconds | MSE: 0.005 ------------------------------
# Execute Training and Walk Forward Testing for (London Stock Exchange Group PLC) for 38 times..
# ------------------------------ 0.009100675582885742 seconds | MSE: 0.055 ------------------------------
# Execute Training and Walk Forward Testing for (Admiral Group PLC) for 49 times..
# ------------------------------ 0.01296234130859375 seconds | MSE: 0.045 ------------------------------
# Execute Training and Walk Forward Testing for (Tui Travel Ltd) for 14 times..
# ------------------------------ 0.0031430721282958984 seconds | MSE: 0.013 ------------------------------
# Execute Training and Walk Forward Testing for (Amec Foster Wheeler Ltd) for 17 times..
# ------------------------------ 0.0037186145782470703 seconds | MSE: 0.005 ------------------------------
# Execute Training and Walk Forward Testing for (G4S Ltd) for 27 times..
# ------------------------------ 0.006546735763549805 seconds | MSE: 0.006 ------------------------------
# Execute Training and Walk Forward Testing for (Currys PLC) for 7 times..
# ------------------------------ 0.0017898082733154297 seconds | MSE: 1474.602 ------------------------------
# Execute Training and Walk Forward Testing for (Tullow Oil PLC) for 22 times..
# ------------------------------ 0.006107807159423828 seconds | MSE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (Taylor Wimpey PLC) for 26 times..
# ------------------------------ 0.00603795051574707 seconds | MSE: 0.014 ------------------------------
# Execute Training and Walk Forward Testing for (Barratt Developments P L C) for 27 times..
# ------------------------------ 0.006243467330932617 seconds | MSE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (Whitbread PLC) for 52 times..
# ------------------------------ 0.012837409973144531 seconds | MSE: 0.085 ------------------------------
# Execute Training and Walk Forward Testing for (Experian PLC) for 54 times..
# ------------------------------ 0.013274908065795898 seconds | MSE: 0.108 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn PLC) for 53 times..
# ------------------------------ 0.012673377990722656 seconds | MSE: 0.090 ------------------------------
# Execute Training and Walk Forward Testing for (SEGRO PLC) for 22 times..
# ------------------------------ 0.004532814025878906 seconds | MSE: 0.023 ------------------------------
# Execute Training and Walk Forward Testing for (NEX Group Ltd) for 17 times..
# ------------------------------ 0.0035009384155273438 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Sibanye Uk Ltd) for 13 times..
# ------------------------------ 0.002702474594116211 seconds | MSE: 0.149 ------------------------------
# Execute Training and Walk Forward Testing for (Drax Group PLC) for 3 times..
# ------------------------------ 0.0007007122039794922 seconds | MSE: 12.330 ------------------------------
# Execute Training and Walk Forward Testing for (Aviva PLC) for 56 times..
# ------------------------------ 0.01449441909790039 seconds | MSE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Barclays PLC) for 56 times..
# ------------------------------ 0.014373302459716797 seconds | MSE: 0.145 ------------------------------
# Execute Training and Walk Forward Testing for (HSBC Holdings PLC) for 56 times..
# ------------------------------ 0.0134735107421875 seconds | MSE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 56 times..
# ------------------------------ 0.013571739196777344 seconds | MSE: 0.095 ------------------------------
# Execute Training and Walk Forward Testing for (Prudential PLC) for 56 times..
# ------------------------------ 0.01372838020324707 seconds | MSE: 0.099 ------------------------------
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 56 times..
# ------------------------------ 0.01423788070678711 seconds | MSE: 0.065 ------------------------------
# Execute Training and Walk Forward Testing for (Man Group PLC) for 18 times..
# ------------------------------ 0.0036864280700683594 seconds | MSE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (WPP PLC) for 56 times..
# ------------------------------ 0.013536453247070312 seconds | MSE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Rolls-Royce Holdings PLC) for 56 times..
# ------------------------------ 0.014340400695800781 seconds | MSE: 0.248 ------------------------------
# Execute Training and Walk Forward Testing for (Cable and Wireless Communications Ltd (Pre-Merger)) for 8 times..
# ------------------------------ 0.0016894340515136719 seconds | MSE: 0.225 ------------------------------
# Execute Training and Walk Forward Testing for (Friends Life FPG Ltd) for 8 times..
# ------------------------------ 0.0018610954284667969 seconds | MSE: 2.128 ------------------------------
# Execute Training and Walk Forward Testing for (United Utilities Group PLC) for 56 times..
# ------------------------------ 0.014791011810302734 seconds | MSE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (Xstrata Ltd) for 21 times..
# ------------------------------ 0.004393100738525391 seconds | MSE: 0.082 ------------------------------
# Execute Training and Walk Forward Testing for (BAE Systems PLC) for 56 times..
# ------------------------------ 0.015292882919311523 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (EDF Energy Nuclear Generation Group Ltd) for 3 times..
# ------------------------------ 0.0009579658508300781 seconds | MSE: 0.127 ------------------------------
# Execute Training and Walk Forward Testing for (Sage Group PLC) for 56 times..
# ------------------------------ 0.014168977737426758 seconds | MSE: 0.030 ------------------------------
# Execute Training and Walk Forward Testing for (Capita PLC) for 35 times..
# ------------------------------ 0.007783412933349609 seconds | MSE: 0.146 ------------------------------
# Execute Training and Walk Forward Testing for (Antofagasta PLC) for 56 times..
# ------------------------------ 0.014110326766967773 seconds | MSE: 0.039 ------------------------------
# Execute Training and Walk Forward Testing for (ITV PLC) for 41 times..
# ------------------------------ 0.009671688079833984 seconds | MSE: 0.151 ------------------------------
# Execute Training and Walk Forward Testing for (WM Morrison Supermarkets Ltd) for 48 times..
# ------------------------------ 0.011306285858154297 seconds | MSE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (Sky Ltd) for 40 times..
# ------------------------------ 0.00980997085571289 seconds | MSE: 0.076 ------------------------------
# Execute Training and Walk Forward Testing for (Vodafone Group PLC) for 56 times..
# ------------------------------ 0.014355897903442383 seconds | MSE: 0.061 ------------------------------
# Execute Training and Walk Forward Testing for (Severn Trent PLC) for 56 times..
# ------------------------------ 0.014099359512329102 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Thomson Reuters UK Ltd) for 8 times..
# ------------------------------ 0.0020651817321777344 seconds | MSE: 0.394 ------------------------------
# Execute Training and Walk Forward Testing for (Anglo American PLC) for 56 times..
# ------------------------------ 0.014245986938476562 seconds | MSE: 0.065 ------------------------------
# Execute Training and Walk Forward Testing for (Abi Sab Group Holding Ltd) for 33 times..
# ------------------------------ 0.0074825286865234375 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Carnival PLC) for 46 times..
# ------------------------------ 0.012961149215698242 seconds | MSE: 0.182 ------------------------------
# Execute Training and Walk Forward Testing for (Kingfisher PLC) for 55 times..
# ------------------------------ 0.013451814651489258 seconds | MSE: 0.112 ------------------------------
# Execute Training and Walk Forward Testing for (3i Group PLC) for 45 times..
# ------------------------------ 0.010569095611572266 seconds | MSE: 0.079 ------------------------------
# Execute Training and Walk Forward Testing for (GSK plc) for 56 times..
# ------------------------------ 0.015822649002075195 seconds | MSE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (Next PLC) for 56 times..
# ------------------------------ 0.013806819915771484 seconds | MSE: 0.087 ------------------------------
# Execute Training and Walk Forward Testing for (HBOS Plc) for 5 times..
# ------------------------------ 0.0012974739074707031 seconds | MSE: 357.356 ------------------------------
# Execute Training and Walk Forward Testing for (BT Group PLC) for 56 times..
# ------------------------------ 0.014509916305541992 seconds | MSE: 0.034 ------------------------------
# Execute Training and Walk Forward Testing for (Compass Group PLC) for 56 times..
# ------------------------------ 0.01368403434753418 seconds | MSE: 0.122 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance & Leicester Ltd) for 3 times..
# ------------------------------ 0.0007486343383789062 seconds | MSE: 30.929 ------------------------------
# Execute Training and Walk Forward Testing for (Tesco PLC) for 56 times..
# ------------------------------ 0.013731718063354492 seconds | MSE: 0.026 ------------------------------
# Execute Training and Walk Forward Testing for (RSA Insurance Group Ltd) for 50 times..
# ------------------------------ 0.011827945709228516 seconds | MSE: 0.074 ------------------------------
# Execute Training and Walk Forward Testing for (Standard Chartered PLC) for 56 times..
# ------------------------------ 0.013589620590209961 seconds | MSE: 0.046 ------------------------------
# Execute Training and Walk Forward Testing for (Smith & Nephew PLC) for 56 times..
# ------------------------------ 0.014744997024536133 seconds | MSE: 0.036 ------------------------------
# Execute Training and Walk Forward Testing for (Smiths Group PLC) for 55 times..
# ------------------------------ 0.013916492462158203 seconds | MSE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish & Newcastle Ltd) for 3 times..
# ------------------------------ 0.0007135868072509766 seconds | MSE: 3.903 ------------------------------
# Execute Training and Walk Forward Testing for (Schroders PLC) for 54 times..
# ------------------------------ 0.01379084587097168 seconds | MSE: 0.151 ------------------------------
# Execute Training and Walk Forward Testing for (J Sainsbury PLC) for 56 times..
# ------------------------------ 0.014080047607421875 seconds | MSE: 0.037 ------------------------------
# Execute Training and Walk Forward Testing for (Hammerson PLC) for 38 times..
# ------------------------------ 0.008855342864990234 seconds | MSE: 0.426 ------------------------------
# Execute Training and Walk Forward Testing for (Marks and Spencer Group PLC) for 44 times..
# ------------------------------ 0.010490894317626953 seconds | MSE: 0.317 ------------------------------
# Execute Training and Walk Forward Testing for (Legal & General Group PLC) for 56 times..
# ------------------------------ 0.013949155807495117 seconds | MSE: 0.113 ------------------------------
# Execute Training and Walk Forward Testing for (Land Securities Group PLC) for 56 times..
# ------------------------------ 0.013931989669799805 seconds | MSE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (British Airways PLC) for 12 times..
# ------------------------------ 0.002515554428100586 seconds | MSE: 0.039 ------------------------------
# Execute Training and Walk Forward Testing for (BG Group Ltd) for 31 times..
# ------------------------------ 0.006776094436645508 seconds | MSE: 0.178 ------------------------------
# Execute Training and Walk Forward Testing for (Associated British Foods PLC) for 56 times..
# ------------------------------ 0.01496124267578125 seconds | MSE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (British Land Company PLC) for 56 times..
# ------------------------------ 0.014088153839111328 seconds | MSE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (BHP Group (UK) Ltd) for 52 times..
# ------------------------------ 0.013315439224243164 seconds | MSE: 0.049 ------------------------------
# Execute Training and Walk Forward Testing for (Pearson PLC) for 56 times..
# ------------------------------ 0.014608621597290039 seconds | MSE: 0.046 ------------------------------
# Execute Training and Walk Forward Testing for (Diageo PLC) for 56 times..
# ------------------------------ 0.014166593551635742 seconds | MSE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Johnson Matthey PLC) for 52 times..
# ------------------------------ 0.014377117156982422 seconds | MSE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (Rio Tinto PLC) for 56 times..
# ------------------------------ 0.013671398162841797 seconds | MSE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (British American Tobacco PLC) for 56 times..
# ------------------------------ 0.014310598373413086 seconds | MSE: 0.050 ------------------------------
# Execute Training and Walk Forward Testing for (Unilever PLC) for 56 times..
# ------------------------------ 0.013868331909179688 seconds | MSE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (Relx PLC) for 56 times..
# ------------------------------ 0.013632774353027344 seconds | MSE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (InterContinental Hotels Group PLC) for 56 times..
# ------------------------------ 0.013813018798828125 seconds | MSE: 0.084 ------------------------------
# Execute Training and Walk Forward Testing for (Tate & Lyle PLC) for 12 times..
# ------------------------------ 0.0025081634521484375 seconds | MSE: 0.029 ------------------------------
# Execute Training and Walk Forward Testing for (Cadbury Ltd) for 9 times..
# ------------------------------ 0.0020623207092285156 seconds | MSE: 0.605 ------------------------------
# Execute Training and Walk Forward Testing for (Reckitt Benckiser Group PLC) for 56 times..
# ------------------------------ 0.014571666717529297 seconds | MSE: 0.017 ------------------------------
# Execute Training and Walk Forward Testing for (Rexam Ltd) for 27 times..
# ------------------------------ 0.005776405334472656 seconds | MSE: 0.009 ------------------------------
# Execute Training and Walk Forward Testing for (BP PLC) for 56 times..
# ------------------------------ 0.014406681060791016 seconds | MSE: 0.102 ------------------------------
# Execute Training and Walk Forward Testing for (Centrica PLC) for 48 times..
# ------------------------------ 0.011513710021972656 seconds | MSE: 0.130 ------------------------------
# Execute Training and Walk Forward Testing for (Shire Ltd) for 41 times..
# ------------------------------ 0.00921487808227539 seconds | MSE: 0.237 ------------------------------
# Execute Training and Walk Forward Testing for (Imperial Brands PLC) for 56 times..
# ------------------------------ 0.013649702072143555 seconds | MSE: 0.024 ------------------------------
# Execute Training and Walk Forward Testing for (Ei Group Ltd) for 4 times..
# ------------------------------ 0.0009469985961914062 seconds | MSE: 5.916 ------------------------------
# Execute Training and Walk Forward Testing for (Rentokil Initial PLC) for 20 times..
# ------------------------------ 0.004204273223876953 seconds | MSE: 0.021 ------------------------------
# Execute Training and Walk Forward Testing for (National Grid PLC) for 56 times..
# ------------------------------ 0.013588905334472656 seconds | MSE: 0.022 ------------------------------
# Execute Training and Walk Forward Testing for (Home Retail Group Ltd) for 9 times..
# ------------------------------ 0.0018873214721679688 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (AstraZeneca PLC) for 56 times..
# ------------------------------ 0.013623476028442383 seconds | MSE: 0.037 ------------------------------
# Execute Training and Walk Forward Testing for (Intu Properties PLC) for 31 times..
# ------------------------------ 0.0066068172454833984 seconds | MSE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (SSE PLC) for 56 times..
# ------------------------------ 0.013615131378173828 seconds | MSE: 0.089 ------------------------------
# Execute Training and Walk Forward Testing for (International Power Ltd) for 18 times..
# ------------------------------ 0.0036361217498779297 seconds | MSE: 0.191 ------------------------------
# Execute Training and Walk Forward Testing for (Capricorn Energy PLC) for 14 times..
# ------------------------------ 0.0028295516967773438 seconds | MSE: 0.154 ------------------------------
# Execute Training and Walk Forward Testing for (Persimmon PLC) for 38 times..
# ------------------------------ 0.009661197662353516 seconds | MSE: 0.081 ------------------------------
# Execute Training and Walk Forward Testing for (Shell PLC) for 56 times..
# ------------------------------ 0.014312505722045898 seconds | MSE: 0.075 ------------------------------

# %%
mresults_m3_dev21 = compile_train_test(train_df, test_df, sample=False, algo='HAR', dataset='m3', viz=False, cap = True)
# Out:
# Execute Training and Walk Forward Testing for (Pershing Square Holdings Ltd) for 3 times..
# ------------------------------ 0.0017094612121582031 seconds | MSE: 0.015 ------------------------------
# Execute Training and Walk Forward Testing for (B&M European Value Retail SA) for 3 times..
# ------------------------------ 0.000993967056274414 seconds | MSE: 0.024 ------------------------------
# Execute Training and Walk Forward Testing for (Avast Ltd) for 3 times..
# ------------------------------ 0.0009794235229492188 seconds | MSE: 0.498 ------------------------------
# Execute Training and Walk Forward Testing for (Intermediate Capital Group PLC) for 5 times..
# ------------------------------ 0.001547098159790039 seconds | MSE: 0.036 ------------------------------
# Execute Training and Walk Forward Testing for (M&G PLC) for 6 times..
# ------------------------------ 0.0021903514862060547 seconds | MSE: 0.360 ------------------------------
# Execute Training and Walk Forward Testing for (Aveva Group Ltd) for 8 times..
# ------------------------------ 0.003366708755493164 seconds | MSE: 0.695 ------------------------------
# Execute Training and Walk Forward Testing for (JD Sports Fashion PLC) for 8 times..
# ------------------------------ 0.003060579299926758 seconds | MSE: 0.157 ------------------------------
# Execute Training and Walk Forward Testing for (Phoenix Group Holdings PLC) for 9 times..
# ------------------------------ 0.0037107467651367188 seconds | MSE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (Auto Trader Group PLC) for 10 times..
# ------------------------------ 0.005270719528198242 seconds | MSE: 2.882 ------------------------------
# Execute Training and Walk Forward Testing for (Spirax-Sarco Engineering PLC) for 10 times..
# ------------------------------ 0.004537343978881836 seconds | MSE: 2.345 ------------------------------
# Execute Training and Walk Forward Testing for (Entain PLC) for 7 times..
# ------------------------------ 0.0025899410247802734 seconds | MSE: 0.939 ------------------------------
# Execute Training and Walk Forward Testing for (Ocado Group PLC) for 12 times..
# ------------------------------ 0.006242513656616211 seconds | MSE: 4.877 ------------------------------
# Execute Training and Walk Forward Testing for (Rightmove PLC) for 12 times..
# ------------------------------ 0.0061719417572021484 seconds | MSE: 0.628 ------------------------------
# Execute Training and Walk Forward Testing for (Halma PLC) for 13 times..
# ------------------------------ 0.023842573165893555 seconds | MSE: 0.132 ------------------------------
# Execute Training and Walk Forward Testing for (DS Smith PLC) for 13 times..
# ------------------------------ 0.008141279220581055 seconds | MSE: 169.130 ------------------------------
# Execute Training and Walk Forward Testing for (NMC Health PLC) for 3 times..
# ------------------------------ 0.0011234283447265625 seconds | MSE: 0.534 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish Mortgage Investment Trust PLC) for 16 times..
# ------------------------------ 0.012000322341918945 seconds | MSE: 9.196 ------------------------------
# Execute Training and Walk Forward Testing for (Smurfit Kappa Group PLC) for 17 times..
# ------------------------------ 0.04668426513671875 seconds | MSE: 1.284 ------------------------------
# Execute Training and Walk Forward Testing for (Micro Focus International Ltd) for 6 times..
# ------------------------------ 0.0019769668579101562 seconds | MSE: 0.185 ------------------------------
# Execute Training and Walk Forward Testing for (Informa PLC) for 20 times..
# ------------------------------ 0.01863265037536621 seconds | MSE: 3.248 ------------------------------
# Execute Training and Walk Forward Testing for (Mediclinic Group Ltd) for 3 times..
# ------------------------------ 0.0010821819305419922 seconds | MSE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (Flutter Entertainment PLC) for 20 times..
# ------------------------------ 0.018100738525390625 seconds | MSE: 0.996 ------------------------------
# Execute Training and Walk Forward Testing for (Worldpay Group Ltd) for 2 times..
# ------------------------------ 0.0009005069732666016 seconds | MSE: 0.051 ------------------------------
# Execute Training and Walk Forward Testing for (DCC PLC) for 21 times..
# ------------------------------ 0.0198824405670166 seconds | MSE: 26.154 ------------------------------
# Execute Training and Walk Forward Testing for (Berkeley Group Holdings PLC) for 18 times..
# ------------------------------ 0.014960765838623047 seconds | MSE: 5.049 ------------------------------
# Execute Training and Walk Forward Testing for (Merlin Entertainments Ltd) for 4 times..
# ------------------------------ 0.0013294219970703125 seconds | MSE: 0.460 ------------------------------
# Execute Training and Walk Forward Testing for (Hikma Pharmaceuticals PLC) for 14 times..
# ------------------------------ 0.03740501403808594 seconds | MSE: 4.412 ------------------------------
# Execute Training and Walk Forward Testing for (TUI AG) for 12 times..
# ------------------------------ 0.007056474685668945 seconds | MSE: 0.224 ------------------------------
# Execute Training and Walk Forward Testing for (Direct Line Insurance Group PLC) for 13 times..
# ------------------------------ 0.008347511291503906 seconds | MSE: 0.304 ------------------------------
# Execute Training and Walk Forward Testing for (St James's Place PLC) for 27 times..
# ------------------------------ 0.06151080131530762 seconds | MSE: 4.739 ------------------------------
# Execute Training and Walk Forward Testing for (International Distributions Services PLC) for 14 times..
# ------------------------------ 0.009071111679077148 seconds | MSE: 8.918 ------------------------------
# Execute Training and Walk Forward Testing for (Ashtead Group PLC) for 28 times..
# ------------------------------ 0.029430866241455078 seconds | MSE: 657.675 ------------------------------
# Execute Training and Walk Forward Testing for (Coca Cola HBC AG) for 29 times..
# ------------------------------ 0.062345027923583984 seconds | MSE: 0.359 ------------------------------
# Execute Training and Walk Forward Testing for (Frasers Group PLC) for 5 times..
# ------------------------------ 0.0016222000122070312 seconds | MSE: 0.049 ------------------------------
# Execute Training and Walk Forward Testing for (Mondi PLC) for 29 times..
# ------------------------------ 0.03249239921569824 seconds | MSE: 0.097 ------------------------------
# Execute Training and Walk Forward Testing for (Travis Perkins PLC) for 7 times..
# ------------------------------ 0.021036386489868164 seconds | MSE: 4.691 ------------------------------
# Execute Training and Walk Forward Testing for (Easyjet PLC) for 19 times..
# ------------------------------ 0.022739171981811523 seconds | MSE: 7.214 ------------------------------
# Execute Training and Walk Forward Testing for (Melrose Industries PLC) for 18 times..
# ------------------------------ 0.017148733139038086 seconds | MSE: 1.832 ------------------------------
# Execute Training and Walk Forward Testing for (Babcock International Group PLC) for 15 times..
# ------------------------------ 0.048308372497558594 seconds | MSE: 4.561 ------------------------------
# Execute Training and Walk Forward Testing for (Croda International PLC) for 24 times..
# ------------------------------ 0.0462491512298584 seconds | MSE: 5.723 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn Holdings Ltd) for 9 times..
# ------------------------------ 0.004444599151611328 seconds | MSE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (EVRAZ plc) for 15 times..
# ------------------------------ 0.022316694259643555 seconds | MSE: 1.987 ------------------------------
# Execute Training and Walk Forward Testing for (Polymetal International PLC) for 9 times..
# ------------------------------ 0.0039179325103759766 seconds | MSE: 0.942 ------------------------------
# Execute Training and Walk Forward Testing for (Meggitt Ltd) for 15 times..
# ------------------------------ 0.018006086349487305 seconds | MSE: 1.390 ------------------------------
# Execute Training and Walk Forward Testing for (Glencore PLC) for 37 times..
# ------------------------------ 0.19593191146850586 seconds | MSE: 0.278 ------------------------------
# Execute Training and Walk Forward Testing for (Hargreaves Lansdown PLC) for 38 times..
# ------------------------------ 0.23120594024658203 seconds | MSE: 0.252 ------------------------------
# Execute Training and Walk Forward Testing for (International Consolidated Airlines Group SA) for 38 times..
# ------------------------------ 0.15302824974060059 seconds | MSE: 0.405 ------------------------------
# Execute Training and Walk Forward Testing for (IMI PLC) for 9 times..
# ------------------------------ 0.030455350875854492 seconds | MSE: 0.024 ------------------------------
# Execute Training and Walk Forward Testing for (Weir Group PLC) for 15 times..
# ------------------------------ 0.020380258560180664 seconds | MSE: 1.509 ------------------------------
# Execute Training and Walk Forward Testing for (GKN Ltd) for 22 times..
# ------------------------------ 0.06744790077209473 seconds | MSE: 2.303 ------------------------------
# Execute Training and Walk Forward Testing for (SVF Holdco (UK) Ltd) for 18 times..
# ------------------------------ 0.04042482376098633 seconds | MSE: 8.017 ------------------------------
# Execute Training and Walk Forward Testing for (Aggreko Ltd) for 15 times..
# ------------------------------ 0.04437518119812012 seconds | MSE: 0.268 ------------------------------
# Execute Training and Walk Forward Testing for (Friends Life Group Ltd) for 12 times..
# ------------------------------ 0.01757979393005371 seconds | MSE: 0.834 ------------------------------
# Execute Training and Walk Forward Testing for (Burberry Group PLC) for 43 times..
# ------------------------------ 0.1593163013458252 seconds | MSE: 0.127 ------------------------------
# Execute Training and Walk Forward Testing for (Intertek Group PLC) for 44 times..
# ------------------------------ 0.1418590545654297 seconds | MSE: 0.081 ------------------------------
# Execute Training and Walk Forward Testing for (Serco Group PLC) for 12 times..
# ------------------------------ 0.036270856857299805 seconds | MSE: 0.078 ------------------------------
# Execute Training and Walk Forward Testing for (Barrick Gold (Holdings) Ltd) for 31 times..
# ------------------------------ 0.1002197265625 seconds | MSE: 0.149 ------------------------------
# Execute Training and Walk Forward Testing for (Fresnillo PLC) for 44 times..
# ------------------------------ 0.13544845581054688 seconds | MSE: 0.134 ------------------------------
# Execute Training and Walk Forward Testing for (Inmarsat Group Holdings Ltd) for 10 times..
# ------------------------------ 0.025914430618286133 seconds | MSE: 6.046 ------------------------------
# Execute Training and Walk Forward Testing for (Autonomy Corp Ltd) for 6 times..
# ------------------------------ 0.002157449722290039 seconds | MSE: 2.196 ------------------------------
# Execute Training and Walk Forward Testing for (Petrofac Ltd) for 17 times..
# ------------------------------ 0.03083014488220215 seconds | MSE: 0.564 ------------------------------
# Execute Training and Walk Forward Testing for (John Wood Group PLC) for 3 times..
# ------------------------------ 0.0011026859283447266 seconds | MSE: 0.020 ------------------------------
# Execute Training and Walk Forward Testing for (Bunzl plc) for 46 times..
# ------------------------------ 0.15615367889404297 seconds | MSE: 0.170 ------------------------------
# Execute Training and Walk Forward Testing for (Cobham Ltd) for 5 times..
# ------------------------------ 0.001562356948852539 seconds | MSE: 0.019 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance Trust PLC) for 6 times..
# ------------------------------ 0.0023124217987060547 seconds | MSE: 0.008 ------------------------------
# Execute Training and Walk Forward Testing for (London Stock Exchange Group PLC) for 38 times..
# ------------------------------ 0.11292219161987305 seconds | MSE: 0.097 ------------------------------
# Execute Training and Walk Forward Testing for (Admiral Group PLC) for 49 times..
# ------------------------------ 0.21040582656860352 seconds | MSE: 0.087 ------------------------------
# Execute Training and Walk Forward Testing for (Tui Travel Ltd) for 14 times..
# ------------------------------ 0.045832157135009766 seconds | MSE: 0.130 ------------------------------
# Execute Training and Walk Forward Testing for (Amec Foster Wheeler Ltd) for 17 times..
# ------------------------------ 0.039908409118652344 seconds | MSE: 0.682 ------------------------------
# Execute Training and Walk Forward Testing for (G4S Ltd) for 27 times..
# ------------------------------ 0.09468555450439453 seconds | MSE: 1.041 ------------------------------
# Execute Training and Walk Forward Testing for (Currys PLC) for 7 times..
# ------------------------------ 0.013854265213012695 seconds | MSE: 5.703 ------------------------------
# Execute Training and Walk Forward Testing for (Tullow Oil PLC) for 22 times..
# ------------------------------ 0.05155634880065918 seconds | MSE: 0.422 ------------------------------
# Execute Training and Walk Forward Testing for (Taylor Wimpey PLC) for 26 times..
# ------------------------------ 0.08189010620117188 seconds | MSE: 12.138 ------------------------------
# Execute Training and Walk Forward Testing for (Barratt Developments P L C) for 27 times..
# ------------------------------ 0.0871880054473877 seconds | MSE: 5.692 ------------------------------
# Execute Training and Walk Forward Testing for (Whitbread PLC) for 52 times..
# ------------------------------ 0.22690439224243164 seconds | MSE: 0.122 ------------------------------
# Execute Training and Walk Forward Testing for (Experian PLC) for 54 times..
# ------------------------------ 0.3062131404876709 seconds | MSE: 0.149 ------------------------------
# Execute Training and Walk Forward Testing for (Abrdn PLC) for 53 times..
# ------------------------------ 0.12698864936828613 seconds | MSE: 0.279 ------------------------------
# Execute Training and Walk Forward Testing for (SEGRO PLC) for 22 times..
# ------------------------------ 0.023614168167114258 seconds | MSE: 0.266 ------------------------------
# Execute Training and Walk Forward Testing for (NEX Group Ltd) for 17 times..
# ------------------------------ 0.032700538635253906 seconds | MSE: 1.040 ------------------------------
# Execute Training and Walk Forward Testing for (Sibanye Uk Ltd) for 13 times..
# ------------------------------ 0.007847070693969727 seconds | MSE: 3.724 ------------------------------
# Execute Training and Walk Forward Testing for (Drax Group PLC) for 3 times..
# ------------------------------ 0.0009088516235351562 seconds | MSE: 0.044 ------------------------------
# Execute Training and Walk Forward Testing for (Aviva PLC) for 56 times..
# ------------------------------ 0.11638236045837402 seconds | MSE: 0.113 ------------------------------
# Execute Training and Walk Forward Testing for (Barclays PLC) for 56 times..
# ------------------------------ 0.11723613739013672 seconds | MSE: 0.342 ------------------------------
# Execute Training and Walk Forward Testing for (HSBC Holdings PLC) for 56 times..
# ------------------------------ 0.1092536449432373 seconds | MSE: 0.110 ------------------------------
# Execute Training and Walk Forward Testing for (Lloyds Banking Group PLC) for 56 times..
# ------------------------------ 0.11257576942443848 seconds | MSE: 0.177 ------------------------------
# Execute Training and Walk Forward Testing for (Prudential PLC) for 56 times..
# ------------------------------ 0.1071019172668457 seconds | MSE: 0.118 ------------------------------
# Execute Training and Walk Forward Testing for (Natwest Group PLC) for 56 times..
# ------------------------------ 0.15828752517700195 seconds | MSE: 0.800 ------------------------------
# Execute Training and Walk Forward Testing for (Man Group PLC) for 18 times..
# ------------------------------ 0.025775909423828125 seconds | MSE: 2.221 ------------------------------
# Execute Training and Walk Forward Testing for (WPP PLC) for 56 times..
# ------------------------------ 0.14915204048156738 seconds | MSE: 0.191 ------------------------------
# Execute Training and Walk Forward Testing for (Rolls-Royce Holdings PLC) for 56 times..
# ------------------------------ 0.14871811866760254 seconds | MSE: 0.291 ------------------------------
# Execute Training and Walk Forward Testing for (Cable and Wireless Communications Ltd (Pre-Merger)) for 8 times..
# ------------------------------ 0.0039000511169433594 seconds | MSE: 0.314 ------------------------------
# Execute Training and Walk Forward Testing for (Friends Life FPG Ltd) for 8 times..
# ------------------------------ 0.007503032684326172 seconds | MSE: 0.297 ------------------------------
# Execute Training and Walk Forward Testing for (United Utilities Group PLC) for 56 times..
# ------------------------------ 0.19697117805480957 seconds | MSE: 0.039 ------------------------------
# Execute Training and Walk Forward Testing for (Xstrata Ltd) for 21 times..
# ------------------------------ 0.03511524200439453 seconds | MSE: 6.628 ------------------------------
# Execute Training and Walk Forward Testing for (BAE Systems PLC) for 56 times..
# ------------------------------ 0.11588788032531738 seconds | MSE: 0.033 ------------------------------
# Execute Training and Walk Forward Testing for (EDF Energy Nuclear Generation Group Ltd) for 3 times..
# ------------------------------ 0.0011165142059326172 seconds | MSE: 0.035 ------------------------------
# Execute Training and Walk Forward Testing for (Sage Group PLC) for 56 times..
# ------------------------------ 0.13878750801086426 seconds | MSE: 0.071 ------------------------------
# Execute Training and Walk Forward Testing for (Capita PLC) for 35 times..
# ------------------------------ 0.04874539375305176 seconds | MSE: 0.974 ------------------------------
# Execute Training and Walk Forward Testing for (Antofagasta PLC) for 56 times..
# ------------------------------ 0.14223790168762207 seconds | MSE: 0.111 ------------------------------
# Execute Training and Walk Forward Testing for (ITV PLC) for 41 times..
# ------------------------------ 0.06130027770996094 seconds | MSE: 0.409 ------------------------------
# Execute Training and Walk Forward Testing for (WM Morrison Supermarkets Ltd) for 48 times..
# ------------------------------ 0.1010286808013916 seconds | MSE: 0.109 ------------------------------
# Execute Training and Walk Forward Testing for (Sky Ltd) for 40 times..
# ------------------------------ 0.057752132415771484 seconds | MSE: 0.301 ------------------------------
# Execute Training and Walk Forward Testing for (Vodafone Group PLC) for 56 times..
# ------------------------------ 0.14997386932373047 seconds | MSE: 0.089 ------------------------------
# Execute Training and Walk Forward Testing for (Severn Trent PLC) for 56 times..
# ------------------------------ 0.13659238815307617 seconds | MSE: 0.032 ------------------------------
# Execute Training and Walk Forward Testing for (Thomson Reuters UK Ltd) for 8 times..
# ------------------------------ 0.003317594528198242 seconds | MSE: 0.151 ------------------------------
# Execute Training and Walk Forward Testing for (Anglo American PLC) for 56 times..
# ------------------------------ 0.13808250427246094 seconds | MSE: 0.129 ------------------------------
# Execute Training and Walk Forward Testing for (Abi Sab Group Holding Ltd) for 33 times..
# ------------------------------ 0.07819175720214844 seconds | MSE: 0.057 ------------------------------
# Execute Training and Walk Forward Testing for (Carnival PLC) for 46 times..
# ------------------------------ 0.09069442749023438 seconds | MSE: 3.140 ------------------------------
# Execute Training and Walk Forward Testing for (Kingfisher PLC) for 55 times..
# ------------------------------ 0.12028026580810547 seconds | MSE: 0.122 ------------------------------
# Execute Training and Walk Forward Testing for (3i Group PLC) for 45 times..
# ------------------------------ 0.08370423316955566 seconds | MSE: 0.171 ------------------------------
# Execute Training and Walk Forward Testing for (GSK plc) for 56 times..
# ------------------------------ 0.1259748935699463 seconds | MSE: 0.047 ------------------------------
# Execute Training and Walk Forward Testing for (Next PLC) for 56 times..
# ------------------------------ 0.1148672103881836 seconds | MSE: 0.175 ------------------------------
# Execute Training and Walk Forward Testing for (HBOS Plc) for 5 times..
# ------------------------------ 0.0017216205596923828 seconds | MSE: 5.606 ------------------------------
# Execute Training and Walk Forward Testing for (BT Group PLC) for 56 times..
# ------------------------------ 0.11652612686157227 seconds | MSE: 0.092 ------------------------------
# Execute Training and Walk Forward Testing for (Compass Group PLC) for 56 times..
# ------------------------------ 0.1188969612121582 seconds | MSE: 0.114 ------------------------------
# Execute Training and Walk Forward Testing for (Alliance & Leicester Ltd) for 3 times..
# ------------------------------ 0.0009303092956542969 seconds | MSE: 0.226 ------------------------------
# Execute Training and Walk Forward Testing for (Tesco PLC) for 56 times..
# ------------------------------ 0.24543261528015137 seconds | MSE: 0.058 ------------------------------
# Execute Training and Walk Forward Testing for (RSA Insurance Group Ltd) for 50 times..
# ------------------------------ 0.20691204071044922 seconds | MSE: 0.124 ------------------------------
# Execute Training and Walk Forward Testing for (Standard Chartered PLC) for 56 times..
# ------------------------------ 0.1055150032043457 seconds | MSE: 0.080 ------------------------------
# Execute Training and Walk Forward Testing for (Smith & Nephew PLC) for 56 times..
# ------------------------------ 0.11484789848327637 seconds | MSE: 0.059 ------------------------------
# Execute Training and Walk Forward Testing for (Smiths Group PLC) for 55 times..
# ------------------------------ 0.13560986518859863 seconds | MSE: 0.088 ------------------------------
# Execute Training and Walk Forward Testing for (Scottish & Newcastle Ltd) for 3 times..
# ------------------------------ 0.0010862350463867188 seconds | MSE: 0.102 ------------------------------
# Execute Training and Walk Forward Testing for (Schroders PLC) for 54 times..
# ------------------------------ 0.24419617652893066 seconds | MSE: 0.187 ------------------------------
# Execute Training and Walk Forward Testing for (J Sainsbury PLC) for 56 times..
# ------------------------------ 0.1382462978363037 seconds | MSE: 0.125 ------------------------------
# Execute Training and Walk Forward Testing for (Hammerson PLC) for 38 times..
# ------------------------------ 0.06331443786621094 seconds | MSE: 0.255 ------------------------------
# Execute Training and Walk Forward Testing for (Marks and Spencer Group PLC) for 44 times..
# ------------------------------ 0.056920766830444336 seconds | MSE: 0.519 ------------------------------
# Execute Training and Walk Forward Testing for (Legal & General Group PLC) for 56 times..
# ------------------------------ 0.1062779426574707 seconds | MSE: 0.454 ------------------------------
# Execute Training and Walk Forward Testing for (Land Securities Group PLC) for 56 times..
# ------------------------------ 0.10431241989135742 seconds | MSE: 0.095 ------------------------------
# Execute Training and Walk Forward Testing for (British Airways PLC) for 12 times..
# ------------------------------ 0.006397724151611328 seconds | MSE: 0.289 ------------------------------
# Execute Training and Walk Forward Testing for (BG Group Ltd) for 31 times..
# ------------------------------ 0.034325599670410156 seconds | MSE: 0.322 ------------------------------
# Execute Training and Walk Forward Testing for (Associated British Foods PLC) for 56 times..
# ------------------------------ 0.09615802764892578 seconds | MSE: 0.100 ------------------------------
# Execute Training and Walk Forward Testing for (British Land Company PLC) for 56 times..
# ------------------------------ 0.09855341911315918 seconds | MSE: 0.063 ------------------------------
# Execute Training and Walk Forward Testing for (BHP Group (UK) Ltd) for 52 times..
# ------------------------------ 0.07252693176269531 seconds | MSE: 0.086 ------------------------------
# Execute Training and Walk Forward Testing for (Pearson PLC) for 56 times..
# ------------------------------ 0.09712004661560059 seconds | MSE: 0.067 ------------------------------
# Execute Training and Walk Forward Testing for (Diageo PLC) for 56 times..
# ------------------------------ 0.12114596366882324 seconds | MSE: 0.322 ------------------------------
# Execute Training and Walk Forward Testing for (Johnson Matthey PLC) for 52 times..
# ------------------------------ 0.10293388366699219 seconds | MSE: 0.110 ------------------------------
# Execute Training and Walk Forward Testing for (Rio Tinto PLC) for 56 times..
# ------------------------------ 0.10641241073608398 seconds | MSE: 0.297 ------------------------------
# Execute Training and Walk Forward Testing for (British American Tobacco PLC) for 56 times..
# ------------------------------ 0.11020040512084961 seconds | MSE: 0.073 ------------------------------
# Execute Training and Walk Forward Testing for (Unilever PLC) for 56 times..
# ------------------------------ 0.1061258316040039 seconds | MSE: 0.028 ------------------------------
# Execute Training and Walk Forward Testing for (Relx PLC) for 56 times..
# ------------------------------ 0.16043376922607422 seconds | MSE: 0.105 ------------------------------
# Execute Training and Walk Forward Testing for (InterContinental Hotels Group PLC) for 56 times..
# ------------------------------ 0.1161041259765625 seconds | MSE: 0.173 ------------------------------
# Execute Training and Walk Forward Testing for (Tate & Lyle PLC) for 12 times..
# ------------------------------ 0.0066416263580322266 seconds | MSE: 0.323 ------------------------------
# Execute Training and Walk Forward Testing for (Cadbury Ltd) for 9 times..
# ------------------------------ 0.0038738250732421875 seconds | MSE: 2.509 ------------------------------
# Execute Training and Walk Forward Testing for (Reckitt Benckiser Group PLC) for 56 times..
# ------------------------------ 0.14000558853149414 seconds | MSE: 0.025 ------------------------------
# Execute Training and Walk Forward Testing for (Rexam Ltd) for 27 times..
# ------------------------------ 0.030812978744506836 seconds | MSE: 0.363 ------------------------------
# Execute Training and Walk Forward Testing for (BP PLC) for 56 times..
# ------------------------------ 0.13836359977722168 seconds | MSE: 0.115 ------------------------------
# Execute Training and Walk Forward Testing for (Centrica PLC) for 48 times..
# ------------------------------ 0.10034441947937012 seconds | MSE: 0.155 ------------------------------
# Execute Training and Walk Forward Testing for (Shire Ltd) for 41 times..
# ------------------------------ 0.05390739440917969 seconds | MSE: 0.349 ------------------------------
# Execute Training and Walk Forward Testing for (Imperial Brands PLC) for 56 times..
# ------------------------------ 0.12492108345031738 seconds | MSE: 0.042 ------------------------------
# Execute Training and Walk Forward Testing for (Ei Group Ltd) for 4 times..
# ------------------------------ 0.0013976097106933594 seconds | MSE: 1.009 ------------------------------
# Execute Training and Walk Forward Testing for (Rentokil Initial PLC) for 20 times..
# ------------------------------ 0.019537925720214844 seconds | MSE: 28.719 ------------------------------
# Execute Training and Walk Forward Testing for (National Grid PLC) for 56 times..
# ------------------------------ 0.1407167911529541 seconds | MSE: 0.052 ------------------------------
# Execute Training and Walk Forward Testing for (Home Retail Group Ltd) for 9 times..
# ------------------------------ 0.0036759376525878906 seconds | MSE: 0.074 ------------------------------
# Execute Training and Walk Forward Testing for (AstraZeneca PLC) for 56 times..
# ------------------------------ 0.11961913108825684 seconds | MSE: 0.058 ------------------------------
# Execute Training and Walk Forward Testing for (Intu Properties PLC) for 31 times..
# ------------------------------ 0.06096529960632324 seconds | MSE: 2.539 ------------------------------
# Execute Training and Walk Forward Testing for (SSE PLC) for 56 times..
# ------------------------------ 0.1169121265411377 seconds | MSE: 0.096 ------------------------------
# Execute Training and Walk Forward Testing for (International Power Ltd) for 18 times..
# ------------------------------ 0.01786184310913086 seconds | MSE: 1852.744 ------------------------------
# Execute Training and Walk Forward Testing for (Capricorn Energy PLC) for 14 times..
# ------------------------------ 0.03488802909851074 seconds | MSE: 6.809 ------------------------------
# Execute Training and Walk Forward Testing for (Persimmon PLC) for 38 times..
# ------------------------------ 0.052240610122680664 seconds | MSE: 5.962 ------------------------------
# Execute Training and Walk Forward Testing for (Shell PLC) for 56 times..
# ------------------------------ 0.14036154747009277 seconds | MSE: 0.154 ------------------------------

# %%
np.mean(mresults_m1_dev21['MSE^3'])
# Out:
# 12.725661997261444

# %%
np.mean(mresults_m3_dev21['MSE^3'])
# Out:
# 18.252256758710207

# %%
ori_har_perf()
# Out:
# m1 datasets: 0.7637676752645515
# m3 datasets: 69.87159748352417

# %%
ori_har_perf(mresults_m1_dev, mresults_m3_dev)
# Out:
# m1 datasets: 13.75543135123275
# m3 datasets: 16.149816685769252

# %%
ori_har_perf(mresults_m1_dev21, mresults_m3_dev21)
# Out:
# m1 datasets: 12.725661997261444
# m3 datasets: 18.252256758710207

# %% [markdown]
# ---

# %%
def compile_train_test(train_df, test_df, sample = True, algo = 'HAR', dataset = 'm1', viz = False, cap = True):
    '''
    '''

    if dataset == 'm1':
        cols = ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
        
    elif dataset == 'm2':
        cols = vif_check()
        print(cols)

    else:
        cols = [ 'buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar'
                ,'CSRStrategy','Community','Emissions','EnvironmentalInnovation','HumanRights','Management','ProductResponsibility'
                ,'ResourceUse','Shareholders','Workforce', 'vol_series_daily','vol_series_weekly','vol_series_monthly', 'V^YZ']
        
        # version 2
        cols = ['buzz','ESG','ESGCombined','ESGControversies','EnvironmentalPillar','GovernancePillar','SocialPillar','Community',
                'EnvironmentalInnovation','Management','ProductResponsibility','Shareholders','Workforce', 'V^YZ']

    mresults = pd.DataFrame()
    predictions_df = pd.DataFrame()

    if sample:
        # assets = [4295894970, 8589934212]
        assets = [8589934212, 8589934254] # 3rd and 4th most volatile stocks in FTSE 2006 to 2022
    else:
        assets = train_df.Asset.unique().tolist()

    for r, asset in enumerate(assets): 

        name = train_df[train_df['Asset'] == asset].iloc[0,-1]

        df_train = train_df[train_df.Asset == asset][cols].dropna()
        df_test = test_df[test_df.Asset == asset][cols].dropna()
        test_size = df_test.shape[0]
        
        # vif for each assets
        # df_merge = pd.concat([df_train, df_test])
        # cols = vif_dynamic_check(df_merge)
        # print(name, cols)
        # df_merge = df_merge[cols]
        # df_train = df_merge[df_merge.Asset == asset].iloc[:-test_size,: ]
        # df_test = df_merge[df_merge.Asset == asset].iloc[-test_size:,:]
        
        df_train = log1p(df_train)
        df_test = log1p(df_test)
        
        X_train = df_train.drop(['V^YZ'], axis=1)
        X_test = df_test.drop(['V^YZ'], axis=1)
        
        y_train = df_train['V^YZ']
        y_test = df_test['V^YZ']
        
        X_train = sm.add_constant(X_train)
        X_test.loc[:, 'const'] = 1
        X_test = X_test[X_train.columns]

        # Fit the model
        model = OLS(y_train, X_train)
        model_fit = model.fit()

        # display(X_test, X_train)
        y_pred = model_fit.predict(X_test)
        if cap:
            y_pred = y_pred.clip(lower = 0)
        
        mse_million = mean_squared_error(y_test,y_pred)*10**3
        mresult = pd.DataFrame({
            'Asset': asset,
            'Name': name,
            'Model': algo,
            'Test Size': test_size,
            'MSE^3':mse_million
                    }
            , index=[r]
        )

        
        y_test = expm1(y_test)
        y_pred = expm1(y_pred)
        
        prediction_df = pd.DataFrame({
            'Asset':asset,
            'Test Data': y_test,
            'Predictions': y_pred
        }, index = y_test.index)
        
        mresults = pd.concat([mresults, mresult])
        predictions_df = pd.concat([predictions_df, prediction_df])

        if viz: 
            vis_line_plot_results(y_pred, y_test, model = 'HAR', dataset=dataset, name=name, r = r)

    return mresults, predictions_df

# %%
mresults_m3_v11, pred = compile_train_test(train_df, test_df, sample=True, algo='HAR', dataset='m3', viz=False, cap = True)

# %%
mresults_m3_v11
# Out:
#         Asset                      Name Model  Test Size     MSE^3
# 0  8589934212         Natwest Group PLC   HAR         60  0.215461
# 1  8589934254  Lloyds Banking Group PLC   HAR         60  0.212880

# %%
pred.to_csv('../data/9-HAR-SAMPLE-PREDICTION-RESULTS.csv')
