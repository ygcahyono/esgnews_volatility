# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#LSTM-Arch-Experimentation" data-toc-modified-id="LSTM-Arch-Experimentation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>LSTM Arch Experimentation</a></span><ul class="toc-item"><li><span><a href="#First-Arch" data-toc-modified-id="First-Arch-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>First Arch</a></span><ul class="toc-item"><li><span><a href="#M3" data-toc-modified-id="M3-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>M3</a></span><ul class="toc-item"><li><span><a href="#Change-0" data-toc-modified-id="Change-0-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>Change 0</a></span></li><li><span><a href="#Change-1-(early_stop)" data-toc-modified-id="Change-1-(early_stop)-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span>Change 1 (early_stop)</a></span></li><li><span><a href="#Change-2-(lookback-7)" data-toc-modified-id="Change-2-(lookback-7)-1.1.1.3"><span class="toc-item-num">1.1.1.3&nbsp;&nbsp;</span>Change 2 (lookback 7)</a></span></li><li><span><a href="#Change-3-(lookback-5)" data-toc-modified-id="Change-3-(lookback-5)-1.1.1.4"><span class="toc-item-num">1.1.1.4&nbsp;&nbsp;</span>Change 3 (lookback 5)</a></span></li><li><span><a href="#Change-4-(lookback-14)" data-toc-modified-id="Change-4-(lookback-14)-1.1.1.5"><span class="toc-item-num">1.1.1.5&nbsp;&nbsp;</span>Change 4 (lookback 14)</a></span></li><li><span><a href="#Change-5-(optimiser-adam-0.001-LR)----legacy" data-toc-modified-id="Change-5-(optimiser-adam-0.001-LR)----legacy-1.1.1.6"><span class="toc-item-num">1.1.1.6&nbsp;&nbsp;</span>Change 5 (optimiser adam 0.001 LR) -- legacy</a></span></li><li><span><a href="#Change-6-(optimiser-adam-0.001-LR-Legacy-and-L1)" data-toc-modified-id="Change-6-(optimiser-adam-0.001-LR-Legacy-and-L1)-1.1.1.7"><span class="toc-item-num">1.1.1.7&nbsp;&nbsp;</span>Change 6 (optimiser adam 0.001 LR Legacy and L1)</a></span></li><li><span><a href="#Change-7-(optimiser-adam-0.001-LR-Legacy-and-L1-and-reduce-to-past-history-30)" data-toc-modified-id="Change-7-(optimiser-adam-0.001-LR-Legacy-and-L1-and-reduce-to-past-history-30)-1.1.1.8"><span class="toc-item-num">1.1.1.8&nbsp;&nbsp;</span>Change 7 (optimiser adam 0.001 LR Legacy and L1 and reduce to past history 30)</a></span></li><li><span><a href="#Change-8-(optimiser-adam-0.001-LR-Legacy-and-L1-and-keep-history-60,-adding-kernel-initialiser-with-glorot_normal)" data-toc-modified-id="Change-8-(optimiser-adam-0.001-LR-Legacy-and-L1-and-keep-history-60,-adding-kernel-initialiser-with-glorot_normal)-1.1.1.9"><span class="toc-item-num">1.1.1.9&nbsp;&nbsp;</span>Change 8 (optimiser adam 0.001 LR Legacy and L1 and keep history 60, adding kernel initialiser with glorot_normal)</a></span></li><li><span><a href="#Change-8---It's-better-but-the-prediction-is-FLAT.-Try-All-Data-to-Train-adding-columns-m3-from-m1-change-the-past-history-to-90-it-GOOD!" data-toc-modified-id="Change-8---It's-better-but-the-prediction-is-FLAT.-Try-All-Data-to-Train-adding-columns-m3-from-m1-change-the-past-history-to-90-it-GOOD!-1.1.1.10"><span class="toc-item-num">1.1.1.10&nbsp;&nbsp;</span>Change 8 - It's better but the prediction is FLAT. Try All Data to Train adding columns m3 from m1 change the past history to 90 it GOOD!</a></span></li><li><span><a href="#Change-9---It's-better-but-the-prediction-is-FLAT.-Try-All-Data-to-Train-adding-columns-m3-from-m1-change-the-past-history-to-120-it's-GOOD!" data-toc-modified-id="Change-9---It's-better-but-the-prediction-is-FLAT.-Try-All-Data-to-Train-adding-columns-m3-from-m1-change-the-past-history-to-120-it's-GOOD!-1.1.1.11"><span class="toc-item-num">1.1.1.11&nbsp;&nbsp;</span>Change 9 - It's better but the prediction is FLAT. Try All Data to Train adding columns m3 from m1 change the past history to 120 it's GOOD!</a></span></li><li><span><a href="#Change-10---IT'S-GETTING-BETTER;-Change-to-128-with-only-1-hidden-layer" data-toc-modified-id="Change-10---IT'S-GETTING-BETTER;-Change-to-128-with-only-1-hidden-layer-1.1.1.12"><span class="toc-item-num">1.1.1.12&nbsp;&nbsp;</span>Change 10 - IT'S GETTING BETTER; Change to 128 with only 1 hidden layer</a></span></li><li><span><a href="#Change-11---IT'S-GETTING-BETTER;-128-too-much-setting-32-with-3-hidden-layers" data-toc-modified-id="Change-11---IT'S-GETTING-BETTER;-128-too-much-setting-32-with-3-hidden-layers-1.1.1.13"><span class="toc-item-num">1.1.1.13&nbsp;&nbsp;</span>Change 11 - IT'S GETTING BETTER; 128 too much setting 32 with 3 hidden layers</a></span></li><li><span><a href="#Change-12---IT'S-GETTING-BETTER;-32-with-3-hidden-layers-to-16-with-4-hidden-layer" data-toc-modified-id="Change-12---IT'S-GETTING-BETTER;-32-with-3-hidden-layers-to-16-with-4-hidden-layer-1.1.1.14"><span class="toc-item-num">1.1.1.14&nbsp;&nbsp;</span>Change 12 - IT'S GETTING BETTER; 32 with 3 hidden layers to 16 with 4 hidden layer</a></span></li></ul></li></ul></li><li><span><a href="#Second-Arch" data-toc-modified-id="Second-Arch-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Second Arch</a></span><ul class="toc-item"><li><span><a href="#M3---Lookback-60" data-toc-modified-id="M3---Lookback-60-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>M3 - Lookback 60</a></span></li><li><span><a href="#M1" data-toc-modified-id="M1-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>M1</a></span></li></ul></li></ul></li><li><span><a href="#Clean-Final-Running-Three-Datasets" data-toc-modified-id="Clean-Final-Running-Three-Datasets-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Clean Final Running Three Datasets</a></span><ul class="toc-item"><li><span><a href="#Experiment-1-(Original)" data-toc-modified-id="Experiment-1-(Original)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Experiment 1 (Original)</a></span><ul class="toc-item"><li><span><a href="#m1" data-toc-modified-id="m1-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>m1</a></span></li><li><span><a href="#m2" data-toc-modified-id="m2-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>m2</a></span></li><li><span><a href="#m3" data-toc-modified-id="m3-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>m3</a></span></li></ul></li><li><span><a href="#Experiment-2-(LB-30)" data-toc-modified-id="Experiment-2-(LB-30)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Experiment 2 (LB 30)</a></span><ul class="toc-item"><li><span><a href="#M3" data-toc-modified-id="M3-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>M3</a></span></li></ul></li><li><span><a href="#Experiment-3-(LB-90-MNTH)" data-toc-modified-id="Experiment-3-(LB-90-MNTH)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Experiment 3 (LB 90 MNTH)</a></span><ul class="toc-item"><li><span><a href="#M3" data-toc-modified-id="M3-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>M3</a></span></li></ul></li><li><span><a href="#Experiment-4-(LB-90-MNTH--64---2-HL)" data-toc-modified-id="Experiment-4-(LB-90-MNTH--64---2-HL)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Experiment 4 (LB 90 MNTH- 64 - 2 HL)</a></span><ul class="toc-item"><li><span><a href="#M3" data-toc-modified-id="M3-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>M3</a></span></li></ul></li><li><span><a href="#Experiment-5-(LB-90-MNTH--128---1-HL)" data-toc-modified-id="Experiment-5-(LB-90-MNTH--128---1-HL)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Experiment 5 (LB 90 MNTH- 128 - 1 HL)</a></span><ul class="toc-item"><li><span><a href="#M3" data-toc-modified-id="M3-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>M3</a></span></li></ul></li><li><span><a href="#Experiment-6-(LB-90-MNTH--128---1-HL)-LAG-1-DAY" data-toc-modified-id="Experiment-6-(LB-90-MNTH--128---1-HL)-LAG-1-DAY-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Experiment 6 (LB 90 MNTH- 128 - 1 HL) LAG 1 DAY</a></span><ul class="toc-item"><li><span><a href="#m1" data-toc-modified-id="m1-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>m1</a></span></li></ul></li></ul></li><li><span><a href="#Experiment-6-(LB-90-MNTH--128---1-HL)-UPDATED-DATASET-WITH-PROPER-LAG" data-toc-modified-id="Experiment-6-(LB-90-MNTH--128---1-HL)-UPDATED-DATASET-WITH-PROPER-LAG-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Experiment 6 (LB 90 MNTH- 128 - 1 HL) UPDATED DATASET WITH PROPER LAG</a></span><ul class="toc-item"><li><span><a href="#Experiment-1-(LB-90)" data-toc-modified-id="Experiment-1-(LB-90)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Experiment 1 (LB 90)</a></span><ul class="toc-item"><li><span><a href="#M1" data-toc-modified-id="M1-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>M1</a></span></li><li><span><a href="#M2" data-toc-modified-id="M2-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>M2</a></span></li><li><span><a href="#M3" data-toc-modified-id="M3-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>M3</a></span></li></ul></li><li><span><a href="#Experiment-1-(LB-60)" data-toc-modified-id="Experiment-1-(LB-60)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Experiment 1 (LB 60)</a></span><ul class="toc-item"><li><span><a href="#M1" data-toc-modified-id="M1-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>M1</a></span></li><li><span><a href="#M2" data-toc-modified-id="M2-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>M2</a></span></li><li><span><a href="#M3" data-toc-modified-id="M3-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>M3</a></span></li></ul></li><li><span><a href="#Experiment-3-(LB-7)" data-toc-modified-id="Experiment-3-(LB-7)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Experiment 3 (LB 7)</a></span><ul class="toc-item"><li><span><a href="#M1" data-toc-modified-id="M1-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>M1</a></span></li><li><span><a href="#M2" data-toc-modified-id="M2-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>M2</a></span></li><li><span><a href="#M3" data-toc-modified-id="M3-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>M3</a></span></li></ul></li><li><span><a href="#Experiment-2-(LB-30)" data-toc-modified-id="Experiment-2-(LB-30)-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Experiment 2 (LB 30)</a></span><ul class="toc-item"><li><span><a href="#M1" data-toc-modified-id="M1-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>M1</a></span></li><li><span><a href="#M2" data-toc-modified-id="M2-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>M2</a></span></li><li><span><a href="#M3" data-toc-modified-id="M3-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>M3</a></span></li></ul></li><li><span><a href="#Experiment-2-4" data-toc-modified-id="Experiment-2-4-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Experiment 2-4</a></span><ul class="toc-item"><li><span><a href="#M1" data-toc-modified-id="M1-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>M1</a></span></li><li><span><a href="#M2" data-toc-modified-id="M2-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>M2</a></span></li><li><span><a href="#M3" data-toc-modified-id="M3-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>M3</a></span></li></ul></li></ul></li></ul></div>

# %%
# !pip install yfinance
# !pip install gtab
# !pip install statsmodels
# !pip install mlxtend
# !pip install arch
# Out:
# WARNING: Skipping /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/numpy-1.24.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/numpy-1.24.3.dist-info due to invalid metadata entry 'name'
# ...
# WARNING: Skipping /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/numpy-1.24.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/numpy-1.24.3.dist-info due to invalid metadata entry 'name'
#
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# WARNING: Skipping /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/numpy-1.24.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/numpy-1.24.3.dist-info due to invalid metadata entry 'name'
# ...

# %%
# !pip install tensorflow
# Out:
# WARNING: Skipping /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/numpy-1.24.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/yogi/miniconda3/envs/nlp2/lib/python3.11/site-packages/numpy-1.24.3.dist-info due to invalid metadata entry 'name'
# ...
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/d6/69/d461fa09235326e08b7ca463d5491426fdd4908ef6d3f9ed51d0777dc071/tensorflow-2.13.0-cp311-cp311-macosx_12_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for tensorflow-macos==2.13.0 from https://files.pythonhosted.org/packages/f1/cc/6c262ae6f3a23b118b1104fa5f6126067744ffa9226faade202b0a20bdd3/tensorflow_macos-2.13.0-cp311-cp311-macosx_12_0_arm64.whl.metadata
# ...
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...

# %%
import sys, os
import pandas as pd
import numpy as np
from keras.callbacks import EarlyStopping
sys.path.append('../python')
pd.set_option('display.max_columns', 100)

from dataprocessingnew2 import *
from runmodels import *
from LSTM_MS_II import *
# from util import Run_Algorithms

import glob

# dataprocessing = DataProcessing('2006-01-01', '2022-12-01', daily=True)
# df_clean, train_df, test_df = dataprocessing.clean_final(fillna = True)

# %%
# %store train_df
# %store test_df

# %%
# %store -r train_df
# %store -r test_df

# %%
coverage_df = pd.read_csv('../data/coverage_dataframe.csv')[['PermID', 'Name', 'TRBCEconomicSector']]
coverage_df['PermID'] = coverage_df.PermID.astype(int)

unique_assets_df = pd.DataFrame({
    'Assets': train_df.Asset.unique()
})

unique_assets_df = pd.merge(unique_assets_df, coverage_df, how = 'left', left_on = 'Assets', right_on= 'PermID')
unique_assets_df = unique_assets_df.iloc[:, 1:]
unique_assets_df.columns = ['Assets', 'Firm Name', 'Economic Sector']

sectors_df = pd.DataFrame(np.unique(unique_assets_df['Economic Sector'], return_counts=True)).T
sectors_df.columns = ['sectors','num_firms']

# %%
sectors_df
# Out:
#                   sectors num_firms
# 0         Basic materials        11
# 1      Consumer cyclicals        15
# 2  Consumer non-cyclicals        13
# 3                  Energy         2
# 4              Financials        16
# 5              Healthcare         4
# 6             Industrials        13
# 7             Real estate         3
# 8              Technology         3
# 9               Utilities         5

# %% [markdown]
# # LSTM Arch Experimentation

# %% [markdown]
# ## First Arch

# %% [markdown]
# ### M3

# %% [markdown]
# #### Change 0

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [False,0.1]
hu = 64
early_stop = None #default

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, depth = hidden_layer, 
                              early_stop = early_stop, hu = hu, features = features, 
                              infer_train= False, dropout=dropout)
    LSTM_1.full_workflow_and_plot()
    break
# Out:
# ------------------------------ Basic materials ------------------------------
# ['buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/lstm-arch-1/change0/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.27434963333333334

# %% [markdown]
# #### Change 1 (early_stop)

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [False,0.1]
hu = 64
early_stop = True #default

gaussian = None
activation = 'linear' # default



for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ Basic materials ------------------------------
# ['buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Epoch 6: early stopping
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.2601082866666666

# %% [markdown]
# #### Change 2 (lookback 7)

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [False,0.1]
hu = 64
early_stop = True #default
past_history = 7

gaussian = None
activation = 'linear' # default



for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ Basic materials ------------------------------
# ['buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Epoch 6: early stopping
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.3325301399999999

# %% [markdown]
# #### Change 3 (lookback 5)

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [False,0.1]
hu = 64
early_stop = True #default
past_history = 5

gaussian = None
activation = 'linear' # default



for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ Basic materials ------------------------------
# ['buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Epoch 17: early stopping
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.3470569066666667

# %% [markdown]
# #### Change 4 (lookback 14)

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [False,0.1]
hu = 64
early_stop = True #default
past_history = 14

gaussian = None
activation = 'linear' # default


for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ Basic materials ------------------------------
# ['buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Epoch 7: early stopping
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.37882756666666667

# %% [markdown]
# #### Change 5 (optimiser adam 0.001 LR) -- legacy

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [False,0.1]
hu = 64
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ Basic materials ------------------------------
# ['buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Restoring model weights from the end of the best epoch: 1.
# Epoch 11: early stopping
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.20829483999999995

# %% [markdown]
# #### Change 6 (optimiser adam 0.001 LR Legacy and L1)
# its getting better with the adam learning rate 0.001
# the next step is I tried to employ the regularisation L1, Why because it seems overfitting

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [False,0.1]
hu = 64
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ Basic materials ------------------------------
# ['buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 64)            19968
#
#  lstm_1 (LSTM)               (None, 60, 64)            33024
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# ...
# Total params: 86081 (336.25 KB)
# Trainable params: 86081 (336.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.16874246666666667

# %% [markdown]
# #### Change 7 (optimiser adam 0.001 LR Legacy and L1 and reduce to past history 30)

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [False,0.1]
hu = 64
early_stop = True #default
past_history = 30

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ Basic materials ------------------------------
# ['buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 30, 64)            19968
#
#  lstm_1 (LSTM)               (None, 30, 64)            33024
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# ...
# Total params: 86081 (336.25 KB)
# Trainable params: 86081 (336.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.22742956666666667

# %% [markdown]
# #### Change 8 (optimiser adam 0.001 LR Legacy and L1 and keep history 60, adding kernel initialiser with glorot_normal)

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [False,0.1]
hu = 64
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ Basic materials ------------------------------
# ['buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 64)            19968
#
#  lstm_1 (LSTM)               (None, 60, 64)            33024
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# ...
# Total params: 86081 (336.25 KB)
# Trainable params: 86081 (336.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.1699401266666666

# %% [markdown]
# ##### Does not change much let's reduce the complexity adding drop out and see the progress

# %%
predict_days = 200
hidden_layer = 2
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 32
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ Basic materials ------------------------------
# ['buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 32)            5888
#
#  dropout (Dropout)           (None, 60, 32)            0
#
#  lstm_1 (LSTM)               (None, 60, 32)            8320
#
#  lstm_2 (LSTM)               (None, 60, 32)            8320
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  dense (Dense)               (None, 1)                 33
#
# ...
# Total params: 30881 (120.63 KB)
# Trainable params: 30881 (120.63 KB)
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.1664478533333333

# %% [markdown]
# #### Change 8 - It's better but the prediction is FLAT. Try All Data to Train adding columns m3 from m1 change the past history to 90 it GOOD!

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 64
early_stop = True #default
past_history = 120

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 120, 64)           20736
#
#  dropout (Dropout)           (None, 120, 64)           0
#
#  lstm_1 (LSTM)               (None, 120, 64)           33024
#
#  dropout_1 (Dropout)         (None, 120, 64)           0
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# ...
# Total params: 86849 (339.25 KB)
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.0200735

# %% [markdown]
# #### Change 9 - It's better but the prediction is FLAT. Try All Data to Train adding columns m3 from m1 change the past history to 120 it's GOOD!

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 64
early_stop = True #default
past_history = 120

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 120, 64)           20736
#
#  dropout (Dropout)           (None, 120, 64)           0
#
#  lstm_1 (LSTM)               (None, 120, 64)           33024
#
#  dropout_1 (Dropout)         (None, 120, 64)           0
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# ...
# Total params: 86849 (339.25 KB)
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.0013933

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.0276665

# %% [markdown]
# #### Change 10 - IT'S GETTING BETTER; Change to 128 with only 1 hidden layer

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 120

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 120, 128)          74240
#
#  dropout (Dropout)           (None, 120, 128)          0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 205953 (804.50 KB)
# Trainable params: 205953 (804.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.0027310000000000004

# %% [markdown]
# #### Change 11 - IT'S GETTING BETTER; 128 too much setting 32 with 3 hidden layers

# %%
# from util import Run_Algorithms
# %store -r test_df
# %store -r train_df

from keras.callbacks import EarlyStopping
import glob
import numpy as np
import pandas as pd
import sys, os

pd.set_option('display.max_columns', 100)
sys.path.append('../python')

from dataprocessingnew import *
from LSTM_MS import *
from runmodels import *

dataprocessing = DataProcessing('2006-01-01', '2022-12-01', daily=True)
df_clean, train_df, test_df = dataprocessing.clean_final(fillna = True)

coverage_df = pd.read_csv('../data/coverage_dataframe.csv')[['PermID', 'Name', 'TRBCEconomicSector']]
coverage_df['PermID'] = coverage_df.PermID.astype(int)

unique_assets_df = pd.DataFrame({
    'Assets': train_df.Asset.unique()
})

unique_assets_df = pd.merge(unique_assets_df, coverage_df, how = 'left', left_on = 'Assets', right_on= 'PermID')
unique_assets_df = unique_assets_df.iloc[:, 1:]
unique_assets_df.columns = ['Assets', 'Firm Name', 'Economic Sector']

sectors_df = pd.DataFrame(np.unique(unique_assets_df['Economic Sector'], return_counts=True)).T
sectors_df.columns = ['sectors','num_firms']
# Out:
# 209
# (395600, 24)

# %%
sectors_df.num_firms.sum()
# Out:
# 83

# %% [markdown]
# ##### This is PER SECTOR NOT PIT data but still eliminating < 2015 and > 2020

# %%
# this is batching with new dataset that only cover 100 ftse

predict_days = 200
hidden_layer = 2
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 32
early_stop = True #default
past_history = 120

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    # sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
# Out:
# ------------------------------ Basic materials ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 120, 32)           6272
#
#  dropout (Dropout)           (None, 120, 32)           0
#
#  lstm_1 (LSTM)               (None, 120, 32)           8320
#
#  dropout_1 (Dropout)         (None, 120, 32)           0
#
#  lstm_2 (LSTM)               (None, 120, 32)           8320
#
#  dropout_2 (Dropout)         (None, 120, 32)           0
#
# ...

# %% [markdown]
# ##### This is will all sectors that using PIT data but still eliminating < 2015 and > 2020

# %%
predict_days = 200
hidden_layer = 2
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 32
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 32)            6272
#
#  dropout (Dropout)           (None, 60, 32)            0
#
#  lstm_1 (LSTM)               (None, 60, 32)            8320
#
#  dropout_1 (Dropout)         (None, 60, 32)            0
#
#  lstm_2 (LSTM)               (None, 60, 32)            8320
#
#  dropout_2 (Dropout)         (None, 60, 32)            0
#
# ...

# %% [markdown]
# ##### This is will all sectors that using PIT data but still eliminating < 2015 and > 2020 (Adding validation set)

# %%
predict_days = 200
hidden_layer = 2
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 32
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.7, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 32)            6272
#
#  dropout (Dropout)           (None, 60, 32)            0
#
#  lstm_1 (LSTM)               (None, 60, 32)            8320
#
#  dropout_1 (Dropout)         (None, 60, 32)            0
#
#  lstm_2 (LSTM)               (None, 60, 32)            8320
#
#  dropout_2 (Dropout)         (None, 60, 32)            0
#
# ...

# %% [markdown]
# ##### Past Result

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.0008625

# %% [markdown]
# ##### All Result (0.10250733611111112)

# %% [markdown]
# ##### Batching per sector (0.10250733611111112)

# %% [markdown]
# #### Change 12 - IT'S GETTING BETTER; 32 with 3 hidden layers to 16 with 4 hidden layer

# %%
predict_days = 200
hidden_layer = 3
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 16
early_stop = True #default
past_history = 120

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 120, 16)           2112
#
#  dropout (Dropout)           (None, 120, 16)           0
#
#  lstm_1 (LSTM)               (None, 120, 16)           2112
#
#  dropout_1 (Dropout)         (None, 120, 16)           0
#
#  lstm_2 (LSTM)               (None, 120, 16)           2112
#
#  dropout_2 (Dropout)         (None, 120, 16)           0
#
# ...

# %%
# Get a list of all csv files that start with "LSTM-m1-"
csv_files = glob.glob("../results/LSTM-m3-*.csv")

master_df = pd.DataFrame()

# Print the list of csv files
for file in csv_files:
    temp_df = pd.read_csv(file)
    master_df = pd.concat([master_df, temp_df])
    
master_df['MSE^3'] = master_df['MSE'] * 10**3
np.mean(master_df['MSE^3'])
# Out:
# 0.0009912999999999999

# %% [markdown]
# ## Second Arch

# %% [markdown]
# ### M3 - Lookback 60

# %% [markdown]
# > **DATA:** \
# > features = m3 \
# > lookback = 60
#
# > **LSTM:** \
# > depth = 1 \
# > hu = 64 \
# > output_size = 1 \
# > lags = 60 \
# > features = 5 \
# > activation = None
# > early_stop = None
# > dropout = False

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm3'
dropout = [True, 0.3]
hu = 64
early_stop = True #default

gaussian = None
activation = 'linear' # default



for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ Basic materials ------------------------------
# ['buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Epoch 11: early stopping
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# length of actual value 199, length of predicted value 199
# ...

# %% [markdown]
# ### M1

# %% [markdown]
# > **DATA:** \
# > features = m3 \
# > lookback = 60
#
# > **LSTM:** \
# > depth = 1 \
# > hu = 64 \
# > output_size = 1 \
# > lags = 60 \
# > features = 5 \
# > activation = None
# > early_stop = None
# > dropout = False

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm1'
dropout = [True, 0.3]
hu = 64
early_stop = True #default

gaussian = None
activation = 'linear' # default



for sector in sectors_df.sectors.tolist():
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop)
    
    LSTM_1.full_workflow_and_plot()
    
    break

# %% [markdown]
# # Clean Final Running Three Datasets

# %% [markdown]
# ## Experiment 1 (Original)

# %%
# from util import Run_Algorithms
# %store -r test_df
# %store -r train_df

from keras.callbacks import EarlyStopping
import glob
import numpy as np
import pandas as pd
import sys, os

pd.set_option('display.max_columns', 100)
sys.path.append('../python')

from dataprocessingnew import *
from LSTM_MS import *
from runmodels import *

dataprocessing = DataProcessing('2006-01-01', '2022-12-01', daily=True)
df_clean, train_df, test_df = dataprocessing.clean_final(fillna = True)

coverage_df = pd.read_csv('../data/coverage_dataframe.csv')[['PermID', 'Name', 'TRBCEconomicSector']]
coverage_df['PermID'] = coverage_df.PermID.astype(int)

unique_assets_df = pd.DataFrame({
    'Assets': train_df.Asset.unique()
})

unique_assets_df = pd.merge(unique_assets_df, coverage_df, how = 'left', left_on = 'Assets', right_on= 'PermID')
unique_assets_df = unique_assets_df.iloc[:, 1:]
unique_assets_df.columns = ['Assets', 'Firm Name', 'Economic Sector']

sectors_df = pd.DataFrame(np.unique(unique_assets_df['Economic Sector'], return_counts=True)).T
sectors_df.columns = ['sectors','num_firms']
# Out:
# 209
# (389669, 25)

# %%
# %store train_df
# %store test_df
# Out:
# Stored 'train_df' (DataFrame)
# Stored 'test_df' (DataFrame)

# %% [markdown]
# ---

# %% [markdown]
# > **DATA:** \
# > features = m3 \
# > lookback = 60 \
# > All Datasets in One Train
#
# > **LSTM:** \
# > depth = 1 \
# > dropout = [True, 0.3]
# > hu = 32 \
# > output_size = 1 \
# > lags = 60 \
# > activation = Linear \
# > early_stop = True \

# %% [markdown]
# ### m1

# %%
predict_days = 200
hidden_layer = 2
epoch = 100
features = 'm1'
dropout = [True,0.3]
hu = 32
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 32)            4608
#
#  dropout (Dropout)           (None, 60, 32)            0
#
#  lstm_1 (LSTM)               (None, 60, 32)            8320
#
#  dropout_1 (Dropout)         (None, 60, 32)            0
#
#  lstm_2 (LSTM)               (None, 60, 32)            8320
#
#  dropout_2 (Dropout)         (None, 60, 32)            0
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  dense (Dense)               (None, 1)                 33
#
# ...
# Total params: 29601 (115.63 KB)
# Trainable params: 29601 (115.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %% [markdown]
# ### m2

# %%
predict_days = 200
hidden_layer = 2
epoch = 100
features = 'm2'
dropout = [True,0.3]
hu = 32
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'EnvironmentalPillar', 'Community', 'Shareholders', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 32)            5120
#
#  dropout (Dropout)           (None, 60, 32)            0
#
#  lstm_1 (LSTM)               (None, 60, 32)            8320
#
#  dropout_1 (Dropout)         (None, 60, 32)            0
#
#  lstm_2 (LSTM)               (None, 60, 32)            8320
#
#  dropout_2 (Dropout)         (None, 60, 32)            0
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  dense (Dense)               (None, 1)                 33
#
# ...
# Total params: 30113 (117.63 KB)
# Trainable params: 30113 (117.63 KB)
# ...

# %% [markdown]
# ### m3

# %%
predict_days = 200
hidden_layer = 2
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 32
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 32)            6272
#
#  dropout (Dropout)           (None, 60, 32)            0
#
#  lstm_1 (LSTM)               (None, 60, 32)            8320
#
#  dropout_1 (Dropout)         (None, 60, 32)            0
#
#  lstm_2 (LSTM)               (None, 60, 32)            8320
#
#  dropout_2 (Dropout)         (None, 60, 32)            0
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Experiment 2 (LB 30)

# %% [markdown]
# > **DATA:** \
# > features = m3 \
# > lookback = 30 \
# > All Datasets in One Train
#
# > **LSTM:** \
# > depth = 1 \
# > dropout = [True, 0.3]
# > hu = 32 \
# > output_size = 1 \
# > lags = 60 \
# > activation = Linear \
# > early_stop = True \

# %% [markdown]
# ### M3

# %%
predict_days = 200
hidden_layer = 2
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 32
early_stop = True #default
past_history = 30

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 30, 32)            6272
#
#  dropout (Dropout)           (None, 30, 32)            0
#
#  lstm_1 (LSTM)               (None, 30, 32)            8320
#
#  dropout_1 (Dropout)         (None, 30, 32)            0
#
#  lstm_2 (LSTM)               (None, 30, 32)            8320
#
#  dropout_2 (Dropout)         (None, 30, 32)            0
#
# ...

# %% [markdown]
# ## Experiment 3 (LB 90 MNTH)

# %% [markdown]
# > **DATA:** \
# > features = m3 \
# > lookback = 90 \
# > All Datasets in One Train
#
# > **LSTM:** \
# > depth = 1 \
# > dropout = [True, 0.3]
# > hu = 32 \
# > output_size = 1 \
# > activation = Linear \
# > early_stop = True \

# %% [markdown]
# ### M3

# %%
predict_days = 200
hidden_layer = 2
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 32
early_stop = True #default
past_history = 90

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 90, 32)            6272
#
#  dropout (Dropout)           (None, 90, 32)            0
#
#  lstm_1 (LSTM)               (None, 90, 32)            8320
#
#  dropout_1 (Dropout)         (None, 90, 32)            0
#
#  lstm_2 (LSTM)               (None, 90, 32)            8320
#
#  dropout_2 (Dropout)         (None, 90, 32)            0
#
# ...

# %% [markdown]
# ## Experiment 4 (LB 90 MNTH- 64 - 2 HL)

# %% [markdown]
# > **DATA:** \
# > features = m3 \
# > lookback = 90 \
# > All Datasets in One Train
#
# > **LSTM:** \
# > depth = 1 \
# > dropout = [True, 0.3]
# > hu = 32 \
# > output_size = 1 \
# > activation = Linear \
# > early_stop = True \

# %% [markdown]
# ### M3

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 64
early_stop = True #default
past_history = 90

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    
    LSTM_1.full_workflow_and_plot()
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 90, 64)            20736
#
#  dropout (Dropout)           (None, 90, 64)            0
#
#  lstm_1 (LSTM)               (None, 90, 64)            33024
#
#  dropout_1 (Dropout)         (None, 90, 64)            0
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# ...
# Total params: 86849 (339.25 KB)
# ...

# %% [markdown]
# ## Experiment 5 (LB 90 MNTH- 128 - 1 HL)

# %% [markdown]
# > **DATA:** \
# > features = m3 \
# > lookback = 90 \
# > All Datasets in One Train
#
# > **LSTM:** \
# > depth = 1 \
# > dropout = [True, 0.3]
# > hu = 32 \
# > output_size = 1 \
# > activation = Linear \
# > early_stop = True \

# %% [markdown]
# ### M3

# %%
# from util import Run_Algorithms
# %store -r test_df
# %store -r train_df

from keras.callbacks import EarlyStopping
import glob
import numpy as np
import pandas as pd
import sys, os

pd.set_option('display.max_columns', 100)
sys.path.append('../python')

from dataprocessingnew2 import *
from LSTM_MS import *
from runmodels import *

dataprocessing = DataProcessing('2006-01-01', '2022-12-01', daily=True)
df_clean, train_df, test_df = dataprocessing.clean_final(fillna = True)
# Out:
# 209
# (389669, 25)

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (270491, 28)
# (17000, 28)

# %%
coverage_df = pd.read_csv('../data/coverage_dataframe.csv')[['PermID', 'Name', 'TRBCEconomicSector']]
coverage_df['PermID'] = coverage_df.PermID.astype(int)

unique_assets_df = pd.DataFrame({
    'Assets': train_df.Asset.unique()
})

unique_assets_df = pd.merge(unique_assets_df, coverage_df, how = 'left', left_on = 'Assets', right_on= 'PermID')
unique_assets_df = unique_assets_df.iloc[:, 1:]
unique_assets_df.columns = ['Assets', 'Firm Name', 'Economic Sector']

sectors_df = pd.DataFrame(np.unique(unique_assets_df['Economic Sector'], return_counts=True)).T
sectors_df.columns = ['sectors','num_firms']

# %%
print(len(train_df.Asset.unique()))
display(sectors_df)
# Out:
# 85
#                   sectors num_firms
# 0         Basic materials        11
# 1      Consumer cyclicals        15
# 2  Consumer non-cyclicals        13
# 3                  Energy         2
# 4              Financials        16
# 5              Healthcare         4
# 6             Industrials        13
# 7             Real estate         3
# 8              Technology         3
# 9               Utilities         5

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 90

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 90, 128)           74240
#
#  dropout (Dropout)           (None, 90, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 205953 (804.50 KB)
# Trainable params: 205953 (804.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %% [markdown]
# ## Experiment 6 (LB 90 MNTH- 128 - 1 HL) LAG 1 DAY

# %% [markdown]
# ### m1

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm1'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 90

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 90, 128)           67584
#
#  dropout (Dropout)           (None, 90, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 199297 (778.50 KB)
# Trainable params: 199297 (778.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 22.
# Epoch 32: early stopping
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# ...

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 90

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 90, 128)           74240
#
#  dropout (Dropout)           (None, 90, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 205953 (804.50 KB)
# Trainable params: 205953 (804.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm2'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 90

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'SocialPillar', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 90, 128)           69632
#
#  dropout (Dropout)           (None, 90, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 201345 (786.50 KB)
# Trainable params: 201345 (786.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 15.
# Epoch 25: early stopping
# Running model_LSTM() is done
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Experiment 6 (LB 90 MNTH- 128 - 1 HL) UPDATED DATASET WITH PROPER LAG

# %% [markdown]
# ## Experiment 1 (LB 90)

# %% [markdown]
# ### M1

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm1'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 90

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 90, 128)           67584
#
#  dropout (Dropout)           (None, 90, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 199297 (778.50 KB)
# Trainable params: 199297 (778.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 12.
# Epoch 22: early stopping
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# ...

# %% [markdown]
# ### M2

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm2'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 90

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'GovernancePillar', 'Management', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 90, 128)           69632
#
#  dropout (Dropout)           (None, 90, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 201345 (786.50 KB)
# Trainable params: 201345 (786.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 2.
# Epoch 12: early stopping
# Running model_LSTM() is done
# ...

# %% [markdown]
# ### M3

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 90

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 90, 128)           74240
#
#  dropout (Dropout)           (None, 90, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 205953 (804.50 KB)
# Trainable params: 205953 (804.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %% [markdown]
# ## Experiment 1 (LB 60)

# %%
from keras.callbacks import EarlyStopping
import glob
import numpy as np
import pandas as pd
import sys, os

pd.set_option('display.max_columns', 100)
sys.path.append('../python')

from dataprocessingnew2 import *
from LSTM_MS import *
from runmodels import *

dataprocessing = DataProcessing('2006-01-01', '2022-12-01', daily=True)
df_clean, train_df, test_df = dataprocessing.clean_final(fillna = True)
# Out:
# 209
# (389669, 25)

# %%
# %store train_df
# %store test_df
# Out:
# Stored 'train_df' (DataFrame)
# Stored 'test_df' (DataFrame)

# %% [markdown]
# ### M1

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm1'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 128)           67584
#
#  dropout (Dropout)           (None, 60, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 199297 (778.50 KB)
# Trainable params: 199297 (778.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 14.
# Epoch 24: early stopping
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# ...

# %% [markdown]
# ### M2

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm2'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'GovernancePillar', 'Management', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 128)           69632
#
#  dropout (Dropout)           (None, 60, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 201345 (786.50 KB)
# Trainable params: 201345 (786.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 6.
# Epoch 16: early stopping
# Running model_LSTM() is done
# ...

# %% [markdown]
# ### M3

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 60

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 128)           74240
#
#  dropout (Dropout)           (None, 60, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 205953 (804.50 KB)
# Trainable params: 205953 (804.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %% [markdown]
# ## Experiment 3 (LB 7)

# %% [markdown]
# ### M1

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm1'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 7

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 7, 128)            67584
#
#  dropout (Dropout)           (None, 7, 128)            0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 199297 (778.50 KB)
# Trainable params: 199297 (778.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 20.
# Epoch 30: early stopping
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# ...

# %% [markdown]
# ### M2

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm2'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 7

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'GovernancePillar', 'Management', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 7, 128)            69632
#
#  dropout (Dropout)           (None, 7, 128)            0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 201345 (786.50 KB)
# Trainable params: 201345 (786.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 20.
# Epoch 30: early stopping
# Running model_LSTM() is done
# ...

# %% [markdown]
# ### M3

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 7

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 7, 128)            74240
#
#  dropout (Dropout)           (None, 7, 128)            0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 205953 (804.50 KB)
# Trainable params: 205953 (804.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %% [markdown]
# ## Experiment 2 (LB 30)

# %% [markdown]
# ### M1

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm1'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 30

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 30, 128)           67584
#
#  dropout (Dropout)           (None, 30, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 199297 (778.50 KB)
# Trainable params: 199297 (778.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 13.
# Epoch 23: early stopping
# Running model_LSTM() is done
# length of actual value 199, length of predicted value 199
# ...

# %% [markdown]
# ### M2

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm2'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 30

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'GovernancePillar', 'Management', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 30, 128)           69632
#
#  dropout (Dropout)           (None, 30, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 201345 (786.50 KB)
# Trainable params: 201345 (786.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 12.
# Epoch 22: early stopping
# Running model_LSTM() is done
# ...

# %% [markdown]
# ### M3

# %%
predict_days = 200
hidden_layer = 0
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 30

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 30, 128)           74240
#
#  dropout (Dropout)           (None, 30, 128)           0
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 205953 (804.50 KB)
# Trainable params: 205953 (804.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %% [markdown]
# ## Experiment 2-4

# %% [markdown]
# ### M1

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm1'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 30

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 30, 128)           67584
#
#  dropout (Dropout)           (None, 30, 128)           0
#
#  lstm_1 (LSTM)               (None, 30, 128)           131584
#
#  dropout_1 (Dropout)         (None, 30, 128)           0
#
#  lstm_2 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 330881 (1.26 MB)
# Trainable params: 330881 (1.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Restoring model weights from the end of the best epoch: 13.
# ...

# %% [markdown]
# ### M2

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm2'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 30

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'GovernancePillar', 'Management', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 30, 128)           69632
#
#  dropout (Dropout)           (None, 30, 128)           0
#
#  lstm_1 (LSTM)               (None, 30, 128)           131584
#
#  dropout_1 (Dropout)         (None, 30, 128)           0
#
#  lstm_2 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 332929 (1.27 MB)
# Trainable params: 332929 (1.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# ...

# %% [markdown]
# ### M3

# %%
predict_days = 200
hidden_layer = 1
epoch = 100
features = 'm3'
dropout = [True,0.3]
hu = 128
early_stop = True #default
past_history = 30

gaussian = None
activation = 'linear' # default

for sector in sectors_df.sectors.tolist():
    sector = 'All'
    print('--'*15, sector, '--'*15)
    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 
                              
                              train_test_split = 0.6, validation_split = .2,
                              
                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history)
    LSTM_1.full_workflow_and_plot()
    
    break
# Out:
# ------------------------------ All ------------------------------
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 25
#      16 tf.keras.backend.clear_session()
#      17 LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31',
#      18
#      19                           train_test_split = 0.6, validation_split = .2,
#    (...)
#      23                           infer_train= False, dropout = dropout, hu = hu,
#      24                           early_stop = early_stop, past_history= past_history)
# ---> 25 LSTM_1.full_workflow_and_plot()
#      27 break
#
# File ~/Docs/2022 - 2023/FTP/3rd Term/Dissertation/esgnews_volatility/notebook/../python/LSTM_MS_II.py:613, in LSTM_Model_MS_II.full_workflow_and_plot(self, model)
#     607 def full_workflow_and_plot(self, model = None):
#     608     '''
# ...

# %% [markdown]
# ---

# %%
predict_days = 200
hidden_layer = 3
epoch = 500
features = 'm3'
dropout = [True,0.8]
hu = 4
early_stop = True #default
past_history = 30
leaky_relu = 0.1
sector = 'All'

gaussian = None
activation = 'linear' # default

# %%
for _asset_ in unique_assets_df.Assets.tolist():

    tf.keras.backend.clear_session()
    LSTM_1 = LSTM_Model_MS_II(train_df, test_df, '2006-01-01', '2022-12-31', 

                              train_test_split = 0.6, validation_split = .2,

                              predict_days = predict_days, sector = sector, 
                              depth=hidden_layer, epochs = epoch ,features = features, 
                              infer_train= False, dropout = dropout, hu = hu, 
                              early_stop = early_stop, past_history= past_history,
                              activation_function = leaky_relu, individual_asset = [True, _asset_]
                             )
    LSTM_1.full_workflow_and_plot()
    break
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# train this: 4295874865 or ['DCC PLC']
# ['vol_series_daily', 'vol_series_weekly', 'vol_series_monthly', 'buzz', 'ESG', 'ESGCombined', 'ESGControversies', 'EnvironmentalPillar', 'GovernancePillar', 'SocialPillar', 'Community', 'EnvironmentalInnovation', 'Management', 'ProductResponsibility', 'Shareholders', 'Workforce', 'V^YZ']
# train_test_prep() function is done
# prepare_test_train() is done
# 32 True
# 16 False
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
